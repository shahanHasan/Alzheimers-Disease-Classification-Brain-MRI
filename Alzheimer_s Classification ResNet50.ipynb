# %% [markdown]
# # Global PAth vars

# %%
#PATH 
base_path = "drive/MyDrive/Pammy_Alzheimers_Disease_Prediction/Dataset/Alzheimers_Dataset/"
train = f"{base_path}train/"
test = f"{base_path}test/"
Save = f"drive/MyDrive/Pammy_Alzheimers_Disease_Prediction/Visualisation/"


base_path_bin = "drive/MyDrive/Pammy_Alzheimers_Disease_Prediction/Dataset/Alzheimers_Dataset_Binary/"
train_bin = f"{base_path_bin}train/" 
test_bin = f"{base_path_bin}test/"
Save_bin = f"drive/MyDrive/Pammy_Alzheimers_Disease_Prediction/Visualisation/BinaryClassification/"

# %% [markdown]
# # Imports

# %%
import os, time

#arr operations
import numpy as np

# Progress Bar
from tqdm import tqdm

# Evaluation metrics
from sklearn import metrics
from sklearn.metrics import confusion_matrix, classification_report

#Importing Deep learning Libraries
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential, load_model
from keras.layers import InputLayer, BatchNormalization, Dropout, Flatten, Dense, Activation, MaxPool2D
from keras.layers import GlobalAveragePooling2D, Conv2D, MaxPooling2D
from keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler, Callback, ReduceLROnPlateau
from keras import optimizers, Input
from keras.utils.vis_utils import plot_model
from keras.applications.imagenet_utils import decode_predictions
import keras.backend as K


#Pretrained models
from keras.applications.xception import Xception
from keras.applications.inception_v3 import InceptionV3
from keras.applications.vgg16 import VGG16
from keras.applications.vgg19 import VGG19
from keras.applications.resnet import ResNet50
from keras.applications.resnet_v2 import ResNet152V2
#from keras.applications.resnet152_v2 import ResNet152V2


#Image read and show
import skimage.io
from skimage.io import imread, imshow
import matplotlib.pyplot as plt 
import seaborn as sns
sns.set_style('darkgrid')
#plt.style.use('fivethirtyeight')

#Metrics
from sklearn.metrics import f1_score , recall_score, accuracy_score, precision_score, confusion_matrix
from sklearn.metrics import roc_curve, auc, classification_report
from sklearn.preprocessing import label_binarize
from sklearn.multiclass import OneVsRestClassifier
from itertools import cycle

# %%
tf.__version__
# Out:
# '2.8.2'

# %% [markdown]
# # Utils Functions

# %%
def Confusion_Matrix_Heatmap(y_test,y_pred,class_Names, fName, ModelName):
    #Plot the confusion matrix to understand the classification in detail
    CM = confusion_matrix(y_test, y_pred)
    plt.figure(figsize=(10, 8), dpi=80, facecolor='w', edgecolor='k')
    ax = sns.heatmap(CM, cmap='Greens', annot=True, fmt='d', xticklabels=class_Names, yticklabels=class_Names)
    plt.title(f'Alzheimer\'s Disease Diagnosis - {ModelName}')
    plt.xlabel('Prediction')
    plt.ylabel('Truth')
    plt.savefig(f"{Save}{fName}")
    #plt.show(ax)

# Plot Evaluation Metrics
sns.set_style('darkgrid')
#plt.style.use('fivethirtyeight')
def Eval_Plot(acc,val_acc, loss,val_loss, auc, val_auc, precision, val_precision, path, title):
    
    fig, (ax1,ax2,ax3,ax4) = plt.subplots(1,4, figsize= (20,5))
    fig.suptitle(f"{title}\n", fontsize = 15)

    ax1.plot(range(1, len(acc) + 1), acc)
    ax1.plot(range(1, len(val_acc) + 1), val_acc)
    ax1.set_title('History of Accuracy', fontsize = 15)
    ax1.set_xlabel('Epochs', fontsize = 15)
    ax1.set_ylabel('Accuracy', fontsize = 15)
    ax1.legend(['Training', 'Validation'], fontsize = 15)


    ax2.plot(range(1, len(loss) + 1), loss)
    ax2.plot(range(1, len(val_loss) + 1), val_loss)
    ax2.set_title('History of Loss', fontsize = 15)
    ax2.set_xlabel('Epochs', fontsize = 15)
    ax2.set_ylabel('Loss', fontsize = 15)
    ax2.legend(['Training', 'Validation'], fontsize = 15)

    ax3.plot(range(1, len(auc) + 1), auc)
    ax3.plot(range(1, len(val_auc) + 1), val_auc)
    ax3.set_title('History of AUC', fontsize = 15)
    ax3.set_xlabel('Epochs', fontsize = 15)
    ax3.set_ylabel('AUC', fontsize = 15)
    ax3.legend(['Training', 'Validation'], fontsize = 15)
    
    ax4.plot(range(1, len(precision) + 1), precision)
    ax4.plot(range(1, len(val_precision) + 1), val_precision)
    ax4.set_title('History of Precision', fontsize = 15)
    ax4.set_xlabel('Epochs', fontsize = 15)
    ax4.set_ylabel('Precision', fontsize = 15)
    ax4.legend(['Training', 'Validation'], fontsize = 15)

    plt.savefig(f"{Save}{path}")
    #plt.show()

# %% [markdown]
# # Model Building

# %% [markdown]
# ## Set Seed

# %%
Seed = 29
Batch_Size = 32
Image_Size = 224
np.random.seed(Seed)
tf.random.set_seed(Seed)

# %% [markdown]
# ## GPU Test

# %%
# GPU
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %% [markdown]
# # MULTICLASS CLASSIFICATION MODELS

# %% [markdown]
# ## Data Generator

# %%
# Image data generator
training_data_gen = ImageDataGenerator(
    validation_split = 0.2,
    preprocessing_function=keras.applications.resnet.preprocess_input,           
    )

testing_data_gen = ImageDataGenerator(        
    preprocessing_function=keras.applications.resnet.preprocess_input,           
    )

validation_data_gen = ImageDataGenerator(
    preprocessing_function=keras.applications.resnet.preprocess_input,
    validation_split = 0.2
    )

# %% [markdown]
# ## Splitting the Data

# %%
training_data = training_data_gen.flow_from_directory(
    directory= train,
    target_size = (Image_Size,Image_Size),
    class_mode = 'categorical',
    color_mode  = 'rgb', 
    subset = 'training',
    seed = Seed,
    batch_size = Batch_Size)

validation_data = validation_data_gen.flow_from_directory(
  directory = train,
  target_size = (Image_Size,Image_Size),
  class_mode = 'categorical',
  color_mode  = 'rgb', 
  subset = 'validation',
  seed = Seed,
  batch_size = Batch_Size)

testing_data =  testing_data_gen.flow_from_directory(
  directory = test,
  target_size = (Image_Size,Image_Size),
  class_mode = 'categorical',
  color_mode  = 'rgb', 
  seed = Seed,
  batch_size = Batch_Size
)
# Out:
# Found 4098 images belonging to 4 classes.
# Found 1023 images belonging to 4 classes.
# Found 1279 images belonging to 4 classes.

# %%
ClassName2Ind = (training_data.class_indices)
Ind2ClassName = {v: k for k, v in ClassName2Ind.items()}
X,y = training_data.next()

# %%
imshow(X[0])
plt.title(Ind2ClassName[np.argmax(y[0],axis=0)])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Text(0.5, 1.0, 'NonDemented')

# %%
steps_per_epoch = training_data.n // training_data.batch_size
print('steps per epoch: ',steps_per_epoch)
# Out:
# steps per epoch:  128

# %%
assert len(training_data) > 5, "Less Than 5 Batches"
assert len(validation_data) > 5, "Less Than 5 Batches"
assert len(testing_data) > 5, "Less Than 5 Batches"

# %%
print(f"Train shape : {X.shape} y shape {y.shape}")
# Out:
# Train shape : (32, 224, 224, 3) y shape (32, 4)

# %% [markdown]
# ## ResNet50

# %%
ResNet50_base = ResNet50(
    include_top=False,
    weights="imagenet",
    input_shape=(Image_Size,Image_Size,3),
)

ResNet50_base.trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 1s 0us/step
# 94781440/94765736 [==============================] - 1s 0us/step

# %%
for layer in ResNet50_base.layers:
    layer.trainable=False

# %%
# Building Top
ResNet50_Top=Sequential()
ResNet50_Top.add(ResNet50_base)
ResNet50_Top.add(BatchNormalization())
ResNet50_Top.add(Conv2D(1024,3,padding='same',activation='relu'))
ResNet50_Top.add(Conv2D(1024,3,padding='same',activation='relu'))
ResNet50_Top.add(MaxPooling2D())
ResNet50_Top.add(Dropout(0.60))
ResNet50_Top.add(BatchNormalization())
ResNet50_Top.add(Flatten())
ResNet50_Top.add(Dense(1024,activation='relu'))
ResNet50_Top.add(Dense(4,activation='softmax'))

# %%
ResNet50_Top.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 7, 7, 2048)        23587712
#
#  batch_normalization (BatchN  (None, 7, 7, 2048)       8192
#  ormalization)
#
#  conv2d (Conv2D)             (None, 7, 7, 1024)        18875392
#
#  conv2d_1 (Conv2D)           (None, 7, 7, 1024)        9438208
#
#  max_pooling2d (MaxPooling2D  (None, 3, 3, 1024)       0
#  )
#
#  dropout (Dropout)           (None, 3, 3, 1024)        0
#
#  batch_normalization_1 (Batc  (None, 3, 3, 1024)       4096
#  hNormalization)
#
#  flatten (Flatten)           (None, 9216)              0
#
#  dense (Dense)               (None, 1024)              9438208
#
#  dense_1 (Dense)             (None, 4)                 4100
#
# =================================================================
# Total params: 61,355,908
# Trainable params: 37,762,052
# Non-trainable params: 23,593,856
# _________________________________________________________________

# %%
plot_model(
    ResNet50_Top,
    to_file=f"{Save}ResNet50/Architecture.png",
    show_shapes=False,
    show_dtype=False,
    show_layer_names=True,
    rankdir="TB",
    expand_nested=False,
    dpi=96,
    layer_range=None,
    show_layer_activations=False,
)

# %% [markdown]
# ### ResNet50 Transfer Learning - Freeze base model

# %%
METRICS = [
      keras.metrics.BinaryAccuracy(name='accuracy'),
      keras.metrics.Precision(name='precision'),
      keras.metrics.Recall(name='recall'),  
      keras.metrics.AUC(name='auc')
]

ResNet50_Top.compile(
    optimizer=keras.optimizers.Adam(0.001), 
    loss='categorical_crossentropy',
    metrics=METRICS,
)

epochs = 20
ResNet50_history_1 = ResNet50_Top.fit(
    training_data, 
    epochs=epochs, 
    validation_data=validation_data,
    steps_per_epoch=steps_per_epoch,
    verbose = 1,
    )
# Out:
# Epoch 1/20
# 128/128 [==============================] - 1385s 10s/step - loss: 1.2098 - accuracy: 0.7648 - precision: 0.5531 - recall: 0.3089 - auc: 0.7842 - val_loss: 1.0997 - val_accuracy: 0.7678 - val_precision: 0.6714 - val_recall: 0.1398 - val_auc: 0.7418
# Epoch 2/20
# 128/128 [==============================] - 18s 140ms/step - loss: 0.9052 - accuracy: 0.7986 - precision: 0.6722 - recall: 0.3797 - auc: 0.8428 - val_loss: 1.0713 - val_accuracy: 0.7783 - val_precision: 0.6058 - val_recall: 0.3245 - val_auc: 0.7937
# Epoch 3/20
# 128/128 [==============================] - 17s 135ms/step - loss: 0.8166 - accuracy: 0.8185 - precision: 0.6913 - recall: 0.4951 - auc: 0.8748 - val_loss: 1.1627 - val_accuracy: 0.7661 - val_precision: 0.5447 - val_recall: 0.3930 - val_auc: 0.8000
# Epoch 4/20
# 128/128 [==============================] - 17s 136ms/step - loss: 0.6834 - accuracy: 0.8543 - precision: 0.7351 - recall: 0.6525 - auc: 0.9153 - val_loss: 1.1149 - val_accuracy: 0.7832 - val_precision: 0.5747 - val_recall: 0.5112 - val_auc: 0.8337
# Epoch 5/20
# 128/128 [==============================] - 17s 135ms/step - loss: 0.5168 - accuracy: 0.8957 - precision: 0.8123 - recall: 0.7577 - auc: 0.9522 - val_loss: 1.1998 - val_accuracy: 0.7871 - val_precision: 0.5792 - val_recall: 0.5435 - val_auc: 0.8325
# Epoch 6/20
# 128/128 [==============================] - 18s 137ms/step - loss: 0.3488 - accuracy: 0.9336 - precision: 0.8770 - recall: 0.8542 - auc: 0.9775 - val_loss: 2.0543 - val_accuracy: 0.7808 - val_precision: 0.5624 - val_recall: 0.5552 - val_auc: 0.8118
# Epoch 7/20
# 128/128 [==============================] - 18s 136ms/step - loss: 0.3795 - accuracy: 0.9285 - precision: 0.8692 - recall: 0.8404 - auc: 0.9738 - val_loss: 1.1990 - val_accuracy: 0.7945 - val_precision: 0.5954 - val_recall: 0.5552 - val_auc: 0.8467
# Epoch 8/20
# 128/128 [==============================] - 17s 134ms/step - loss: 0.2127 - accuracy: 0.9625 - precision: 0.9299 - recall: 0.9193 - auc: 0.9909 - val_loss: 2.3758 - val_accuracy: 0.7810 - val_precision: 0.5629 - val_recall: 0.5552 - val_auc: 0.7926
# Epoch 9/20
# 128/128 [==============================] - 17s 135ms/step - loss: 0.3660 - accuracy: 0.9309 - precision: 0.8754 - recall: 0.8436 - auc: 0.9756 - val_loss: 1.2916 - val_accuracy: 0.8104 - val_precision: 0.6229 - val_recall: 0.6119 - val_auc: 0.8538
# Epoch 10/20
# 128/128 [==============================] - 17s 136ms/step - loss: 0.1977 - accuracy: 0.9641 - precision: 0.9327 - recall: 0.9230 - auc: 0.9920 - val_loss: 1.5702 - val_accuracy: 0.8003 - val_precision: 0.6036 - val_recall: 0.5865 - val_auc: 0.8180
# Epoch 11/20
# 128/128 [==============================] - 17s 136ms/step - loss: 0.1286 - accuracy: 0.9780 - precision: 0.9578 - recall: 0.9540 - auc: 0.9963 - val_loss: 1.4683 - val_accuracy: 0.8196 - val_precision: 0.6429 - val_recall: 0.6266 - val_auc: 0.8552
# Epoch 12/20
# 128/128 [==============================] - 17s 135ms/step - loss: 0.1061 - accuracy: 0.9803 - precision: 0.9620 - recall: 0.9592 - auc: 0.9975 - val_loss: 1.2918 - val_accuracy: 0.8302 - val_precision: 0.6630 - val_recall: 0.6520 - val_auc: 0.8722
# Epoch 13/20
# 128/128 [==============================] - 18s 138ms/step - loss: 0.0690 - accuracy: 0.9882 - precision: 0.9771 - recall: 0.9757 - auc: 0.9989 - val_loss: 1.6033 - val_accuracy: 0.8150 - val_precision: 0.6333 - val_recall: 0.6178 - val_auc: 0.8384
# Epoch 14/20
# 128/128 [==============================] - 17s 134ms/step - loss: 0.0494 - accuracy: 0.9917 - precision: 0.9840 - recall: 0.9828 - auc: 0.9989 - val_loss: 1.6884 - val_accuracy: 0.8282 - val_precision: 0.6569 - val_recall: 0.6549 - val_auc: 0.8490
# Epoch 15/20
# 128/128 [==============================] - 17s 135ms/step - loss: 0.0461 - accuracy: 0.9919 - precision: 0.9842 - recall: 0.9833 - auc: 0.9994 - val_loss: 1.8641 - val_accuracy: 0.8052 - val_precision: 0.6119 - val_recall: 0.6041 - val_auc: 0.8286
# Epoch 16/20
# 128/128 [==============================] - 17s 135ms/step - loss: 0.0565 - accuracy: 0.9894 - precision: 0.9791 - recall: 0.9784 - auc: 0.9988 - val_loss: 2.0145 - val_accuracy: 0.7813 - val_precision: 0.5643 - val_recall: 0.5494 - val_auc: 0.8108
# Epoch 17/20
# 128/128 [==============================] - 17s 134ms/step - loss: 0.0464 - accuracy: 0.9925 - precision: 0.9855 - recall: 0.9845 - auc: 0.9990 - val_loss: 2.1681 - val_accuracy: 0.7950 - val_precision: 0.5907 - val_recall: 0.5855 - val_auc: 0.8081
# Epoch 18/20
# 128/128 [==============================] - 17s 133ms/step - loss: 0.0364 - accuracy: 0.9934 - precision: 0.9870 - recall: 0.9865 - auc: 0.9995 - val_loss: 1.6360 - val_accuracy: 0.8390 - val_precision: 0.6784 - val_recall: 0.6764 - val_auc: 0.8691
# Epoch 19/20
# 128/128 [==============================] - 18s 136ms/step - loss: 0.0737 - accuracy: 0.9868 - precision: 0.9746 - recall: 0.9725 - auc: 0.9984 - val_loss: 1.6123 - val_accuracy: 0.8223 - val_precision: 0.6474 - val_recall: 0.6354 - val_auc: 0.8568
# Epoch 20/20
# 128/128 [==============================] - 18s 139ms/step - loss: 0.1116 - accuracy: 0.9807 - precision: 0.9641 - recall: 0.9584 - auc: 0.9968 - val_loss: 1.4380 - val_accuracy: 0.8082 - val_precision: 0.6219 - val_recall: 0.5934 - val_auc: 0.8498

# %%
path = "ResNet50/loss_acc_1.png"
title = " MODEL'S METRICS VISUALIZATION : Transfer Learning "
Eval_Plot(
    ResNet50_history_1.history['accuracy'],ResNet50_history_1.history['val_accuracy'],
    ResNet50_history_1.history['loss'],ResNet50_history_1.history['val_loss'],
    ResNet50_history_1.history['auc'],ResNet50_history_1.history['val_auc'],
    ResNet50_history_1.history['precision'],ResNet50_history_1.history['val_precision'],
    path, title
)

# %% [markdown]
# ### ResNet50 finetuning - Unfreeze base model and train entire model with low learning rate

# %%
isinstance(ResNet50_base.layers[1], BatchNormalization)
# Out:
# False

# %%
ResNet50_base.trainable = True
#freeze_BN(ResNet50_base)

# %%
epochs = 50
lr_reduce = ReduceLROnPlateau(monitor='val_auc', factor=0.6, patience=5, verbose=1, mode='max', min_lr=5e-5)

early_stopping_cb = EarlyStopping(
    monitor='val_auc', 
    patience=10, 
    restore_best_weights=True, 
    verbose=1, 
    mode="max"
    )

checkpoint_cb = ModelCheckpoint(
    f"{Save}ResNet50/ResNet50.h5", 
    monitor='val_auc',
    save_best_only=True, 
    verbose=1, 
    mode="max"
    )

ResNet50_Top.compile(
    optimizer=keras.optimizers.RMSprop(0.001),  # Low learning rate
    loss='categorical_crossentropy',
    metrics=METRICS,
)

ResNet50_Top.summary()

ResNet50_history_2 = ResNet50_Top.fit(
    training_data, 
    epochs=epochs, 
    validation_data=validation_data, 
    verbose = 1, 
    steps_per_epoch=steps_per_epoch,
    callbacks = [lr_reduce, early_stopping_cb, checkpoint_cb])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 7, 7, 2048)        23587712
#
#  batch_normalization (BatchN  (None, 7, 7, 2048)       8192
#  ormalization)
#
#  conv2d (Conv2D)             (None, 7, 7, 1024)        18875392
#
#  conv2d_1 (Conv2D)           (None, 7, 7, 1024)        9438208
#
#  max_pooling2d (MaxPooling2D  (None, 3, 3, 1024)       0
#  )
#
#  dropout (Dropout)           (None, 3, 3, 1024)        0
#
#  batch_normalization_1 (Batc  (None, 3, 3, 1024)       4096
#  hNormalization)
#
#  flatten (Flatten)           (None, 9216)              0
#
#  dense (Dense)               (None, 1024)              9438208
#
#  dense_1 (Dense)             (None, 4)                 4100
#
# =================================================================
# Total params: 61,355,908
# Trainable params: 61,296,644
# Non-trainable params: 59,264
# _________________________________________________________________
# Epoch 1/50
# 128/128 [==============================] - ETA: 0s - loss: 1.1965 - accuracy: 0.7788 - precision: 0.5879 - recall: 0.3849 - auc: 0.8052
# Epoch 1: val_auc improved from -inf to 0.62311, saving model to drive/MyDrive/Pammy_Alzheimers_Disease_Prediction/Visualisation/ResNet50/ResNet50.h5
# 128/128 [==============================] - 59s 345ms/step - loss: 1.1965 - accuracy: 0.7788 - precision: 0.5879 - recall: 0.3849 - auc: 0.8052 - val_loss: 17.2331 - val_accuracy: 0.6999 - val_precision: 0.3998 - val_recall: 0.3998 - val_auc: 0.6231 - lr: 0.0010
# Epoch 2/50
# 128/128 [==============================] - ETA: 0s - loss: 0.9918 - accuracy: 0.7845 - precision: 0.6314 - recall: 0.3315 - auc: 0.8212
# Epoch 2: val_auc did not improve from 0.62311
# 128/128 [==============================] - 32s 245ms/step - loss: 0.9918 - accuracy: 0.7845 - precision: 0.6314 - recall: 0.3315 - auc: 0.8212 - val_loss: 722.8312 - val_accuracy: 0.6750 - val_precision: 0.3500 - val_recall: 0.3500 - val_auc: 0.5666 - lr: 0.0010
# Epoch 3/50
# 128/128 [==============================] - ETA: 0s - loss: 0.8806 - accuracy: 0.8059 - precision: 0.6742 - recall: 0.4326 - auc: 0.8603
# Epoch 3: val_auc improved from 0.62311 to 0.76315, saving model to drive/MyDrive/Pammy_Alzheimers_Disease_Prediction/Visualisation/ResNet50/ResNet50.h5
# 128/128 [==============================] - 36s 281ms/step - loss: 0.8806 - accuracy: 0.8059 - precision: 0.6742 - recall: 0.4326 - auc: 0.8603 - val_loss: 2.0342 - val_accuracy: 0.7297 - val_precision: 0.4511 - val_recall: 0.3744 - val_auc: 0.7632 - lr: 0.0010
# Epoch 4/50
# 128/128 [==============================] - ETA: 0s - loss: 0.6865 - accuracy: 0.8607 - precision: 0.7550 - recall: 0.6554 - auc: 0.9180
# Epoch 4: val_auc did not improve from 0.76315
# 128/128 [==============================] - 32s 244ms/step - loss: 0.6865 - accuracy: 0.8607 - precision: 0.7550 - recall: 0.6554 - auc: 0.9180 - val_loss: 176.3513 - val_accuracy: 0.7512 - val_precision: 0.5024 - val_recall: 0.5024 - val_auc: 0.6709 - lr: 0.0010
# Epoch 5/50
# 128/128 [==============================] - ETA: 0s - loss: 0.4717 - accuracy: 0.9105 - precision: 0.8390 - recall: 0.7946 - auc: 0.9614
# Epoch 5: val_auc did not improve from 0.76315
# 128/128 [==============================] - 31s 244ms/step - loss: 0.4717 - accuracy: 0.9105 - precision: 0.8390 - recall: 0.7946 - auc: 0.9614 - val_loss: 132.0426 - val_accuracy: 0.7744 - val_precision: 0.5521 - val_recall: 0.5181 - val_auc: 0.7278 - lr: 0.0010
# Epoch 6/50
# 128/128 [==============================] - ETA: 0s - loss: 0.3621 - accuracy: 0.9382 - precision: 0.8870 - recall: 0.8628 - auc: 0.9788
# Epoch 6: val_auc did not improve from 0.76315
# 128/128 [==============================] - 31s 244ms/step - loss: 0.3621 - accuracy: 0.9382 - precision: 0.8870 - recall: 0.8628 - auc: 0.9788 - val_loss: 21.4665 - val_accuracy: 0.7661 - val_precision: 0.5325 - val_recall: 0.5288 - val_auc: 0.7235 - lr: 0.0010
# Epoch 7/50
# 128/128 [==============================] - ETA: 0s - loss: 0.2451 - accuracy: 0.9595 - precision: 0.9241 - recall: 0.9129 - auc: 0.9875
# Epoch 7: val_auc did not improve from 0.76315
# 128/128 [==============================] - 31s 244ms/step - loss: 0.2451 - accuracy: 0.9595 - precision: 0.9241 - recall: 0.9129 - auc: 0.9875 - val_loss: 35.1329 - val_accuracy: 0.7490 - val_precision: 0.4980 - val_recall: 0.4956 - val_auc: 0.6943 - lr: 0.0010
# Epoch 8/50
# 128/128 [==============================] - ETA: 0s - loss: 0.1816 - accuracy: 0.9691 - precision: 0.9417 - recall: 0.9343 - auc: 0.9927
# Epoch 8: val_auc improved from 0.76315 to 0.76515, saving model to drive/MyDrive/Pammy_Alzheimers_Disease_Prediction/Visualisation/ResNet50/ResNet50.h5
# 128/128 [==============================] - 36s 283ms/step - loss: 0.1816 - accuracy: 0.9691 - precision: 0.9417 - recall: 0.9343 - auc: 0.9927 - val_loss: 10.6482 - val_accuracy: 0.8013 - val_precision: 0.6033 - val_recall: 0.5992 - val_auc: 0.7652 - lr: 0.0010
# Epoch 9/50
# 128/128 [==============================] - ETA: 0s - loss: 0.1795 - accuracy: 0.9711 - precision: 0.9442 - recall: 0.9400 - auc: 0.9933
# Epoch 9: val_auc did not improve from 0.76515
# 128/128 [==============================] - 32s 245ms/step - loss: 0.1795 - accuracy: 0.9711 - precision: 0.9442 - recall: 0.9400 - auc: 0.9933 - val_loss: 3.9792 - val_accuracy: 0.7199 - val_precision: 0.4386 - val_recall: 0.4291 - val_auc: 0.7000 - lr: 0.0010
# Epoch 10/50
# 128/128 [==============================] - ETA: 0s - loss: 0.1580 - accuracy: 0.9754 - precision: 0.9526 - recall: 0.9488 - auc: 0.9938
# Epoch 10: val_auc improved from 0.76515 to 0.86133, saving model to drive/MyDrive/Pammy_Alzheimers_Disease_Prediction/Visualisation/ResNet50/ResNet50.h5
# 128/128 [==============================] - 36s 283ms/step - loss: 0.1580 - accuracy: 0.9754 - precision: 0.9526 - recall: 0.9488 - auc: 0.9938 - val_loss: 1.5358 - val_accuracy: 0.8245 - val_precision: 0.6530 - val_recall: 0.6364 - val_auc: 0.8613 - lr: 0.0010
# Epoch 11/50
# 128/128 [==============================] - ETA: 0s - loss: 0.1220 - accuracy: 0.9799 - precision: 0.9610 - recall: 0.9584 - auc: 0.9958
# Epoch 11: val_auc did not improve from 0.86133
# 128/128 [==============================] - 32s 246ms/step - loss: 0.1220 - accuracy: 0.9799 - precision: 0.9610 - recall: 0.9584 - auc: 0.9958 - val_loss: 2.4006 - val_accuracy: 0.8324 - val_precision: 0.6680 - val_recall: 0.6549 - val_auc: 0.8442 - lr: 0.0010
# Epoch 12/50
# 128/128 [==============================] - ETA: 0s - loss: 0.1329 - accuracy: 0.9802 - precision: 0.9618 - recall: 0.9589 - auc: 0.9957
# Epoch 12: val_auc did not improve from 0.86133
# 128/128 [==============================] - 31s 244ms/step - loss: 0.1329 - accuracy: 0.9802 - precision: 0.9618 - recall: 0.9589 - auc: 0.9957 - val_loss: 5.5418 - val_accuracy: 0.7314 - val_precision: 0.4621 - val_recall: 0.4526 - val_auc: 0.6870 - lr: 0.0010
# Epoch 13/50
# 128/128 [==============================] - ETA: 0s - loss: 0.1113 - accuracy: 0.9843 - precision: 0.9692 - recall: 0.9680 - auc: 0.9960
# Epoch 13: val_auc did not improve from 0.86133
# 128/128 [==============================] - 31s 245ms/step - loss: 0.1113 - accuracy: 0.9843 - precision: 0.9692 - recall: 0.9680 - auc: 0.9960 - val_loss: 6.4019 - val_accuracy: 0.7739 - val_precision: 0.5492 - val_recall: 0.5347 - val_auc: 0.7501 - lr: 0.0010
# Epoch 14/50
# 128/128 [==============================] - ETA: 0s - loss: 0.0977 - accuracy: 0.9870 - precision: 0.9753 - recall: 0.9727 - auc: 0.9963
# Epoch 14: val_auc did not improve from 0.86133
# 128/128 [==============================] - 31s 244ms/step - loss: 0.0977 - accuracy: 0.9870 - precision: 0.9753 - recall: 0.9727 - auc: 0.9963 - val_loss: 6.8163 - val_accuracy: 0.7463 - val_precision: 0.4927 - val_recall: 0.4927 - val_auc: 0.7017 - lr: 0.0010
# Epoch 15/50
# 128/128 [==============================] - ETA: 0s - loss: 0.1524 - accuracy: 0.9833 - precision: 0.9670 - recall: 0.9663 - auc: 0.9943
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0006000000284984708.
#
# Epoch 15: val_auc did not improve from 0.86133
# 128/128 [==============================] - 31s 244ms/step - loss: 0.1524 - accuracy: 0.9833 - precision: 0.9670 - recall: 0.9663 - auc: 0.9943 - val_loss: 17.3845 - val_accuracy: 0.7984 - val_precision: 0.5982 - val_recall: 0.5894 - val_auc: 0.7949 - lr: 0.0010
# Epoch 16/50
# 128/128 [==============================] - ETA: 0s - loss: 0.0325 - accuracy: 0.9955 - precision: 0.9911 - recall: 0.9909 - auc: 0.9991
# Epoch 16: val_auc improved from 0.86133 to 0.88003, saving model to drive/MyDrive/Pammy_Alzheimers_Disease_Prediction/Visualisation/ResNet50/ResNet50.h5
# 128/128 [==============================] - 36s 282ms/step - loss: 0.0325 - accuracy: 0.9955 - precision: 0.9911 - recall: 0.9909 - auc: 0.9991 - val_loss: 1.6813 - val_accuracy: 0.8517 - val_precision: 0.7055 - val_recall: 0.6979 - val_auc: 0.8800 - lr: 6.0000e-04
# Epoch 17/50
# 128/128 [==============================] - ETA: 0s - loss: 0.0239 - accuracy: 0.9966 - precision: 0.9934 - recall: 0.9931 - auc: 0.9994
# Epoch 17: val_auc did not improve from 0.88003
# 128/128 [==============================] - 32s 246ms/step - loss: 0.0239 - accuracy: 0.9966 - precision: 0.9934 - recall: 0.9931 - auc: 0.9994 - val_loss: 2.9289 - val_accuracy: 0.8189 - val_precision: 0.6388 - val_recall: 0.6344 - val_auc: 0.8189 - lr: 6.0000e-04
# Epoch 18/50
# 128/128 [==============================] - ETA: 0s - loss: 0.0442 - accuracy: 0.9953 - precision: 0.9907 - recall: 0.9907 - auc: 0.9983
# Epoch 18: val_auc improved from 0.88003 to 0.88490, saving model to drive/MyDrive/Pammy_Alzheimers_Disease_Prediction/Visualisation/ResNet50/ResNet50.h5
# 128/128 [==============================] - 36s 282ms/step - loss: 0.0442 - accuracy: 0.9953 - precision: 0.9907 - recall: 0.9907 - auc: 0.9983 - val_loss: 1.7066 - val_accuracy: 0.8631 - val_precision: 0.7276 - val_recall: 0.7234 - val_auc: 0.8849 - lr: 6.0000e-04
# Epoch 19/50
# 128/128 [==============================] - ETA: 0s - loss: 0.0235 - accuracy: 0.9962 - precision: 0.9926 - recall: 0.9921 - auc: 0.9996
# Epoch 19: val_auc did not improve from 0.88490
# 128/128 [==============================] - 32s 246ms/step - loss: 0.0235 - accuracy: 0.9962 - precision: 0.9926 - recall: 0.9921 - auc: 0.9996 - val_loss: 2.2947 - val_accuracy: 0.8436 - val_precision: 0.6883 - val_recall: 0.6843 - val_auc: 0.8521 - lr: 6.0000e-04
# Epoch 20/50
# 128/128 [==============================] - ETA: 0s - loss: 0.0325 - accuracy: 0.9961 - precision: 0.9924 - recall: 0.9919 - auc: 0.9987
# Epoch 20: val_auc improved from 0.88490 to 0.90386, saving model to drive/MyDrive/Pammy_Alzheimers_Disease_Prediction/Visualisation/ResNet50/ResNet50.h5
# 128/128 [==============================] - 36s 283ms/step - loss: 0.0325 - accuracy: 0.9961 - precision: 0.9924 - recall: 0.9919 - auc: 0.9987 - val_loss: 1.4029 - val_accuracy: 0.8697 - val_precision: 0.7426 - val_recall: 0.7331 - val_auc: 0.9039 - lr: 6.0000e-04
# Epoch 21/50
# 128/128 [==============================] - ETA: 0s - loss: 0.0387 - accuracy: 0.9953 - precision: 0.9907 - recall: 0.9904 - auc: 0.9985
# Epoch 21: val_auc did not improve from 0.90386
# 128/128 [==============================] - 31s 245ms/step - loss: 0.0387 - accuracy: 0.9953 - precision: 0.9907 - recall: 0.9904 - auc: 0.9985 - val_loss: 3.9582 - val_accuracy: 0.7759 - val_precision: 0.5523 - val_recall: 0.5474 - val_auc: 0.7704 - lr: 6.0000e-04
# Epoch 22/50
# 128/128 [==============================] - ETA: 0s - loss: 0.0169 - accuracy: 0.9983 - precision: 0.9966 - recall: 0.9966 - auc: 0.9992
# Epoch 22: val_auc did not improve from 0.90386
# 128/128 [==============================] - 31s 245ms/step - loss: 0.0169 - accuracy: 0.9983 - precision: 0.9966 - recall: 0.9966 - auc: 0.9992 - val_loss: 6.1283 - val_accuracy: 0.8087 - val_precision: 0.6176 - val_recall: 0.6158 - val_auc: 0.7890 - lr: 6.0000e-04
# Epoch 23/50
# 128/128 [==============================] - ETA: 0s - loss: 0.0360 - accuracy: 0.9956 - precision: 0.9911 - recall: 0.9911 - auc: 0.9985
# Epoch 23: val_auc did not improve from 0.90386
# 128/128 [==============================] - 31s 244ms/step - loss: 0.0360 - accuracy: 0.9956 - precision: 0.9911 - recall: 0.9911 - auc: 0.9985 - val_loss: 2.4916 - val_accuracy: 0.8441 - val_precision: 0.6900 - val_recall: 0.6833 - val_auc: 0.8510 - lr: 6.0000e-04
# Epoch 24/50
# 128/128 [==============================] - ETA: 0s - loss: 0.0203 - accuracy: 0.9968 - precision: 0.9936 - recall: 0.9936 - auc: 0.9996
# Epoch 24: val_auc did not improve from 0.90386
# 128/128 [==============================] - 31s 245ms/step - loss: 0.0203 - accuracy: 0.9968 - precision: 0.9936 - recall: 0.9936 - auc: 0.9996 - val_loss: 3.2608 - val_accuracy: 0.8641 - val_precision: 0.7287 - val_recall: 0.7273 - val_auc: 0.8795 - lr: 6.0000e-04
# Epoch 25/50
# 128/128 [==============================] - ETA: 0s - loss: 0.0245 - accuracy: 0.9970 - precision: 0.9941 - recall: 0.9941 - auc: 0.9991
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0003600000170990825.
#
# Epoch 25: val_auc did not improve from 0.90386
# 128/128 [==============================] - 31s 245ms/step - loss: 0.0245 - accuracy: 0.9970 - precision: 0.9941 - recall: 0.9941 - auc: 0.9991 - val_loss: 1.5946 - val_accuracy: 0.8651 - val_precision: 0.7307 - val_recall: 0.7292 - val_auc: 0.8902 - lr: 6.0000e-04
# Epoch 26/50
# 128/128 [==============================] - ETA: 0s - loss: 0.0123 - accuracy: 0.9985 - precision: 0.9970 - recall: 0.9970 - auc: 0.9997
# Epoch 26: val_auc did not improve from 0.90386
# 128/128 [==============================] - 31s 245ms/step - loss: 0.0123 - accuracy: 0.9985 - precision: 0.9970 - recall: 0.9970 - auc: 0.9997 - val_loss: 2.2337 - val_accuracy: 0.8644 - val_precision: 0.7290 - val_recall: 0.7283 - val_auc: 0.8744 - lr: 3.6000e-04
# Epoch 27/50
# 128/128 [==============================] - ETA: 0s - loss: 0.0147 - accuracy: 0.9986 - precision: 0.9973 - recall: 0.9973 - auc: 0.9995
# Epoch 27: val_auc did not improve from 0.90386
# 128/128 [==============================] - 32s 246ms/step - loss: 0.0147 - accuracy: 0.9986 - precision: 0.9973 - recall: 0.9973 - auc: 0.9995 - val_loss: 2.0089 - val_accuracy: 0.8827 - val_precision: 0.7659 - val_recall: 0.7644 - val_auc: 0.8951 - lr: 3.6000e-04
# Epoch 28/50
# 128/128 [==============================] - ETA: 0s - loss: 0.0086 - accuracy: 0.9994 - precision: 0.9988 - recall: 0.9988 - auc: 0.9998
# Epoch 28: val_auc did not improve from 0.90386
# 128/128 [==============================] - 31s 245ms/step - loss: 0.0086 - accuracy: 0.9994 - precision: 0.9988 - recall: 0.9988 - auc: 0.9998 - val_loss: 1.6503 - val_accuracy: 0.8827 - val_precision: 0.7675 - val_recall: 0.7615 - val_auc: 0.8953 - lr: 3.6000e-04
# Epoch 29/50
# 128/128 [==============================] - ETA: 0s - loss: 0.0064 - accuracy: 0.9991 - precision: 0.9983 - recall: 0.9983 - auc: 0.9999
# Epoch 29: val_auc did not improve from 0.90386
# 128/128 [==============================] - 31s 245ms/step - loss: 0.0064 - accuracy: 0.9991 - precision: 0.9983 - recall: 0.9983 - auc: 0.9999 - val_loss: 2.3204 - val_accuracy: 0.8732 - val_precision: 0.7471 - val_recall: 0.7449 - val_auc: 0.8764 - lr: 3.6000e-04
# Epoch 30/50
# 128/128 [==============================] - ETA: 0s - loss: 0.0088 - accuracy: 0.9991 - precision: 0.9983 - recall: 0.9983 - auc: 0.9997
# Epoch 30: ReduceLROnPlateau reducing learning rate to 0.00021600000327453016.
# Restoring model weights from the end of the best epoch: 20.
#
# Epoch 30: val_auc did not improve from 0.90386
# 128/128 [==============================] - 32s 246ms/step - loss: 0.0088 - accuracy: 0.9991 - precision: 0.9983 - recall: 0.9983 - auc: 0.9997 - val_loss: 1.9402 - val_accuracy: 0.8925 - val_precision: 0.7861 - val_recall: 0.7830 - val_auc: 0.8943 - lr: 3.6000e-04
# Epoch 30: early stopping

# %% [markdown]
# ### Scores

# %%
scores_ResNet50 = ResNet50_Top.evaluate(testing_data)
# Out:
# 40/40 [==============================] - 693s 18s/step - loss: 1.7367 - accuracy: 0.8661 - precision: 0.7361 - recall: 0.7240 - auc: 0.8829

# %%
print(f"Accuracy in test set  : {scores_ResNet50[1]}")
print(f"Precision in test set : {scores_ResNet50[2]}")
print(f"Recall in test set    : {scores_ResNet50[3]}")
print(f"AUC in test set       : {scores_ResNet50[4]}")
# Out:
# Accuracy in test set  : 0.8661063313484192
# Precision in test set : 0.7360890507698059
# Recall in test set    : 0.7240031361579895
# AUC in test set       : 0.882936418056488

# %%
import pandas as pd
Scores = pd.DataFrame([scores_ResNet50], columns = ["Loss", "Test Accuracy", "Precision", "Recall", "AUC"])
Scores
# Out:
#        Loss  Test Accuracy  Precision    Recall       AUC
# 0  1.736727       0.866106   0.736089  0.724003  0.882936

# %%
Scores.to_csv(f"{Save}ResNet50/score.csv")

# %% [markdown]
# ### Plots

# %%
path = "ResNet50/loss_acc_2.png"
title = " MODEL'S METRICS VISUALIZATION : Fine Tuning "
Eval_Plot(
    ResNet50_history_2.history['accuracy'],ResNet50_history_2.history['val_accuracy'],
    ResNet50_history_2.history['loss'],ResNet50_history_2.history['val_loss'],
    ResNet50_history_2.history['auc'],ResNet50_history_2.history['val_auc'],
    ResNet50_history_2.history['precision'],ResNet50_history_2.history['val_precision'],
    path, title
)

# %%
predictions = ResNet50_Top.predict(testing_data) 
y_pred = predictions.argmax(axis = -1)
y_label = testing_data.labels.copy()
class_Names = list(testing_data.class_indices.keys())

# %%
assert y_pred.shape == y_label.shape

# %%
Confusion_Matrix_Heatmap(y_label, y_pred, class_Names, f"ResNet50/HeatMap.jpeg", "ResNet50")

# %% [markdown]
# # GradCam, activation Visualisation

# %%
# Display
from IPython.display import Image, display
import matplotlib.pyplot as plt
import matplotlib.cm as cm

# %% [markdown]
# ## Configurable parameters

# %%
ResNet50_Top.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 7, 7, 2048)        23587712
#
#  batch_normalization (BatchN  (None, 7, 7, 2048)       8192
#  ormalization)
#
#  conv2d (Conv2D)             (None, 7, 7, 1024)        18875392
#
#  conv2d_1 (Conv2D)           (None, 7, 7, 1024)        9438208
#
#  max_pooling2d (MaxPooling2D  (None, 3, 3, 1024)       0
#  )
#
#  dropout (Dropout)           (None, 3, 3, 1024)        0
#
#  batch_normalization_1 (Batc  (None, 3, 3, 1024)       4096
#  hNormalization)
#
#  flatten (Flatten)           (None, 9216)              0
#
#  dense (Dense)               (None, 1024)              9438208
#
#  dense_1 (Dense)             (None, 4)                 4100
#
# =================================================================
# Total params: 61,355,908
# Trainable params: 61,296,644
# Non-trainable params: 59,264
# _________________________________________________________________

# %%
last_conv_layer_name = "conv2d_1"
decode_predictions = keras.applications.inception_v3.decode_predictions
X,y = testing_data.next()

# %%
X[3].shape
# Out:
# (224, 224, 3)

# %%
img_path = X[0].copy()
imshow(X[3])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
def get_img_array(img_path, size):
    # `img` is a PIL image of size 299x299
    img = keras.preprocessing.image.load_img(img_path, target_size=size)
    # `array` is a float32 Numpy array of shape (299, 299, 3)
    array = keras.preprocessing.image.img_to_array(img)
    # We add a dimension to transform our image array into a "batch"
    # of size (1, 299, 299, 3)
    array = np.expand_dims(array, axis=0)
    return array


def make_gradcam_heatmap(img_array, model, last_conv_layer_name, pred_index=None):
    # First, we create a model that maps the input image to the activations
    # of the last conv layer as well as the output predictions
    grad_model = tf.keras.models.Model(
        [model.inputs], [model.get_layer(last_conv_layer_name).output, model.output]
    )

    # Then, we compute the gradient of the top predicted class for our input image
    # with respect to the activations of the last conv layer
    with tf.GradientTape() as tape:
        last_conv_layer_output, preds = grad_model(img_array)
        if pred_index is None:
            pred_index = tf.argmax(preds[0])
        class_channel = preds[:, pred_index]

    # This is the gradient of the output neuron (top predicted or chosen)
    # with regard to the output feature map of the last conv layer
    grads = tape.gradient(class_channel, last_conv_layer_output)

    # This is a vector where each entry is the mean intensity of the gradient
    # over a specific feature map channel
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))

    # We multiply each channel in the feature map array
    # by "how important this channel is" with regard to the top predicted class
    # then sum all the channels to obtain the heatmap class activation
    last_conv_layer_output = last_conv_layer_output[0]
    heatmap = last_conv_layer_output @ pooled_grads[..., tf.newaxis]
    heatmap = tf.squeeze(heatmap)

    # For visualization purpose, we will also normalize the heatmap between 0 & 1
    heatmap = tf.maximum(heatmap, 0) / tf.math.reduce_max(heatmap)
    return heatmap.numpy()

def get_gradcam_img(img_path, heatmap, cam_path="cam.jpg", alpha=0.4):
    # Load the original image
    img = keras.preprocessing.image.load_img(img_path)
    img = keras.preprocessing.image.img_to_array(img)

    # Rescale heatmap to a range 0-255
    heatmap = np.uint8(255 * heatmap)

    # Use jet colormap to colorize heatmap
    jet = cm.get_cmap("jet")

    # Use RGB values of the colormap
    jet_colors = jet(np.arange(256))[:, :3]
    jet_heatmap = jet_colors[heatmap]

    # Create an image with RGB colorized heatmap
    jet_heatmap = keras.preprocessing.image.array_to_img(jet_heatmap)
    jet_heatmap = jet_heatmap.resize((img.shape[1], img.shape[0]))
    jet_heatmap = keras.preprocessing.image.img_to_array(jet_heatmap)

    # Superimpose the heatmap on original image
    superimposed_img = jet_heatmap * alpha + img
    superimposed_img = keras.preprocessing.image.array_to_img(superimposed_img)

    return superimposed_img

# %%
# Make model
model_load= keras.models.load_model(f"{Save}ResNet50/ResNet50.h5")

# Remove last layer's softmax
model_load.layers[-1].activation = None

# %%
class_Names = os.listdir(f"{test}").copy()
img_paths = []
for cls in class_Names:
  ClsPath2dir = f"{test}{cls}/"
  content = os.listdir(ClsPath2dir)
  imgPath = os.path.join(ClsPath2dir, np.random.choice(content))
  img_paths.append(imgPath)

img_paths
# Out:
# ['drive/MyDrive/Pammy_Alzheimers_Disease_Prediction/Dataset/Alzheimers_Dataset/test/ModerateDemented/30 (2).jpg',
#  'drive/MyDrive/Pammy_Alzheimers_Disease_Prediction/Dataset/Alzheimers_Dataset/test/VeryMildDemented/27 (53).jpg',
#  'drive/MyDrive/Pammy_Alzheimers_Disease_Prediction/Dataset/Alzheimers_Dataset/test/NonDemented/27 (75).jpg',
#  'drive/MyDrive/Pammy_Alzheimers_Disease_Prediction/Dataset/Alzheimers_Dataset/test/MildDemented/29 (28).jpg']

# %%
fig, axs = plt.subplots(2, 2, figsize = (15,15))
for ax, path, label in zip(axs.flatten(), img_paths, class_Names): 
  # Prepare image
  img_arry = keras.applications.resnet.preprocess_input(get_img_array(path, (Image_Size, Image_Size)))
  # Print what the top predicted class is
  preds = model_load.predict(img_arry)
  print(f"Predicted : {Ind2ClassName[int(preds.argmax(axis=-1).squeeze())]}")
  #print("Predicted:", decode_predictions(preds, top=1)[0])

  # Generate class activation heatmap
  heatmap = make_gradcam_heatmap(img_arry, model_load, last_conv_layer_name)

  # Get superImposed Image
  superimposed_img = get_gradcam_img(path, heatmap)
  ax.imshow(superimposed_img)
  ax.axis('off')
  ax.title.set_text(f"Predicted label : {Ind2ClassName[int(preds.argmax(axis=-1).squeeze())]} Actual : {label}")

plt.suptitle('Grad Cam Visualisation')
plt.savefig(f"{Save}ResNet50/GradCam.jpg")
plt.show()
# Out:
# Predicted : ModerateDemented
# Predicted : VeryMildDemented
# Predicted : NonDemented
# Predicted : NonDemented
