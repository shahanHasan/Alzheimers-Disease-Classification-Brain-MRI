# %% [markdown]
# # Global PAth vars

# %%
#PATH
base_path = "drive/MyDrive/Pammy_Alzheimers_Disease_Prediction/Dataset/Alzheimers_Dataset/"
train = f"{base_path}train/"
test = f"{base_path}test/"
Save = f"drive/MyDrive/Pammy_Alzheimers_Disease_Prediction/Visualisation/"

base_path_bin = "drive/MyDrive/Pammy_Alzheimers_Disease_Prediction/Dataset/Alzheimers_Dataset_Binary/"
train_bin = f"{base_path_bin}train/" 
test_bin = f"{base_path_bin}test/"
Save_bin = f"drive/MyDrive/Pammy_Alzheimers_Disease_Prediction/Visualisation/BinaryClassification/"

# %% [markdown]
# # Imports

# %%
import os, time

#arr operations
import numpy as np

# Progress Bar
from tqdm import tqdm

# Evaluation metrics
from sklearn import metrics
from sklearn.metrics import confusion_matrix, classification_report

#Importing Deep learning Libraries
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential, load_model
from keras.layers import InputLayer, BatchNormalization, Dropout, Flatten, Dense, Activation, MaxPool2D
from keras.layers import GlobalAveragePooling2D, Conv2D, MaxPooling2D
from keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler, Callback, ReduceLROnPlateau
from keras import optimizers, Input
from keras.utils.vis_utils import plot_model
from keras.applications.imagenet_utils import decode_predictions
import keras.backend as K


#Pretrained models
from keras.applications.xception import Xception
from keras.applications.inception_v3 import InceptionV3
from keras.applications.vgg16 import VGG16
from keras.applications.vgg19 import VGG19
from keras.applications.resnet import ResNet50
from keras.applications.resnet_v2 import ResNet152V2
#from keras.applications.resnet152_v2 import ResNet152V2


#Image read and show
import skimage.io
from skimage.io import imread, imshow
import matplotlib.pyplot as plt 
import seaborn as sns
sns.set_style('darkgrid')
#plt.style.use('fivethirtyeight')

#Metrics
from sklearn.metrics import f1_score , recall_score, accuracy_score, precision_score, confusion_matrix
from sklearn.metrics import roc_curve, auc, classification_report
from sklearn.preprocessing import label_binarize
from sklearn.multiclass import OneVsRestClassifier
from itertools import cycle

# %%
tf.__version__
# Out:
# '2.8.2'

# %% [markdown]
# # Utils Functions

# %%
def Confusion_Matrix_Heatmap(y_test,y_pred,class_Names, fName, ModelName):
    #Plot the confusion matrix to understand the classification in detail
    CM = confusion_matrix(y_test, y_pred)
    plt.figure(figsize=(10, 8), dpi=80, facecolor='w', edgecolor='k')
    ax = sns.heatmap(CM, cmap='Greens', annot=True, fmt='d', xticklabels=class_Names, yticklabels=class_Names)
    plt.title(f'Alzheimer\'s Disease Diagnosis - {ModelName}')
    plt.xlabel('Prediction')
    plt.ylabel('Truth')
    plt.savefig(f"{Save}{fName}")
    #plt.show(ax)

# Plot Evaluation Metrics
sns.set_style('darkgrid')
#plt.style.use('fivethirtyeight')
def Eval_Plot(acc,val_acc, loss,val_loss, auc, val_auc, precision, val_precision, path, title):
    
    fig, (ax1,ax2,ax3,ax4) = plt.subplots(1,4, figsize= (20,5))
    fig.suptitle(f"{title}\n", fontsize = 15)

    ax1.plot(range(1, len(acc) + 1), acc)
    ax1.plot(range(1, len(val_acc) + 1), val_acc)
    ax1.set_title('History of Accuracy', fontsize = 15)
    ax1.set_xlabel('Epochs', fontsize = 15)
    ax1.set_ylabel('Accuracy', fontsize = 15)
    ax1.legend(['Training', 'Validation'], fontsize = 15)


    ax2.plot(range(1, len(loss) + 1), loss)
    ax2.plot(range(1, len(val_loss) + 1), val_loss)
    ax2.set_title('History of Loss', fontsize = 15)
    ax2.set_xlabel('Epochs', fontsize = 15)
    ax2.set_ylabel('Loss', fontsize = 15)
    ax2.legend(['Training', 'Validation'], fontsize = 15)

    ax3.plot(range(1, len(auc) + 1), auc)
    ax3.plot(range(1, len(val_auc) + 1), val_auc)
    ax3.set_title('History of AUC', fontsize = 15)
    ax3.set_xlabel('Epochs', fontsize = 15)
    ax3.set_ylabel('AUC', fontsize = 15)
    ax3.legend(['Training', 'Validation'], fontsize = 15)
    
    ax4.plot(range(1, len(precision) + 1), precision)
    ax4.plot(range(1, len(val_precision) + 1), val_precision)
    ax4.set_title('History of Precision', fontsize = 15)
    ax4.set_xlabel('Epochs', fontsize = 15)
    ax4.set_ylabel('Precision', fontsize = 15)
    ax4.legend(['Training', 'Validation'], fontsize = 15)

    plt.savefig(f"{Save}{path}")
    #plt.show()

def freeze_BN(model):
  """
  Unfreeze all layers except BatchNorm
  """
  for layer in model.layers:
    if isinstance(layer, BatchNormalization):
      layer.trainable = False

# %% [markdown]
# # Model Building

# %% [markdown]
# ## Set Seed

# %%
Seed = 29
Batch_Size = 32
Image_Size = 299
np.random.seed(Seed)
tf.random.set_seed(Seed)

# %% [markdown]
# ## GPU Test

# %%
# GPU
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %% [markdown]
# # MULTICLASS CLASSIFICATION MODELS

# %% [markdown]
# ## Data Generator

# %%
# Image data generator
training_data_gen = ImageDataGenerator(
    validation_split = 0.2,
    preprocessing_function=keras.applications.inception_v3.preprocess_input,           
    )

testing_data_gen = ImageDataGenerator(        
    preprocessing_function=keras.applications.inception_v3.preprocess_input,           
    )

validation_data_gen = ImageDataGenerator(
    preprocessing_function=keras.applications.inception_v3.preprocess_input,
    validation_split = 0.2
    )

# %% [markdown]
# ## Splitting the Data

# %%
training_data = training_data_gen.flow_from_directory(
    directory= train,
    target_size = (Image_Size,Image_Size),
    class_mode = 'categorical',
    color_mode  = 'rgb', 
    subset = 'training',
    seed = Seed,
    batch_size = Batch_Size)

validation_data = validation_data_gen.flow_from_directory(
  directory = train,
  target_size = (Image_Size,Image_Size),
  class_mode = 'categorical',
  color_mode  = 'rgb', 
  subset = 'validation',
  seed = Seed,
  batch_size = Batch_Size)

testing_data =  testing_data_gen.flow_from_directory(
  directory = test,
  target_size = (Image_Size,Image_Size),
  class_mode = 'categorical',
  color_mode  = 'rgb', 
  seed = Seed,
  batch_size = Batch_Size
)
# Out:
# Found 4098 images belonging to 4 classes.
# Found 1023 images belonging to 4 classes.
# Found 1279 images belonging to 4 classes.

# %%
ClassName2Ind = (training_data.class_indices)
Ind2ClassName = {v: k for k, v in ClassName2Ind.items()}
X,y = training_data.next()

# %%
path = "Inception/Pre-Processed-Image.png"
plt.figure(figsize=(10, 8))
plt.imshow(X[0])
plt.title(Ind2ClassName[np.argmax(y[0],axis=0)])
plt.axis("off")
plt.savefig(f"{Save}{path}")
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# Image data generator
generate_samples = ImageDataGenerator(
    validation_split = 0.2,
    preprocessing_function=keras.applications.inception_v3.preprocess_input,           
    )

# %%
steps_per_epoch = training_data.n // training_data.batch_size
print('steps per epoch: ',steps_per_epoch)
# Out:
# steps per epoch:  128

# %%
assert len(training_data) > 5, "Less Than 5 Batches"
assert len(validation_data) > 5, "Less Than 5 Batches"
assert len(testing_data) > 5, "Less Than 5 Batches"

# %%
print(f"Train shape : {X.shape} y shape {y.shape}")
# Out:
# Train shape : (32, 299, 299, 3) y shape (32, 4)

# %% [markdown]
# ## InceptionV3

# %%
Inception_base = InceptionV3(
    include_top=False,
    weights="imagenet",
    input_shape=(Image_Size,Image_Size,3),
)

Inception_base.trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87916544/87910968 [==============================] - 1s 0us/step
# 87924736/87910968 [==============================] - 1s 0us/step

# %%
# for layer in Inception_base.layers:
#     layer.trainable=False

# %%
# Building Top
Inception_Extention=Sequential()
Inception_Extention.add(Inception_base)
Inception_Extention.add(BatchNormalization())
Inception_Extention.add(Conv2D(1024,3,padding='same',activation='relu'))
Inception_Extention.add(Conv2D(1024,3,padding='same',activation='relu'))
Inception_Extention.add(MaxPooling2D())
Inception_Extention.add(Dropout(0.60))
Inception_Extention.add(BatchNormalization())
Inception_Extention.add(Flatten())
Inception_Extention.add(Dense(1024,activation='relu'))
Inception_Extention.add(Dense(4,activation='softmax'))

# %%
Inception_Extention.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inception_v3 (Functional)   (None, 8, 8, 2048)        21802784
#
#  batch_normalization_95 (Bat  (None, 8, 8, 2048)       8192
#  chNormalization)
#
#  conv2d_96 (Conv2D)          (None, 8, 8, 1024)        18875392
#
#  conv2d_97 (Conv2D)          (None, 8, 8, 1024)        9438208
#
#  max_pooling2d_4 (MaxPooling  (None, 4, 4, 1024)       0
#  2D)
#
#  dropout (Dropout)           (None, 4, 4, 1024)        0
#
#  batch_normalization_96 (Bat  (None, 4, 4, 1024)       4096
#  chNormalization)
#
#  flatten (Flatten)           (None, 16384)             0
#
#  dense (Dense)               (None, 1024)              16778240
#
#  dense_1 (Dense)             (None, 4)                 4100
#
# =================================================================
# Total params: 66,911,012
# Trainable params: 45,102,084
# Non-trainable params: 21,808,928
# _________________________________________________________________

# %%
plot_model(
    Inception_Extention,
    to_file=f"{Save}Inception/Architecture.png",
    show_shapes=False,
    show_dtype=False,
    show_layer_names=True,
    rankdir="TB",
    expand_nested=False,
    dpi=96,
    layer_range=None,
    show_layer_activations=False,
)

# %% [markdown]
# ### InceptionV3 Transfer Learning - Freeze base model

# %%
METRICS = [
      keras.metrics.BinaryAccuracy(name='accuracy'),
      keras.metrics.Precision(name='precision'),
      keras.metrics.Recall(name='recall'),  
      keras.metrics.AUC(name='auc')
]

Inception_Extention.compile(
    optimizer=keras.optimizers.Adam(), 
    loss='categorical_crossentropy',
    metrics=METRICS,
)

epochs = 20
Inception_history_1 = Inception_Extention.fit(
    training_data, 
    epochs=epochs, 
    validation_data=validation_data,
    steps_per_epoch=steps_per_epoch,
    verbose = 1,
    )
# Out:
# Epoch 1/20
# 128/128 [==============================] - 2505s 19s/step - loss: 1.4334 - accuracy: 0.7604 - precision: 0.5316 - recall: 0.3495 - auc: 0.7803 - val_loss: 1.1776 - val_accuracy: 0.7182 - val_precision: 0.1934 - val_recall: 0.0401 - val_auc: 0.7112
# Epoch 2/20
# 128/128 [==============================] - 27s 214ms/step - loss: 0.9346 - accuracy: 0.7895 - precision: 0.6407 - recall: 0.3596 - auc: 0.8310 - val_loss: 1.0346 - val_accuracy: 0.7810 - val_precision: 0.6453 - val_recall: 0.2757 - val_auc: 0.7842
# Epoch 3/20
# 128/128 [==============================] - 28s 219ms/step - loss: 0.8698 - accuracy: 0.8064 - precision: 0.6817 - recall: 0.4230 - auc: 0.8557 - val_loss: 1.0532 - val_accuracy: 0.7739 - val_precision: 0.6219 - val_recall: 0.2444 - val_auc: 0.7586
# Epoch 4/20
# 128/128 [==============================] - 28s 220ms/step - loss: 0.8021 - accuracy: 0.8205 - precision: 0.6840 - recall: 0.5243 - auc: 0.8796 - val_loss: 1.3032 - val_accuracy: 0.7473 - val_precision: 0.4937 - val_recall: 0.4242 - val_auc: 0.7837
# Epoch 5/20
# 128/128 [==============================] - 28s 219ms/step - loss: 0.7288 - accuracy: 0.8391 - precision: 0.7122 - recall: 0.5981 - auc: 0.9013 - val_loss: 1.2564 - val_accuracy: 0.7224 - val_precision: 0.4384 - val_recall: 0.3930 - val_auc: 0.7554
# Epoch 6/20
# 128/128 [==============================] - 28s 220ms/step - loss: 0.6250 - accuracy: 0.8669 - precision: 0.7561 - recall: 0.6906 - auc: 0.9288 - val_loss: 1.1455 - val_accuracy: 0.7483 - val_precision: 0.4962 - val_recall: 0.4477 - val_auc: 0.7993
# Epoch 7/20
# 128/128 [==============================] - 28s 219ms/step - loss: 0.5278 - accuracy: 0.8907 - precision: 0.8017 - recall: 0.7479 - auc: 0.9493 - val_loss: 1.1622 - val_accuracy: 0.7781 - val_precision: 0.5645 - val_recall: 0.4917 - val_auc: 0.8202
# Epoch 8/20
# 128/128 [==============================] - 28s 220ms/step - loss: 0.4380 - accuracy: 0.9131 - precision: 0.8419 - recall: 0.8030 - auc: 0.9651 - val_loss: 1.2543 - val_accuracy: 0.7771 - val_precision: 0.5568 - val_recall: 0.5318 - val_auc: 0.8284
# Epoch 9/20
# 128/128 [==============================] - 28s 220ms/step - loss: 0.3397 - accuracy: 0.9327 - precision: 0.8745 - recall: 0.8534 - auc: 0.9786 - val_loss: 1.4781 - val_accuracy: 0.7761 - val_precision: 0.5552 - val_recall: 0.5259 - val_auc: 0.8009
# Epoch 10/20
# 128/128 [==============================] - 28s 219ms/step - loss: 0.2961 - accuracy: 0.9431 - precision: 0.8935 - recall: 0.8770 - auc: 0.9835 - val_loss: 1.6327 - val_accuracy: 0.7637 - val_precision: 0.5280 - val_recall: 0.5161 - val_auc: 0.7985
# Epoch 11/20
# 128/128 [==============================] - 28s 220ms/step - loss: 0.2101 - accuracy: 0.9623 - precision: 0.9285 - recall: 0.9201 - auc: 0.9906 - val_loss: 1.3520 - val_accuracy: 0.7896 - val_precision: 0.5817 - val_recall: 0.5640 - val_auc: 0.8395
# Epoch 12/20
# 128/128 [==============================] - 28s 220ms/step - loss: 0.1821 - accuracy: 0.9670 - precision: 0.9377 - recall: 0.9297 - auc: 0.9935 - val_loss: 2.0453 - val_accuracy: 0.7458 - val_precision: 0.4916 - val_recall: 0.4878 - val_auc: 0.7799
# Epoch 13/20
# 128/128 [==============================] - 28s 220ms/step - loss: 0.1522 - accuracy: 0.9728 - precision: 0.9485 - recall: 0.9422 - auc: 0.9949 - val_loss: 1.7127 - val_accuracy: 0.7835 - val_precision: 0.5691 - val_recall: 0.5513 - val_auc: 0.8115
# Epoch 14/20
# 128/128 [==============================] - 28s 219ms/step - loss: 0.1291 - accuracy: 0.9759 - precision: 0.9534 - recall: 0.9501 - auc: 0.9964 - val_loss: 1.7271 - val_accuracy: 0.7991 - val_precision: 0.5990 - val_recall: 0.5943 - val_auc: 0.8341
# Epoch 15/20
# 128/128 [==============================] - 28s 220ms/step - loss: 0.4450 - accuracy: 0.9126 - precision: 0.8448 - recall: 0.7966 - auc: 0.9650 - val_loss: 1.7473 - val_accuracy: 0.7016 - val_precision: 0.3953 - val_recall: 0.3656 - val_auc: 0.7026
# Epoch 16/20
# 128/128 [==============================] - 28s 219ms/step - loss: 0.4492 - accuracy: 0.9129 - precision: 0.8388 - recall: 0.8064 - auc: 0.9637 - val_loss: 1.2099 - val_accuracy: 0.7796 - val_precision: 0.5639 - val_recall: 0.5220 - val_auc: 0.8279
# Epoch 17/20
# 128/128 [==============================] - 28s 220ms/step - loss: 0.2576 - accuracy: 0.9528 - precision: 0.9125 - recall: 0.8972 - auc: 0.9872 - val_loss: 1.2065 - val_accuracy: 0.7984 - val_precision: 0.6006 - val_recall: 0.5777 - val_auc: 0.8540
# Epoch 18/20
# 128/128 [==============================] - 28s 219ms/step - loss: 0.1738 - accuracy: 0.9676 - precision: 0.9381 - recall: 0.9319 - auc: 0.9939 - val_loss: 1.3635 - val_accuracy: 0.7891 - val_precision: 0.5806 - val_recall: 0.5630 - val_auc: 0.8354
# Epoch 19/20
# 128/128 [==============================] - 28s 220ms/step - loss: 0.1152 - accuracy: 0.9787 - precision: 0.9592 - recall: 0.9552 - auc: 0.9968 - val_loss: 1.8155 - val_accuracy: 0.7835 - val_precision: 0.5686 - val_recall: 0.5552 - val_auc: 0.8141
# Epoch 20/20
# 128/128 [==============================] - 28s 219ms/step - loss: 0.1666 - accuracy: 0.9707 - precision: 0.9441 - recall: 0.9383 - auc: 0.9936 - val_loss: 1.6847 - val_accuracy: 0.7898 - val_precision: 0.5817 - val_recall: 0.5670 - val_auc: 0.8168

# %%
path = "Inception/loss_acc_1.png"
title = " MODEL'S METRICS VISUALIZATION : Transfer Learning "
Eval_Plot(
    Inception_history_1.history['accuracy'],Inception_history_1.history['val_accuracy'],
    Inception_history_1.history['loss'],Inception_history_1.history['val_loss'],
    Inception_history_1.history['auc'],Inception_history_1.history['val_auc'],
    Inception_history_1.history['precision'],Inception_history_1.history['val_precision'],
    path, title
)

# %% [markdown]
# ### InceptionV3 finetuning - Unfreeze base model and train entire model with low learning rate

# %%
isinstance(Inception_base.layers[1], BatchNormalization)
# Out:
# False

# %%
Inception_base.trainable = True
#freeze_BN(Inception_base)

# %%
epochs = 50
lr_reduce = ReduceLROnPlateau(monitor='val_auc', factor=0.6, patience=5, verbose=1, mode='max', min_lr=5e-5)

early_stopping_cb = EarlyStopping(
    monitor='val_auc', 
    patience=10, 
    restore_best_weights=True, 
    verbose=1, 
    mode="max"
    )

checkpoint_cb = ModelCheckpoint(
    f"{Save}Inception/Inception.h5", 
    monitor='val_auc',
    save_best_only=True, 
    verbose=1, 
    mode="max"
    )

Inception_Extention.compile(
    optimizer=keras.optimizers.RMSprop(0.001),  # Low learning rate
    loss='categorical_crossentropy',
    metrics=METRICS,
)

Inception_Extention.summary()

Inception_history_2 = Inception_Extention.fit(
    training_data, 
    epochs=epochs, 
    validation_data=validation_data, 
    verbose = 1, 
    steps_per_epoch=steps_per_epoch,
    callbacks = [lr_reduce, early_stopping_cb, checkpoint_cb])
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inception_v3 (Functional)   (None, 8, 8, 2048)        21802784
#
#  batch_normalization_95 (Bat  (None, 8, 8, 2048)       8192
#  chNormalization)
#
#  conv2d_96 (Conv2D)          (None, 8, 8, 1024)        18875392
#
#  conv2d_97 (Conv2D)          (None, 8, 8, 1024)        9438208
#
#  max_pooling2d_4 (MaxPooling  (None, 4, 4, 1024)       0
#  2D)
#
#  dropout (Dropout)           (None, 4, 4, 1024)        0
#
#  batch_normalization_96 (Bat  (None, 4, 4, 1024)       4096
#  chNormalization)
#
#  flatten (Flatten)           (None, 16384)             0
#
#  dense (Dense)               (None, 1024)              16778240
#
#  dense_1 (Dense)             (None, 4)                 4100
#
# =================================================================
# Total params: 66,911,012
# Trainable params: 66,870,436
# Non-trainable params: 40,576
# _________________________________________________________________
# Epoch 1/50
# 128/128 [==============================] - ETA: 0s - loss: 1.4816 - accuracy: 0.7710 - precision: 0.5614 - recall: 0.3844 - auc: 0.7869
# Epoch 1: val_auc improved from -inf to 0.42783, saving model to drive/MyDrive/Pammy_Alzheimers_Disease_Prediction/Visualisation/Inception/Inception.h5
# 128/128 [==============================] - 95s 619ms/step - loss: 1.4816 - accuracy: 0.7710 - precision: 0.5614 - recall: 0.3844 - auc: 0.7869 - val_loss: 224659.9375 - val_accuracy: 0.5709 - val_precision: 0.1417 - val_recall: 0.1417 - val_auc: 0.4278 - lr: 0.0010
# Epoch 2/50
# 128/128 [==============================] - ETA: 0s - loss: 1.1384 - accuracy: 0.7831 - precision: 0.6247 - recall: 0.3320 - auc: 0.8185
# Epoch 2: val_auc improved from 0.42783 to 0.66699, saving model to drive/MyDrive/Pammy_Alzheimers_Disease_Prediction/Visualisation/Inception/Inception.h5
# 128/128 [==============================] - 76s 586ms/step - loss: 1.1384 - accuracy: 0.7831 - precision: 0.6247 - recall: 0.3320 - auc: 0.8185 - val_loss: 57359.2109 - val_accuracy: 0.7502 - val_precision: 0.5005 - val_recall: 0.5005 - val_auc: 0.6670 - lr: 0.0010
# Epoch 3/50
# 128/128 [==============================] - ETA: 0s - loss: 0.9459 - accuracy: 0.7919 - precision: 0.6513 - recall: 0.3606 - auc: 0.8368
# Epoch 3: val_auc did not improve from 0.66699
# 128/128 [==============================] - 70s 549ms/step - loss: 0.9459 - accuracy: 0.7919 - precision: 0.6513 - recall: 0.3606 - auc: 0.8368 - val_loss: 10814.0469 - val_accuracy: 0.7502 - val_precision: 0.5005 - val_recall: 0.5005 - val_auc: 0.6670 - lr: 0.0010
# Epoch 4/50
# 128/128 [==============================] - ETA: 0s - loss: 0.8974 - accuracy: 0.7965 - precision: 0.6603 - recall: 0.3829 - auc: 0.8482
# Epoch 4: val_auc improved from 0.66699 to 0.70415, saving model to drive/MyDrive/Pammy_Alzheimers_Disease_Prediction/Visualisation/Inception/Inception.h5
# 128/128 [==============================] - 75s 583ms/step - loss: 0.8974 - accuracy: 0.7965 - precision: 0.6603 - recall: 0.3829 - auc: 0.8482 - val_loss: 1.2689 - val_accuracy: 0.7070 - val_precision: 0.3576 - val_recall: 0.2160 - val_auc: 0.7041 - lr: 0.0010
# Epoch 5/50
# 128/128 [==============================] - ETA: 0s - loss: 0.8886 - accuracy: 0.8060 - precision: 0.6661 - recall: 0.4493 - auc: 0.8636
# Epoch 5: val_auc improved from 0.70415 to 0.72211, saving model to drive/MyDrive/Pammy_Alzheimers_Disease_Prediction/Visualisation/Inception/Inception.h5
# 128/128 [==============================] - 76s 596ms/step - loss: 0.8886 - accuracy: 0.8060 - precision: 0.6661 - recall: 0.4493 - auc: 0.8636 - val_loss: 1.3177 - val_accuracy: 0.7576 - val_precision: 0.5742 - val_recall: 0.1173 - val_auc: 0.7221 - lr: 0.0010
# Epoch 6/50
# 128/128 [==============================] - ETA: 0s - loss: 0.7950 - accuracy: 0.8230 - precision: 0.6866 - recall: 0.5371 - auc: 0.8873
# Epoch 6: val_auc did not improve from 0.72211
# 128/128 [==============================] - 70s 550ms/step - loss: 0.7950 - accuracy: 0.8230 - precision: 0.6866 - recall: 0.5371 - auc: 0.8873 - val_loss: 8.1277 - val_accuracy: 0.6742 - val_precision: 0.3251 - val_recall: 0.2815 - val_auc: 0.6256 - lr: 0.0010
# Epoch 7/50
# 128/128 [==============================] - ETA: 0s - loss: 0.7032 - accuracy: 0.8502 - precision: 0.7307 - recall: 0.6348 - auc: 0.9123
# Epoch 7: val_auc improved from 0.72211 to 0.77848, saving model to drive/MyDrive/Pammy_Alzheimers_Disease_Prediction/Visualisation/Inception/Inception.h5
# 128/128 [==============================] - 75s 587ms/step - loss: 0.7032 - accuracy: 0.8502 - precision: 0.7307 - recall: 0.6348 - auc: 0.9123 - val_loss: 2.7383 - val_accuracy: 0.7674 - val_precision: 0.5365 - val_recall: 0.5103 - val_auc: 0.7785 - lr: 0.0010
# Epoch 8/50
# 128/128 [==============================] - ETA: 0s - loss: 0.6018 - accuracy: 0.8717 - precision: 0.7620 - recall: 0.7078 - auc: 0.9365
# Epoch 8: val_auc did not improve from 0.77848
# 128/128 [==============================] - 70s 549ms/step - loss: 0.6018 - accuracy: 0.8717 - precision: 0.7620 - recall: 0.7078 - auc: 0.9365 - val_loss: 1.3498 - val_accuracy: 0.6921 - val_precision: 0.3624 - val_recall: 0.3050 - val_auc: 0.7128 - lr: 0.0010
# Epoch 9/50
# 128/128 [==============================] - ETA: 0s - loss: 0.4727 - accuracy: 0.9096 - precision: 0.8284 - recall: 0.8052 - auc: 0.9604
# Epoch 9: val_auc did not improve from 0.77848
# 128/128 [==============================] - 70s 549ms/step - loss: 0.4727 - accuracy: 0.9096 - precision: 0.8284 - recall: 0.8052 - auc: 0.9604 - val_loss: 3.8171 - val_accuracy: 0.7649 - val_precision: 0.5305 - val_recall: 0.5181 - val_auc: 0.7438 - lr: 0.0010
# Epoch 10/50
# 128/128 [==============================] - ETA: 0s - loss: 0.4158 - accuracy: 0.9222 - precision: 0.8530 - recall: 0.8320 - auc: 0.9704
# Epoch 10: val_auc did not improve from 0.77848
# 128/128 [==============================] - 70s 549ms/step - loss: 0.4158 - accuracy: 0.9222 - precision: 0.8530 - recall: 0.8320 - auc: 0.9704 - val_loss: 36.9920 - val_accuracy: 0.7659 - val_precision: 0.5318 - val_recall: 0.5318 - val_auc: 0.7087 - lr: 0.0010
# Epoch 11/50
# 128/128 [==============================] - ETA: 0s - loss: 0.2983 - accuracy: 0.9482 - precision: 0.9006 - recall: 0.8910 - auc: 0.9831
# Epoch 11: val_auc did not improve from 0.77848
# 128/128 [==============================] - 70s 549ms/step - loss: 0.2983 - accuracy: 0.9482 - precision: 0.9006 - recall: 0.8910 - auc: 0.9831 - val_loss: 11.4703 - val_accuracy: 0.5855 - val_precision: 0.1632 - val_recall: 0.1593 - val_auc: 0.4173 - lr: 0.0010
# Epoch 12/50
# 128/128 [==============================] - ETA: 0s - loss: 0.2790 - accuracy: 0.9545 - precision: 0.9139 - recall: 0.9031 - auc: 0.9876
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0006000000284984708.
#
# Epoch 12: val_auc did not improve from 0.77848
# 128/128 [==============================] - 70s 549ms/step - loss: 0.2790 - accuracy: 0.9545 - precision: 0.9139 - recall: 0.9031 - auc: 0.9876 - val_loss: 1.7839 - val_accuracy: 0.7515 - val_precision: 0.5032 - val_recall: 0.4594 - val_auc: 0.7690 - lr: 0.0010
# Epoch 13/50
# 128/128 [==============================] - ETA: 0s - loss: 0.1431 - accuracy: 0.9768 - precision: 0.9546 - recall: 0.9525 - auc: 0.9947
# Epoch 13: val_auc improved from 0.77848 to 0.78636, saving model to drive/MyDrive/Pammy_Alzheimers_Disease_Prediction/Visualisation/Inception/Inception.h5
# 128/128 [==============================] - 75s 588ms/step - loss: 0.1431 - accuracy: 0.9768 - precision: 0.9546 - recall: 0.9525 - auc: 0.9947 - val_loss: 1.7254 - val_accuracy: 0.7634 - val_precision: 0.5283 - val_recall: 0.5015 - val_auc: 0.7864 - lr: 6.0000e-04
# Epoch 14/50
# 128/128 [==============================] - ETA: 0s - loss: 0.0998 - accuracy: 0.9839 - precision: 0.9685 - recall: 0.9670 - auc: 0.9967
# Epoch 14: val_auc did not improve from 0.78636
# 128/128 [==============================] - 70s 549ms/step - loss: 0.0998 - accuracy: 0.9839 - precision: 0.9685 - recall: 0.9670 - auc: 0.9967 - val_loss: 42.4667 - val_accuracy: 0.7358 - val_precision: 0.4716 - val_recall: 0.4702 - val_auc: 0.6755 - lr: 6.0000e-04
# Epoch 15/50
# 128/128 [==============================] - ETA: 0s - loss: 0.0974 - accuracy: 0.9851 - precision: 0.9705 - recall: 0.9697 - auc: 0.9967
# Epoch 15: val_auc improved from 0.78636 to 0.89968, saving model to drive/MyDrive/Pammy_Alzheimers_Disease_Prediction/Visualisation/Inception/Inception.h5
# 128/128 [==============================] - 75s 589ms/step - loss: 0.0974 - accuracy: 0.9851 - precision: 0.9705 - recall: 0.9697 - auc: 0.9967 - val_loss: 3.7531 - val_accuracy: 0.8504 - val_precision: 0.7103 - val_recall: 0.6784 - val_auc: 0.8997 - lr: 6.0000e-04
# Epoch 16/50
# 128/128 [==============================] - ETA: 0s - loss: 0.0941 - accuracy: 0.9889 - precision: 0.9783 - recall: 0.9771 - auc: 0.9975
# Epoch 16: val_auc did not improve from 0.89968
# 128/128 [==============================] - 70s 549ms/step - loss: 0.0941 - accuracy: 0.9889 - precision: 0.9783 - recall: 0.9771 - auc: 0.9975 - val_loss: 200.5636 - val_accuracy: 0.6554 - val_precision: 0.3109 - val_recall: 0.3109 - val_auc: 0.5397 - lr: 6.0000e-04
# Epoch 17/50
# 128/128 [==============================] - ETA: 0s - loss: 0.0933 - accuracy: 0.9852 - precision: 0.9707 - recall: 0.9700 - auc: 0.9970
# Epoch 17: val_auc did not improve from 0.89968
# 128/128 [==============================] - 70s 549ms/step - loss: 0.0933 - accuracy: 0.9852 - precision: 0.9707 - recall: 0.9700 - auc: 0.9970 - val_loss: 6.5044 - val_accuracy: 0.7691 - val_precision: 0.5382 - val_recall: 0.5367 - val_auc: 0.7291 - lr: 6.0000e-04
# Epoch 18/50
# 128/128 [==============================] - ETA: 0s - loss: 0.0593 - accuracy: 0.9903 - precision: 0.9808 - recall: 0.9806 - auc: 0.9981
# Epoch 18: val_auc did not improve from 0.89968
# 128/128 [==============================] - 70s 549ms/step - loss: 0.0593 - accuracy: 0.9903 - precision: 0.9808 - recall: 0.9806 - auc: 0.9981 - val_loss: 1.9230 - val_accuracy: 0.8375 - val_precision: 0.6772 - val_recall: 0.6686 - val_auc: 0.8810 - lr: 6.0000e-04
# Epoch 19/50
# 128/128 [==============================] - ETA: 0s - loss: 0.1505 - accuracy: 0.9894 - precision: 0.9798 - recall: 0.9779 - auc: 0.9972
# Epoch 19: val_auc did not improve from 0.89968
# 128/128 [==============================] - 70s 549ms/step - loss: 0.1505 - accuracy: 0.9894 - precision: 0.9798 - recall: 0.9779 - auc: 0.9972 - val_loss: 2.3432 - val_accuracy: 0.8482 - val_precision: 0.6978 - val_recall: 0.6931 - val_auc: 0.8571 - lr: 6.0000e-04
# Epoch 20/50
# 128/128 [==============================] - ETA: 0s - loss: 0.0831 - accuracy: 0.9882 - precision: 0.9771 - recall: 0.9757 - auc: 0.9970
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0003600000170990825.
#
# Epoch 20: val_auc did not improve from 0.89968
# 128/128 [==============================] - 70s 549ms/step - loss: 0.0831 - accuracy: 0.9882 - precision: 0.9771 - recall: 0.9757 - auc: 0.9970 - val_loss: 1.1722 - val_accuracy: 0.8495 - val_precision: 0.7083 - val_recall: 0.6764 - val_auc: 0.8972 - lr: 6.0000e-04
# Epoch 21/50
# 128/128 [==============================] - ETA: 0s - loss: 0.0317 - accuracy: 0.9957 - precision: 0.9919 - recall: 0.9909 - auc: 0.9996
# Epoch 21: val_auc improved from 0.89968 to 0.90985, saving model to drive/MyDrive/Pammy_Alzheimers_Disease_Prediction/Visualisation/Inception/Inception.h5
# 128/128 [==============================] - 76s 595ms/step - loss: 0.0317 - accuracy: 0.9957 - precision: 0.9919 - recall: 0.9909 - auc: 0.9996 - val_loss: 1.3642 - val_accuracy: 0.8781 - val_precision: 0.7599 - val_recall: 0.7488 - val_auc: 0.9098 - lr: 3.6000e-04
# Epoch 22/50
# 128/128 [==============================] - ETA: 0s - loss: 0.0253 - accuracy: 0.9961 - precision: 0.9921 - recall: 0.9921 - auc: 0.9993
# Epoch 22: val_auc did not improve from 0.90985
# 128/128 [==============================] - 70s 549ms/step - loss: 0.0253 - accuracy: 0.9961 - precision: 0.9921 - recall: 0.9921 - auc: 0.9993 - val_loss: 2.5166 - val_accuracy: 0.8512 - val_precision: 0.7029 - val_recall: 0.7009 - val_auc: 0.8589 - lr: 3.6000e-04
# Epoch 23/50
# 128/128 [==============================] - ETA: 0s - loss: 0.0196 - accuracy: 0.9968 - precision: 0.9936 - recall: 0.9936 - auc: 0.9995
# Epoch 23: val_auc did not improve from 0.90985
# 128/128 [==============================] - 70s 548ms/step - loss: 0.0196 - accuracy: 0.9968 - precision: 0.9936 - recall: 0.9936 - auc: 0.9995 - val_loss: 2.4624 - val_accuracy: 0.8512 - val_precision: 0.7029 - val_recall: 0.7009 - val_auc: 0.8598 - lr: 3.6000e-04
# Epoch 24/50
# 128/128 [==============================] - ETA: 0s - loss: 0.0170 - accuracy: 0.9975 - precision: 0.9951 - recall: 0.9948 - auc: 0.9996
# Epoch 24: val_auc did not improve from 0.90985
# 128/128 [==============================] - 70s 549ms/step - loss: 0.0170 - accuracy: 0.9975 - precision: 0.9951 - recall: 0.9948 - auc: 0.9996 - val_loss: 1.5121 - val_accuracy: 0.8803 - val_precision: 0.7620 - val_recall: 0.7576 - val_auc: 0.9021 - lr: 3.6000e-04
# Epoch 25/50
# 128/128 [==============================] - ETA: 0s - loss: 0.0185 - accuracy: 0.9963 - precision: 0.9926 - recall: 0.9926 - auc: 0.9998
# Epoch 25: val_auc did not improve from 0.90985
# 128/128 [==============================] - 70s 548ms/step - loss: 0.0185 - accuracy: 0.9963 - precision: 0.9926 - recall: 0.9926 - auc: 0.9998 - val_loss: 3.0743 - val_accuracy: 0.8133 - val_precision: 0.6271 - val_recall: 0.6246 - val_auc: 0.8208 - lr: 3.6000e-04
# Epoch 26/50
# 128/128 [==============================] - ETA: 0s - loss: 0.0268 - accuracy: 0.9972 - precision: 0.9943 - recall: 0.9943 - auc: 0.9993
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.00021600000327453016.
#
# Epoch 26: val_auc did not improve from 0.90985
# 128/128 [==============================] - 70s 547ms/step - loss: 0.0268 - accuracy: 0.9972 - precision: 0.9943 - recall: 0.9943 - auc: 0.9993 - val_loss: 2.3138 - val_accuracy: 0.8717 - val_precision: 0.7441 - val_recall: 0.7419 - val_auc: 0.8760 - lr: 3.6000e-04
# Epoch 27/50
# 128/128 [==============================] - ETA: 0s - loss: 0.0199 - accuracy: 0.9979 - precision: 0.9958 - recall: 0.9958 - auc: 0.9995
# Epoch 27: val_auc did not improve from 0.90985
# 128/128 [==============================] - 70s 548ms/step - loss: 0.0199 - accuracy: 0.9979 - precision: 0.9958 - recall: 0.9958 - auc: 0.9995 - val_loss: 1.7266 - val_accuracy: 0.8832 - val_precision: 0.7664 - val_recall: 0.7664 - val_auc: 0.9014 - lr: 2.1600e-04
# Epoch 28/50
# 128/128 [==============================] - ETA: 0s - loss: 0.0078 - accuracy: 0.9989 - precision: 0.9978 - recall: 0.9978 - auc: 0.9998
# Epoch 28: val_auc did not improve from 0.90985
# 128/128 [==============================] - 70s 548ms/step - loss: 0.0078 - accuracy: 0.9989 - precision: 0.9978 - recall: 0.9978 - auc: 0.9998 - val_loss: 3.1800 - val_accuracy: 0.8644 - val_precision: 0.7290 - val_recall: 0.7283 - val_auc: 0.8590 - lr: 2.1600e-04
# Epoch 29/50
# 128/128 [==============================] - ETA: 0s - loss: 0.0017 - accuracy: 0.9998 - precision: 0.9995 - recall: 0.9995 - auc: 1.0000
# Epoch 29: val_auc improved from 0.90985 to 0.92663, saving model to drive/MyDrive/Pammy_Alzheimers_Disease_Prediction/Visualisation/Inception/Inception.h5
# 128/128 [==============================] - 78s 611ms/step - loss: 0.0017 - accuracy: 0.9998 - precision: 0.9995 - recall: 0.9995 - auc: 1.0000 - val_loss: 1.3292 - val_accuracy: 0.9132 - val_precision: 0.8268 - val_recall: 0.8260 - val_auc: 0.9266 - lr: 2.1600e-04
# Epoch 30/50
# 128/128 [==============================] - ETA: 0s - loss: 0.0071 - accuracy: 0.9990 - precision: 0.9980 - recall: 0.9980 - auc: 0.9998
# Epoch 30: val_auc did not improve from 0.92663
# 128/128 [==============================] - 70s 549ms/step - loss: 0.0071 - accuracy: 0.9990 - precision: 0.9980 - recall: 0.9980 - auc: 0.9998 - val_loss: 5.5983 - val_accuracy: 0.7994 - val_precision: 0.5988 - val_recall: 0.5982 - val_auc: 0.7666 - lr: 2.1600e-04
# Epoch 31/50
# 128/128 [==============================] - ETA: 0s - loss: 0.0072 - accuracy: 0.9994 - precision: 0.9988 - recall: 0.9988 - auc: 0.9998
# Epoch 31: val_auc did not improve from 0.92663
# 128/128 [==============================] - 70s 548ms/step - loss: 0.0072 - accuracy: 0.9994 - precision: 0.9988 - recall: 0.9988 - auc: 0.9998 - val_loss: 1.6616 - val_accuracy: 0.8974 - val_precision: 0.7947 - val_recall: 0.7947 - val_auc: 0.9057 - lr: 2.1600e-04
# Epoch 32/50
# 128/128 [==============================] - ETA: 0s - loss: 0.0088 - accuracy: 0.9989 - precision: 0.9978 - recall: 0.9978 - auc: 0.9998
# Epoch 32: val_auc did not improve from 0.92663
# 128/128 [==============================] - 70s 549ms/step - loss: 0.0088 - accuracy: 0.9989 - precision: 0.9978 - recall: 0.9978 - auc: 0.9998 - val_loss: 1.3286 - val_accuracy: 0.9157 - val_precision: 0.8317 - val_recall: 0.8309 - val_auc: 0.9224 - lr: 2.1600e-04
# Epoch 33/50
# 128/128 [==============================] - ETA: 0s - loss: 0.0022 - accuracy: 0.9994 - precision: 0.9988 - recall: 0.9988 - auc: 1.0000
# Epoch 33: val_auc did not improve from 0.92663
# 128/128 [==============================] - 70s 551ms/step - loss: 0.0022 - accuracy: 0.9994 - precision: 0.9988 - recall: 0.9988 - auc: 1.0000 - val_loss: 1.5827 - val_accuracy: 0.9128 - val_precision: 0.8265 - val_recall: 0.8240 - val_auc: 0.9209 - lr: 2.1600e-04
# Epoch 34/50
# 128/128 [==============================] - ETA: 0s - loss: 0.0100 - accuracy: 0.9996 - precision: 0.9993 - recall: 0.9993 - auc: 0.9998
# Epoch 34: ReduceLROnPlateau reducing learning rate to 0.00012960000021848827.
#
# Epoch 34: val_auc did not improve from 0.92663
# 128/128 [==============================] - 70s 547ms/step - loss: 0.0100 - accuracy: 0.9996 - precision: 0.9993 - recall: 0.9993 - auc: 0.9998 - val_loss: 2.1455 - val_accuracy: 0.8883 - val_precision: 0.7769 - val_recall: 0.7761 - val_auc: 0.8915 - lr: 2.1600e-04
# Epoch 35/50
# 128/128 [==============================] - ETA: 0s - loss: 0.0018 - accuracy: 0.9996 - precision: 0.9993 - recall: 0.9993 - auc: 1.0000
# Epoch 35: val_auc did not improve from 0.92663
# 128/128 [==============================] - 70s 549ms/step - loss: 0.0018 - accuracy: 0.9996 - precision: 0.9993 - recall: 0.9993 - auc: 1.0000 - val_loss: 1.9351 - val_accuracy: 0.9005 - val_precision: 0.8014 - val_recall: 0.8006 - val_auc: 0.9036 - lr: 1.2960e-04
# Epoch 36/50
# 128/128 [==============================] - ETA: 0s - loss: 0.0041 - accuracy: 0.9996 - precision: 0.9993 - recall: 0.9993 - auc: 0.9998
# Epoch 36: val_auc did not improve from 0.92663
# 128/128 [==============================] - 70s 548ms/step - loss: 0.0041 - accuracy: 0.9996 - precision: 0.9993 - recall: 0.9993 - auc: 0.9998 - val_loss: 3.1482 - val_accuracy: 0.8700 - val_precision: 0.7400 - val_recall: 0.7400 - val_auc: 0.8614 - lr: 1.2960e-04
# Epoch 37/50
# 128/128 [==============================] - ETA: 0s - loss: 0.0022 - accuracy: 0.9998 - precision: 0.9995 - recall: 0.9995 - auc: 1.0000
# Epoch 37: val_auc did not improve from 0.92663
# 128/128 [==============================] - 70s 547ms/step - loss: 0.0022 - accuracy: 0.9998 - precision: 0.9995 - recall: 0.9995 - auc: 1.0000 - val_loss: 2.4287 - val_accuracy: 0.8925 - val_precision: 0.7855 - val_recall: 0.7840 - val_auc: 0.8885 - lr: 1.2960e-04
# Epoch 38/50
# 128/128 [==============================] - ETA: 0s - loss: 0.0027 - accuracy: 0.9996 - precision: 0.9993 - recall: 0.9993 - auc: 0.9998
# Epoch 38: val_auc did not improve from 0.92663
# 128/128 [==============================] - 70s 548ms/step - loss: 0.0027 - accuracy: 0.9996 - precision: 0.9993 - recall: 0.9993 - auc: 0.9998 - val_loss: 2.0095 - val_accuracy: 0.9013 - val_precision: 0.8031 - val_recall: 0.8016 - val_auc: 0.9023 - lr: 1.2960e-04
# Epoch 39/50
# 128/128 [==============================] - ETA: 0s - loss: 5.0367e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000
# Epoch 39: ReduceLROnPlateau reducing learning rate to 7.775999838486313e-05.
# Restoring model weights from the end of the best epoch: 29.
#
# Epoch 39: val_auc did not improve from 0.92663
# 128/128 [==============================] - 70s 550ms/step - loss: 5.0367e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 2.7515 - val_accuracy: 0.8903 - val_precision: 0.7808 - val_recall: 0.7801 - val_auc: 0.8828 - lr: 1.2960e-04
# Epoch 39: early stopping

# %% [markdown]
# ### Scores

# %%
scores_Inception = Inception_Extention.evaluate(testing_data)
# Out:
# 40/40 [==============================] - 597s 15s/step - loss: 2.6338 - accuracy: 0.8675 - precision: 0.7353 - recall: 0.7342 - auc: 0.8671

# %%
print(f"Accuracy in test set  : {scores_Inception[1]}")
print(f"Precision in test set : {scores_Inception[2]}")
print(f"Recall in test set    : {scores_Inception[3]}")
print(f"AUC in test set       : {scores_Inception[4]}")
# Out:
# Accuracy in test set  : 0.8674746155738831
# Precision in test set : 0.7353171706199646
# Recall in test set    : 0.7341673374176025
# AUC in test set       : 0.8671102523803711

# %%
import pandas as pd
Scores = pd.DataFrame([scores_Inception], columns = ["Loss", "Test Accuracy", "Precision", "Recall", "AUC"])
Scores
# Out:
#        Loss  Test Accuracy  Precision    Recall      AUC
# 0  2.633832       0.867475   0.735317  0.734167  0.86711

# %%
Scores.to_csv(f"{Save}Inception/score.csv")

# %% [markdown]
# ### Plots

# %%
path = "Inception/loss_acc_2.png"
title = " MODEL'S METRICS VISUALIZATION : Fine Tuning "
Eval_Plot(
    Inception_history_2.history['accuracy'],Inception_history_2.history['val_accuracy'],
    Inception_history_2.history['loss'],Inception_history_2.history['val_loss'],
    Inception_history_2.history['auc'],Inception_history_2.history['val_auc'],
    Inception_history_2.history['precision'],Inception_history_2.history['val_precision'],
    path, title
)

# %%
predictions = Inception_Extention.predict(testing_data) 
y_pred = predictions.argmax(axis = -1)
y_label = testing_data.labels.copy()
class_Names = list(testing_data.class_indices.keys())

# %%
assert y_pred.shape == y_label.shape

# %%
Confusion_Matrix_Heatmap(y_label, y_pred, class_Names, f"Inception/HeatMap.jpeg", "InceptionV3")

# %% [markdown]
# # GradCam, activation Visualisation

# %%
# Display
from IPython.display import Image, display
import matplotlib.pyplot as plt
import matplotlib.cm as cm

# %% [markdown]
# ## Configurable parameters

# %%
Inception_Extention.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inception_v3 (Functional)   (None, 8, 8, 2048)        21802784
#
#  batch_normalization_95 (Bat  (None, 8, 8, 2048)       8192
#  chNormalization)
#
#  conv2d_96 (Conv2D)          (None, 8, 8, 1024)        18875392
#
#  conv2d_97 (Conv2D)          (None, 8, 8, 1024)        9438208
#
#  max_pooling2d_4 (MaxPooling  (None, 4, 4, 1024)       0
#  2D)
#
#  dropout (Dropout)           (None, 4, 4, 1024)        0
#
#  batch_normalization_96 (Bat  (None, 4, 4, 1024)       4096
#  chNormalization)
#
#  flatten (Flatten)           (None, 16384)             0
#
#  dense (Dense)               (None, 1024)              16778240
#
#  dense_1 (Dense)             (None, 4)                 4100
#
# =================================================================
# Total params: 66,911,012
# Trainable params: 66,870,436
# Non-trainable params: 40,576
# _________________________________________________________________

# %%
last_conv_layer_name = "conv2d_97"
decode_predictions = keras.applications.inception_v3.decode_predictions
X,y = testing_data.next()

# %%
X[3].shape
# Out:
# (299, 299, 3)

# %%
img_path = X[0].copy()
imshow(X[3])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
def get_img_array(img_path, size):
    # `img` is a PIL image of size 299x299
    img = keras.preprocessing.image.load_img(img_path, target_size=size)
    # `array` is a float32 Numpy array of shape (299, 299, 3)
    array = keras.preprocessing.image.img_to_array(img)
    # We add a dimension to transform our image array into a "batch"
    # of size (1, 299, 299, 3)
    array = np.expand_dims(array, axis=0)
    return array


def make_gradcam_heatmap(img_array, model, last_conv_layer_name, pred_index=None):
    # First, we create a model that maps the input image to the activations
    # of the last conv layer as well as the output predictions
    grad_model = tf.keras.models.Model(
        [model.inputs], [model.get_layer(last_conv_layer_name).output, model.output]
    )

    # Then, we compute the gradient of the top predicted class for our input image
    # with respect to the activations of the last conv layer
    with tf.GradientTape() as tape:
        last_conv_layer_output, preds = grad_model(img_array)
        if pred_index is None:
            pred_index = tf.argmax(preds[0])
        class_channel = preds[:, pred_index]

    # This is the gradient of the output neuron (top predicted or chosen)
    # with regard to the output feature map of the last conv layer
    grads = tape.gradient(class_channel, last_conv_layer_output)

    # This is a vector where each entry is the mean intensity of the gradient
    # over a specific feature map channel
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))

    # We multiply each channel in the feature map array
    # by "how important this channel is" with regard to the top predicted class
    # then sum all the channels to obtain the heatmap class activation
    last_conv_layer_output = last_conv_layer_output[0]
    heatmap = last_conv_layer_output @ pooled_grads[..., tf.newaxis]
    heatmap = tf.squeeze(heatmap)

    # For visualization purpose, we will also normalize the heatmap between 0 & 1
    heatmap = tf.maximum(heatmap, 0) / tf.math.reduce_max(heatmap)
    return heatmap.numpy()

def get_gradcam_img(img_path, heatmap, cam_path="cam.jpg", alpha=0.4):
    # Load the original image
    img = keras.preprocessing.image.load_img(img_path)
    img = keras.preprocessing.image.img_to_array(img)

    # Rescale heatmap to a range 0-255
    heatmap = np.uint8(255 * heatmap)

    # Use jet colormap to colorize heatmap
    jet = cm.get_cmap("jet")

    # Use RGB values of the colormap
    jet_colors = jet(np.arange(256))[:, :3]
    jet_heatmap = jet_colors[heatmap]

    # Create an image with RGB colorized heatmap
    jet_heatmap = keras.preprocessing.image.array_to_img(jet_heatmap)
    jet_heatmap = jet_heatmap.resize((img.shape[1], img.shape[0]))
    jet_heatmap = keras.preprocessing.image.img_to_array(jet_heatmap)

    # Superimpose the heatmap on original image
    superimposed_img = jet_heatmap * alpha + img
    superimposed_img = keras.preprocessing.image.array_to_img(superimposed_img)

    return superimposed_img

# %%
# Make model
model_load= keras.models.load_model(f"{Save}Inception/Inception.h5")

# Remove last layer's softmax
model_load.layers[-1].activation = None

# %%
# Out:
# ['ModerateDemented', 'VeryMildDemented', 'NonDemented', 'MildDemented']

# %%
class_Names = os.listdir(f"{test}").copy()
img_paths = []
for cls in class_Names:
  ClsPath2dir = f"{test}{cls}/"
  content = os.listdir(ClsPath2dir)
  imgPath = os.path.join(ClsPath2dir, np.random.choice(content))
  img_paths.append(imgPath)

img_paths
# Out:
# ['drive/MyDrive/Pammy_Alzheimers_Disease_Prediction/Dataset/Alzheimers_Dataset/test/ModerateDemented/32 (2).jpg',
#  'drive/MyDrive/Pammy_Alzheimers_Disease_Prediction/Dataset/Alzheimers_Dataset/test/VeryMildDemented/31 (54).jpg',
#  'drive/MyDrive/Pammy_Alzheimers_Disease_Prediction/Dataset/Alzheimers_Dataset/test/NonDemented/27 (60).jpg',
#  'drive/MyDrive/Pammy_Alzheimers_Disease_Prediction/Dataset/Alzheimers_Dataset/test/MildDemented/29 (8).jpg']

# %%
fig, axs = plt.subplots(2, 2, figsize = (15,15))
for ax, path, label in zip(axs.flatten(), img_paths, class_Names): 
  # Prepare image
  img_arry = keras.applications.inception_v3.preprocess_input(get_img_array(path, (Image_Size, Image_Size)))
  # Print what the top predicted class is
  preds = model_load.predict(img_arry)
  print(f"Predicted : {Ind2ClassName[int(preds.argmax(axis=-1).squeeze())]}")
  #print("Predicted:", decode_predictions(preds, top=1)[0])

  # Generate class activation heatmap
  heatmap = make_gradcam_heatmap(img_arry, model_load, last_conv_layer_name)

  # Get superImposed Image
  superimposed_img = get_gradcam_img(path, heatmap)
  ax.imshow(superimposed_img)
  ax.axis('off')
  ax.title.set_text(f"Predicted label : {Ind2ClassName[int(preds.argmax(axis=-1).squeeze())]} Actual : {label}")

plt.suptitle('Grad Cam Visualisation')
plt.savefig(f"{Save}Inception/GradCam.jpg")
plt.show()
# Out:
# Predicted : MildDemented
# Predicted : VeryMildDemented
# Predicted : NonDemented
# Predicted : MildDemented
