# %% [markdown]
# # Global PAth vars

# %%
#PATH 
base_path = "drive/MyDrive/Pammy_Alzheimers_Disease_Prediction/Dataset/Alzheimers_Dataset/"
train = f"{base_path}train/"
test = f"{base_path}test/"
Save = f"drive/MyDrive/Pammy_Alzheimers_Disease_Prediction/Visualisation/"


base_path_bin = "drive/MyDrive/Pammy_Alzheimers_Disease_Prediction/Dataset/Alzheimers_Dataset_Binary/"
train_bin = f"{base_path_bin}train/" 
test_bin = f"{base_path_bin}test/"
Save_bin = f"drive/MyDrive/Pammy_Alzheimers_Disease_Prediction/Visualisation/BinaryClassification/"

# %% [markdown]
# # Imports

# %%
import os, time

#arr operations
import numpy as np

# Progress Bar
from tqdm import tqdm

# Evaluation metrics
from sklearn import metrics
from sklearn.metrics import confusion_matrix, classification_report

#Importing Deep learning Libraries
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential, load_model
from keras.layers import InputLayer, BatchNormalization, Dropout, Flatten, Dense, Activation, MaxPool2D
from keras.layers import GlobalAveragePooling2D, Conv2D, MaxPooling2D
from keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler, Callback, ReduceLROnPlateau
from keras import optimizers, Input
from keras.utils.vis_utils import plot_model
from keras.applications.imagenet_utils import decode_predictions
import keras.backend as K


#Pretrained models
from keras.applications.xception import Xception
from keras.applications.inception_v3 import InceptionV3
from keras.applications.vgg16 import VGG16
from keras.applications.vgg19 import VGG19
from keras.applications.resnet import ResNet50
from keras.applications.resnet_v2 import ResNet152V2
#from keras.applications.resnet152_v2 import ResNet152V2


#Image read and show
import skimage.io
from skimage.io import imread, imshow
import matplotlib.pyplot as plt 
import seaborn as sns
sns.set_style('darkgrid')
#plt.style.use('fivethirtyeight')

#Metrics
from sklearn.metrics import f1_score , recall_score, accuracy_score, precision_score, confusion_matrix
from sklearn.metrics import roc_curve, auc, classification_report
from sklearn.preprocessing import label_binarize
from sklearn.multiclass import OneVsRestClassifier
from itertools import cycle

# %%
tf.__version__
# Out:
# '2.8.2'

# %% [markdown]
# # Utils Functions

# %%
def Confusion_Matrix_Heatmap(y_test,y_pred,class_Names, fName, ModelName):
    #Plot the confusion matrix to understand the classification in detail
    CM = confusion_matrix(y_test, y_pred)
    plt.figure(figsize=(10, 8), dpi=80, facecolor='w', edgecolor='k')
    ax = sns.heatmap(CM, cmap='Greens', annot=True, fmt='d', xticklabels=class_Names, yticklabels=class_Names)
    plt.title(f'Alzheimer\'s Disease Diagnosis - {ModelName}')
    plt.xlabel('Prediction')
    plt.ylabel('Truth')
    plt.savefig(f"{Save}{fName}")
    #plt.show(ax)

# Plot Evaluation Metrics
sns.set_style('darkgrid')
#plt.style.use('fivethirtyeight')
def Eval_Plot(acc,val_acc, loss,val_loss, auc, val_auc, precision, val_precision, path, title):
    
    fig, (ax1,ax2,ax3,ax4) = plt.subplots(1,4, figsize= (20,5))
    fig.suptitle(f"{title}\n", fontsize = 15)

    ax1.plot(range(1, len(acc) + 1), acc)
    ax1.plot(range(1, len(val_acc) + 1), val_acc)
    ax1.set_title('History of Accuracy', fontsize = 15)
    ax1.set_xlabel('Epochs', fontsize = 15)
    ax1.set_ylabel('Accuracy', fontsize = 15)
    ax1.legend(['Training', 'Validation'], fontsize = 15)


    ax2.plot(range(1, len(loss) + 1), loss)
    ax2.plot(range(1, len(val_loss) + 1), val_loss)
    ax2.set_title('History of Loss', fontsize = 15)
    ax2.set_xlabel('Epochs', fontsize = 15)
    ax2.set_ylabel('Loss', fontsize = 15)
    ax2.legend(['Training', 'Validation'], fontsize = 15)

    ax3.plot(range(1, len(auc) + 1), auc)
    ax3.plot(range(1, len(val_auc) + 1), val_auc)
    ax3.set_title('History of AUC', fontsize = 15)
    ax3.set_xlabel('Epochs', fontsize = 15)
    ax3.set_ylabel('AUC', fontsize = 15)
    ax3.legend(['Training', 'Validation'], fontsize = 15)
    
    ax4.plot(range(1, len(precision) + 1), precision)
    ax4.plot(range(1, len(val_precision) + 1), val_precision)
    ax4.set_title('History of Precision', fontsize = 15)
    ax4.set_xlabel('Epochs', fontsize = 15)
    ax4.set_ylabel('Precision', fontsize = 15)
    ax4.legend(['Training', 'Validation'], fontsize = 15)

    plt.savefig(f"{Save}{path}")
    #plt.show()

def freeze_BN(model):
  """
  Unfreeze all layers except BatchNorm
  """
  for layer in model.layers:
    if isinstance(layer, BatchNormalization):
      layer.trainable = False

# %% [markdown]
# # Model Building

# %% [markdown]
# ## Set Seed

# %%
Seed = 29
Batch_Size = 32
Image_Size = 224
np.random.seed(Seed)
tf.random.set_seed(Seed)

# %% [markdown]
# ## GPU Test

# %%
# GPU
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %% [markdown]
# # MULTICLASS CLASSIFICATION MODELS

# %% [markdown]
# ## Data Generator

# %%
# Image data generator
training_data_gen = ImageDataGenerator(
    validation_split = 0.2,
    preprocessing_function=keras.applications.vgg16.preprocess_input,           
    )

testing_data_gen = ImageDataGenerator(        
    preprocessing_function=keras.applications.vgg16.preprocess_input,           
    )

validation_data_gen = ImageDataGenerator(
    preprocessing_function=keras.applications.vgg16.preprocess_input,
    validation_split = 0.2
    )

# %% [markdown]
# ## Splitting the Data

# %%
training_data = training_data_gen.flow_from_directory(
    directory= train,
    target_size = (Image_Size,Image_Size),
    class_mode = 'categorical',
    color_mode  = 'rgb', 
    subset = 'training',
    seed = Seed,
    batch_size = Batch_Size)

validation_data = validation_data_gen.flow_from_directory(
  directory = train,
  target_size = (Image_Size,Image_Size),
  class_mode = 'categorical',
  color_mode  = 'rgb', 
  subset = 'validation',
  seed = Seed,
  batch_size = Batch_Size)

testing_data =  testing_data_gen.flow_from_directory(
  directory = test,
  target_size = (Image_Size,Image_Size),
  class_mode = 'categorical',
  color_mode  = 'rgb', 
  seed = Seed,
  batch_size = Batch_Size
)
# Out:
# Found 4098 images belonging to 4 classes.
# Found 1023 images belonging to 4 classes.
# Found 1279 images belonging to 4 classes.

# %%
ClassName2Ind = (training_data.class_indices)
Ind2ClassName = {v: k for k, v in ClassName2Ind.items()}
X,y = training_data.next()

# %%
imshow(X[0])
plt.title(Ind2ClassName[np.argmax(y[0],axis=0)])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Text(0.5, 1.0, 'NonDemented')

# %%
steps_per_epoch = training_data.n // training_data.batch_size
print('steps per epoch: ',steps_per_epoch)
# Out:
# steps per epoch:  128

# %%
assert len(training_data) > 5, "Less Than 5 Batches"
assert len(validation_data) > 5, "Less Than 5 Batches"
assert len(testing_data) > 5, "Less Than 5 Batches"

# %%
print(f"Train shape : {X.shape} y shape {y.shape}")
# Out:
# Train shape : (32, 224, 224, 3) y shape (32, 4)

# %% [markdown]
# ## VGG16

# %%
VGG16_base = VGG16(
    include_top=False,
    weights="imagenet",
    input_shape=(Image_Size,Image_Size,3),
)

VGG16_base.trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 0s 0us/step
# 58900480/58889256 [==============================] - 0s 0us/step

# %%
for layer in VGG16_base.layers:
    layer.trainable=False

# %%
# Building Top
VGG16_Top=Sequential()
VGG16_Top.add(VGG16_base)
VGG16_Top.add(BatchNormalization())
VGG16_Top.add(Conv2D(1024,3,padding='same',activation='relu'))
VGG16_Top.add(Conv2D(1024,3,padding='same',activation='relu'))
VGG16_Top.add(MaxPooling2D())
VGG16_Top.add(Dropout(0.60))
VGG16_Top.add(BatchNormalization())
VGG16_Top.add(Flatten())
VGG16_Top.add(Dense(1024,activation='relu'))
VGG16_Top.add(Dense(4,activation='softmax'))

# %%
VGG16_Top.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  batch_normalization (BatchN  (None, 7, 7, 512)        2048
#  ormalization)
#
#  conv2d (Conv2D)             (None, 7, 7, 1024)        4719616
#
#  conv2d_1 (Conv2D)           (None, 7, 7, 1024)        9438208
#
#  max_pooling2d (MaxPooling2D  (None, 3, 3, 1024)       0
#  )
#
#  dropout (Dropout)           (None, 3, 3, 1024)        0
#
#  batch_normalization_1 (Batc  (None, 3, 3, 1024)       4096
#  hNormalization)
#
#  flatten (Flatten)           (None, 9216)              0
#
#  dense (Dense)               (None, 1024)              9438208
#
#  dense_1 (Dense)             (None, 4)                 4100
#
# =================================================================
# Total params: 38,320,964
# Trainable params: 23,603,204
# Non-trainable params: 14,717,760
# _________________________________________________________________

# %%
plot_model(
    VGG16_Top,
    to_file=f"{Save}VGG16/Architecture.png",
    show_shapes=False,
    show_dtype=False,
    show_layer_names=True,
    rankdir="TB",
    expand_nested=False,
    dpi=96,
    layer_range=None,
    show_layer_activations=False,
)

# %% [markdown]
# ### VGG16 Transfer Learning - Freeze base model

# %%
METRICS = [
      keras.metrics.BinaryAccuracy(name='accuracy'),
      keras.metrics.Precision(name='precision'),
      keras.metrics.Recall(name='recall'),  
      keras.metrics.AUC(name='auc')
]

VGG16_Top.compile(
    optimizer=keras.optimizers.Adam(0.001), 
    loss='categorical_crossentropy',
    metrics=METRICS,
)

epochs = 20
VGG16_history_1 = VGG16_Top.fit(
    training_data, 
    epochs=epochs, 
    validation_data=validation_data,
    steps_per_epoch=steps_per_epoch,
    verbose = 1,
    )
# Out:
# Epoch 1/20
# 128/128 [==============================] - 1266s 10s/step - loss: 1.2618 - accuracy: 0.7764 - precision: 0.5811 - recall: 0.3780 - auc: 0.8021 - val_loss: 1.0986 - val_accuracy: 0.7537 - val_precision: 0.5091 - val_recall: 0.4106 - val_auc: 0.8017
# Epoch 2/20
# 128/128 [==============================] - 15s 116ms/step - loss: 0.7885 - accuracy: 0.8308 - precision: 0.7087 - recall: 0.5487 - auc: 0.8882 - val_loss: 1.1512 - val_accuracy: 0.7598 - val_precision: 0.5257 - val_recall: 0.3998 - val_auc: 0.7820
# Epoch 3/20
# 128/128 [==============================] - 15s 115ms/step - loss: 0.6057 - accuracy: 0.8779 - precision: 0.7816 - recall: 0.7102 - auc: 0.9354 - val_loss: 1.3590 - val_accuracy: 0.6997 - val_precision: 0.3744 - val_recall: 0.3001 - val_auc: 0.7164
# Epoch 4/20
# 128/128 [==============================] - 15s 116ms/step - loss: 0.4065 - accuracy: 0.9220 - precision: 0.8574 - recall: 0.8251 - auc: 0.9699 - val_loss: 1.3659 - val_accuracy: 0.7735 - val_precision: 0.5506 - val_recall: 0.5103 - val_auc: 0.8207
# Epoch 5/20
# 128/128 [==============================] - 15s 117ms/step - loss: 0.2632 - accuracy: 0.9511 - precision: 0.9071 - recall: 0.8960 - auc: 0.9867 - val_loss: 1.4676 - val_accuracy: 0.7818 - val_precision: 0.5673 - val_recall: 0.5357 - val_auc: 0.8343
# Epoch 6/20
# 128/128 [==============================] - 15s 116ms/step - loss: 0.1848 - accuracy: 0.9677 - precision: 0.9401 - recall: 0.9299 - auc: 0.9926 - val_loss: 1.5622 - val_accuracy: 0.7774 - val_precision: 0.5579 - val_recall: 0.5279 - val_auc: 0.8184
# Epoch 7/20
# 128/128 [==============================] - 15s 117ms/step - loss: 0.1360 - accuracy: 0.9752 - precision: 0.9530 - recall: 0.9474 - auc: 0.9959 - val_loss: 1.8407 - val_accuracy: 0.7979 - val_precision: 0.5980 - val_recall: 0.5846 - val_auc: 0.8279
# Epoch 8/20
# 128/128 [==============================] - 15s 116ms/step - loss: 0.0978 - accuracy: 0.9838 - precision: 0.9694 - recall: 0.9658 - auc: 0.9978 - val_loss: 1.7023 - val_accuracy: 0.8094 - val_precision: 0.6221 - val_recall: 0.6051 - val_auc: 0.8457
# Epoch 9/20
# 128/128 [==============================] - 15s 116ms/step - loss: 0.1337 - accuracy: 0.9771 - precision: 0.9567 - recall: 0.9513 - auc: 0.9961 - val_loss: 1.7684 - val_accuracy: 0.8006 - val_precision: 0.6040 - val_recall: 0.5875 - val_auc: 0.8409
# Epoch 10/20
# 128/128 [==============================] - 15s 116ms/step - loss: 0.0770 - accuracy: 0.9866 - precision: 0.9739 - recall: 0.9725 - auc: 0.9983 - val_loss: 1.8429 - val_accuracy: 0.8072 - val_precision: 0.6165 - val_recall: 0.6051 - val_auc: 0.8431
    VGG16_history_1.history['loss'],VGG16_history_1.history['val_loss'],
    VGG16_history_1.history['auc'],VGG16_history_1.history['val_auc'],
    VGG16_history_1.history['precision'],VGG16_history_1.history['val_precision'],
    path, title
)

# %% [markdown]
# ### VGG16 finetuning - Unfreeze base model and train entire model with low learning rate

# %%
isinstance(VGG16_base.layers[1], BatchNormalization)
# Out:
# False

# %%
VGG16_base.trainable = True
#freeze_BN(VGG16_base)

# %%
epochs = 50
lr_reduce = ReduceLROnPlateau(monitor='val_auc', factor=0.6, patience=5, verbose=1, mode='max', min_lr=5e-5)

early_stopping_cb = EarlyStopping(
    monitor='val_auc', 
    patience=10, 
    restore_best_weights=True, 
    verbose=1, 
    mode="max"
    )

checkpoint_cb = ModelCheckpoint(
    f"{Save}VGG16/VGG16.h5", 
    monitor='val_auc',
    save_best_only=True, 
    verbose=1, 
    mode="max"
    )

VGG16_Top.compile(
    optimizer=keras.optimizers.RMSprop(0.001),  # Low learning rate
    loss='categorical_crossentropy',
    metrics=METRICS,
)

VGG16_Top.summary()

VGG16_history_2 = VGG16_Top.fit(
    training_data, 
    epochs=epochs, 
    validation_data=validation_data, 
    verbose = 1, 
    steps_per_epoch=steps_per_epoch,
    callbacks = [lr_reduce, early_stopping_cb, checkpoint_cb])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  batch_normalization (BatchN  (None, 7, 7, 512)        2048
#  ormalization)
#
#  conv2d (Conv2D)             (None, 7, 7, 1024)        4719616
#
#  conv2d_1 (Conv2D)           (None, 7, 7, 1024)        9438208
#
#  max_pooling2d (MaxPooling2D  (None, 3, 3, 1024)       0
#  )
#
#  dropout (Dropout)           (None, 3, 3, 1024)        0
#
#  batch_normalization_1 (Batc  (None, 3, 3, 1024)       4096
#  hNormalization)
#
#  flatten (Flatten)           (None, 9216)              0
#
#  dense (Dense)               (None, 1024)              9438208
#
#  dense_1 (Dense)             (None, 4)                 4100
#
# =================================================================
# Total params: 38,320,964
# Trainable params: 38,317,892
# Non-trainable params: 3,072
# _________________________________________________________________
# Epoch 1/50
# 128/128 [==============================] - ETA: 0s - loss: 1.1950 - accuracy: 0.7782 - precision: 0.5883 - recall: 0.3759 - auc: 0.7994
# Epoch 1: val_auc improved from -inf to 0.42652, saving model to drive/MyDrive/Pammy_Alzheimers_Disease_Prediction/Visualisation/VGG16/VGG16.h5
# 128/128 [==============================] - 38s 272ms/step - loss: 1.1950 - accuracy: 0.7782 - precision: 0.5883 - recall: 0.3759 - auc: 0.7994 - val_loss: 804.0751 - val_accuracy: 0.5699 - val_precision: 0.1398 - val_recall: 0.1398 - val_auc: 0.4265 - lr: 0.0010
# Epoch 2/50
# 128/128 [==============================] - ETA: 0s - loss: 0.9556 - accuracy: 0.7907 - precision: 0.6566 - recall: 0.3414 - auc: 0.8286
# Epoch 2: val_auc did not improve from 0.42652
# 128/128 [==============================] - 33s 258ms/step - loss: 0.9556 - accuracy: 0.7907 - precision: 0.6566 - recall: 0.3414 - auc: 0.8286 - val_loss: 34.3097 - val_accuracy: 0.5699 - val_precision: 0.1398 - val_recall: 0.1398 - val_auc: 0.4265 - lr: 0.0010
# Epoch 3/50
# 128/128 [==============================] - ETA: 0s - loss: 0.9207 - accuracy: 0.7940 - precision: 0.6651 - recall: 0.3542 - auc: 0.8376
# Epoch 3: val_auc improved from 0.42652 to 0.75393, saving model to drive/MyDrive/Pammy_Alzheimers_Disease_Prediction/Visualisation
saving model to drive/MyDrive/Pammy_Alzheimers_Disease_Prediction/Visualisation/VGG16/VGG16.h5
# 128/128 [==============================] - 35s 277ms/step - loss: 0.5094 - accuracy: 0.8882 - precision: 0.7953 - recall: 0.7442 - auc: 0.9520 - val_loss: 1.4988 - val_accuracy: 0.7889 - val_precision: 0.5812 - val_recall: 0.5562 - val_auc: 0.8347 - lr: 6.0000e-04
# Epoch 17/50
# 128/128 [==============================] - ETA: 0s - loss: 0.4650 - accuracy: 0.8992 - precision: 0.8103 - recall: 0.7794 - auc: 0.9595
# Epoch 17: val_auc did not improve from 0.83472
# 128/128 [==============================] - 33s 257ms/step - loss: 0.4650 - accuracy: 0.8992 - precision: 0.8103 - recall: 0.7794 - auc: 0.9595 - val_loss: 1.1236 - val_accuracy: 0.7603 - val_precision: 0.5255 - val_recall: 0.4233 - val_auc: 0.8098 - lr: 6.0000e-04
# Epoch 18/50
# 128/128 [==============================] - ETA: 0s - loss: 0.4062 - accuracy: 0.9145 - precision: 0.8375 - recall: 0.8163 - auc: 0.9686
# Epoch 18: val_auc did not improve from 0.83472
# 128/128 [==============================] - 33s 259ms/step - loss: 0.4062 - accuracy: 0.9145 - precision: 0.8375 - recall: 0.8163 - auc: 0.9686 - val_loss: 1.8876 - val_accuracy: 0.7488 - val_precision: 0.4974 - val_recall: 0.4633 - val_auc: 0.7993 - lr: 6.0000e-04
# Epoch 19/50
# 128/128 [==============================] - ETA: 0s - loss: 0.3551 - accuracy: 0.9237 - precision: 0.8546 - recall: 0.8372 - auc: 0.9757
# Epoch 19: val_auc did not improve from 0.83472
# 128/128 [==============================] - 33s 258ms/step - loss: 0.3551 - accuracy: 0.9237 - precision: 0.8546 - recall: 0.8372 - auc: 0.9757 - val_loss: 5.7337 - val_accuracy: 0.6596 - val_precision: 0.3186 - val_recall: 0.3177 - val_auc: 0.6222 - lr: 6.0000e-04
# Epoch 20/50
# 128/128 [==============================] - ETA: 0s - loss: 0.3372 - accuracy: 0.9279 - precision: 0.8617 - recall: 0.8475 - auc: 0.9782
# Epoch 20: val_auc did not improve from 0.83472
# 128/128 [==============================] - 33s 257ms/step - loss: 0.3372 - accuracy: 0.9279 - precision: 0.8617 - recall: 0.8475 - auc: 0.9782 - val_loss: 18.5414 - val_accuracy: 0.7510 - val_precision: 0.5020 - val_recall: 0.5005 - val_auc: 0.6895 - lr: 6.0000e-04
# Epoch 21/50
# 128/128 [==============================] - ETA: 0s - loss: 0.3053 - accuracy: 0.9366 - precision: 0.8781 - recall: 0.8667 - auc: 0.9819
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0003600000170990825.
#
# Epoch 21: val_auc did not improve from 0.83472
# 128/128 [==============================] - 33s 258ms/step - loss: 0.3053 - accuracy: 0.9366 - precision: 0.8781 - recall: 0.8667 - auc: 0.9819 - val_loss: 3.9239 - val_accuracy: 0.7023 - val_precision: 0.4041 - val_recall: 0.4018 - val_auc: 0.6945 - lr: 6.0000e-04
# Epoch 22/50
# 128/128 [==============================] - ETA: 0s - loss: 0.2018 - accuracy: 0.9616 - precision: 0.9260 - recall: 0.9201 - auc: 0.9917
# Epoch 22: val_auc did not improve from 0.83472
# 128/128 [==============================] - 33s 257ms/step - loss: 0.2018 - accuracy: 0.9616 - precision: 0.9260 - recall: 0.9201 - auc: 0.9917 - val_loss: 13.6245 - val_accuracy: 0.7549 - val_precision: 0.5098 - val_recall: 0.5083 - val_auc: 0.7038 - lr: 3.6000e-04
# Epoch 23/50
# 128/128 [==============================] - ETA: 0s - loss: 0.1435 - accuracy: 0.9694 - precision: 0.9396 - recall: 0.9378 - auc: 0.9953
# Epoch 23: val_auc did not improve from 0.83472
# 128/128 [==============================] - 33s 257ms/step - loss: 0.1435 - accuracy: 0.9694 - precision: 0.9396 - recall: 0.9378 - auc: 0.9953 - val_loss: 39.9732 - val_accuracy: 0.6525 - val_precision: 0.3050 - val_recall: 0.3050 - val_auc: 0.5481 - lr: 3.6000e-04
# Epoch 24/50
# 128/128 [==============================] - ETA: 0s - loss: 0.1421 - accuracy: 0.9735 - precision: 0.9480 - recall: 0.9459 - auc: 0.9953
# Epoch 24: val_auc did not improve from 0.83472
# 128/128 [==============================] - 33s 257ms/step - loss: 0.1421 - accuracy: 0.9735 - precision: 0.9480 - recall: 0.9459 - auc: 0.9953 - val_loss: 7.3417 - val_accuracy: 0.7700 - val_precision: 0.5403 - val_recall: 0.5376 - val_auc: 0.7558 - lr: 3.6000e-04
# Epoch 25/50
# 128/128 [==============================] - ETA: 0s - loss: 0.1351 - accuracy: 0.9744 - precision: 0.9495 - recall: 0.9479 - auc: 0.9950
# Epoch 25: val_auc did not improve from 0.83472
# 128/128 [==============================] - 33s 258ms/step - loss: 0.1351 - accuracy: 0.9744 - precision: 0.9495 - recall: 0.9479 - auc: 0.9950 - val_loss: 9.2939 - val_accuracy: 0.6725 - val_precision: 0.3451 - val_recall: 0.3451 - val_auc: 0.6037 - lr: 3.6000e-04
# Epoch 26/50
# 128/128 [==============================] - ETA: 0s - loss: 0.1192 - accuracy: 0.9785 - precision: 0.9581 - recall: 0.9560 - auc: 0.9964
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.00021600000327453016.
# Restoring model weights from the end of the best epoch: 16.
#
# Epoch 26: val_auc did not improve from 0.83472
# 128/128 [==============================] - 33s 258ms/step - loss: 0.1192 - accuracy: 0.9785 - precision: 0.9581 - recall: 0.9560 - auc: 0.9964 - val_loss: 10.9218 - val_accuracy: 0.7566 - val_precision: 0.5132 - val_recall: 0.5122 - val_auc: 0.7035 - lr: 3.6000e-04
# Epoch 26: early stopping

# %% [markdown]
# ### Scores

# %%
scores_VGG16 = VGG16_Top.evaluate(testing_data)
# Out:
# 40/40 [==============================] - 161s 4s/step - loss: 1.3917 - accuracy: 0.8106 - precision: 0.6244 - recall: 0.6083 - auc: 0.8538

# %%
print(f"Accuracy in test set  : {scores_VGG16[1]}")
print(f"Precision in test set : {scores_VGG16[2]}")
print(f"Recall in test set    : {scores_VGG16[3]}")
print(f"AUC in test set       : {scores_VGG16[4]}")
# Out:
# Accuracy in test set  : 0.8105942010879517
# Precision in test set : 0.6243980526924133
# Recall in test set    : 0.6082877516746521
# AUC in test set       : 0.8537646532058716

# %%
import pandas as pd
Scores = pd.DataFrame([scores_VGG16], columns = ["Loss", "Test Accuracy", "Precision", "Recall", "AUC"])
Scores
# Out:
#        Loss  Test Accuracy  Precision    Recall       AUC
# 0  1.391695       0.810594   0.624398  0.608288  0.853765

# %%
Scores.to_csv(f"{Save}VGG16/score.csv")

# %% [markdown]
# ### Plots

# %%
path = "VGG16/loss_acc_2.png"
title = " MODEL'S METRICS VISUALIZATION : Fine Tuning "
Eval_Plot(
    VGG16_history_2.history['accuracy'],VGG16_history_2.history['val_accuracy'],
    VGG16_history_2.history['loss'],VGG16_history_2.history['val_loss'],
    VGG16_history_2.history['auc'],VGG16_history_2.history['val_auc'],
    VGG16_history_2.history['precision'],VGG16_history_2.history['val_precision'],
    path, title
)

# %%
predictions = VGG16_Top.predict(testing_data) 
y_pred = predictions.argmax(axis = -1)
y_label = testing_data.labels.copy()
class_Names = list(testing_data.class_indices.keys())

# %%
assert y_pred.shape == y_label.shape

# %%
Confusion_Matrix_Heatmap(y_label, y_pred, class_Names, f"VGG16/HeatMap.jpeg", "VGG16")

# %% [markdown]
# # GradCam, activation Visualisation

# %%
# Display
from IPython.display import Image, display
import matplotlib.pyplot as plt
import matplotlib.cm as cm

# %% [markdown]
# ## Configurable parameters

# %%
VGG16_Top.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  batch_normalization (BatchN  (None, 7, 7, 512)        2048
#  ormalization)
#
#  conv2d (Conv2D)             (None, 7, 7, 1024)        4719616
#
#  conv2d_1 (Conv2D)           (None, 7, 7, 1024)        9438208
#
#  max_pooling2d (MaxPooling2D  (None, 3, 3, 1024)       0
#  )
#
#  dropout (Dropout)           (None, 3, 3, 1024)        0
#
#  batch_normalization_1 (Batc  (None, 3, 3, 1024)       4096
#  hNormalization)
#
#  flatten (Flatten)           (None, 9216)              0
#
#  dense (Dense)               (None, 1024)              9438208
#
#  dense_1 (Dense)             (None, 4)                 4100
#
# =================================================================
# Total params: 38,320,964
# Trainable params: 38,317,892
# Non-trainable params: 3,072
# _________________________________________________________________

# %%
last_conv_layer_name = "conv2d_1"
decode_predictions = keras.applications.inception_v3.decode_predictions
X,y = testing_data.next()

# %%
X[3].shape
# Out:
# (224, 224, 3)

# %%
img_path = X[0].copy()
imshow(X[3])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
def get_img_array(img_path, size):
    # `img` is a PIL image of size 299x299
    img = keras.preprocessing.image.load_img(img_path, target_size=size)
    # `array` is a float32 Numpy array of shape (299, 299, 3)
    array = keras.preprocessing.image.img_to_array(img)
    # We add a dimension to transform our image array into a "batch"
    # of size (1, 299, 299, 3)
    array = np.expand_dims(array, axis=0)
    return array


def make_gradcam_heatmap(img_array, model, last_conv_layer_name, pred_index=None):
    # First, we create a model that maps the input image to the activations
    # of the last conv layer as well as the output predictions
    grad_model = tf.keras.models.Model(
        [model.inputs], [model.get_layer(last_conv_layer_name).output, model.output]
    )

    # Then, we compute the gradient of the top predicted class for our input image
    # with respect to the activations of the last conv layer
    with tf.GradientTape() as tape:
        last_conv_layer_output, preds = grad_model(img_array)
        if pred_index is None:
            pred_index = tf.argmax(preds[0])
        class_channel = preds[:, pred_index]

    # This is the gradient of the output neuron (top predicted or chosen)
    # with regard to the output feature map of the last conv layer
    grads = tape.gradient(class_channel, last_conv_layer_output)

    # This is a vector where each entry is the mean intensity of the gradient
    # over a specific feature map channel
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))

    # We multiply each channel in the feature map array
    # by "how important this channel is" with regard to the top predicted class
    # then sum all the channels to obtain the heatmap class activation
    last_conv_layer_output = last_conv_layer_output[0]
    heatmap = last_conv_layer_output @ pooled_grads[..., tf.newaxis]
    heatmap = tf.squeeze(heatmap)

    # For visualization purpose, we will also normalize the heatmap between 0 & 1
    heatmap = tf.maximum(heatmap, 0) / tf.math.reduce_max(heatmap)
    return heatmap.numpy()

def get_gradcam_img(img_path, heatmap, cam_path="cam.jpg", alpha=0.4):
    # Load the original image
    img = keras.preprocessing.image.load_img(img_path)
    img = keras.preprocessing.image.img_to_array(img)

    # Rescale heatmap to a range 0-255
    heatmap = np.uint8(255 * heatmap)

    # Use jet colormap to colorize heatmap
    jet = cm.get_cmap("jet")

    # Use RGB values of the colormap
    jet_colors = jet(np.arange(256))[:, :3]
    jet_heatmap = jet_colors[heatmap]

    # Create an image with RGB colorized heatmap
    jet_heatmap = keras.preprocessing.image.array_to_img(jet_heatmap)
    jet_heatmap = jet_heatmap.resize((img.shape[1], img.shape[0]))
    jet_heatmap = keras.preprocessing.image.img_to_array(jet_heatmap)

    # Superimpose the heatmap on original image
    superimposed_img = jet_heatmap * alpha + img
    superimposed_img = keras.preprocessing.image.array_to_img(superimposed_img)

    return superimposed_img

# %%
# Make model
model_load= keras.models.load_model(f"{Save}VGG16/VGG16.h5")

# Remove last layer's softmax
model_load.layers[-1].activation = None

# %%
class_Names = os.listdir(f"{test}").copy()
img_paths = []
for cls in class_Names:
  ClsPath2dir = f"{test}{cls}/"
  content = os.listdir(ClsPath2dir)
  imgPath = os.path.join(ClsPath2dir, np.random.choice(content))
  img_paths.append(imgPath)

img_paths
# Out:
# ['drive/MyDrive/Pammy_Alzheimers_Disease_Prediction/Dataset/Alzheimers_Dataset/test/ModerateDemented/31.jpg',
#  'drive/MyDrive/Pammy_Alzheimers_Disease_Prediction/Dataset/Alzheimers_Dataset/test/VeryMildDemented/27 (30).jpg',
#  'drive/MyDrive/Pammy_Alzheimers_Disease_Prediction/Dataset/Alzheimers_Dataset/test/NonDemented/32 (85).jpg',
#  'drive/MyDrive/Pammy_Alzheimers_Disease_Prediction/Dataset/Alzheimers_Dataset/test/MildDemented/32 (18).jpg']

# %%
fig, axs = plt.subplots(2, 2, figsize = (15,15))
for ax, path, label in zip(axs.flatten(), img_paths, class_Names): 
  # Prepare image
  img_arry = keras.applications.vgg16.preprocess_input(get_img_array(path, (Image_Size, Image_Size)))
  # Print what the top predicted class is
  preds = model_load.predict(img_arry)
  print(f"Predicted : {Ind2ClassName[int(preds.argmax(axis=-1).squeeze())]}")
  #print("Predicted:", decode_predictions(preds, top=1)[0])

  # Generate class activation heatmap
  heatmap = make_gradcam_heatmap(img_arry, model_load, last_conv_layer_name)

  # Get superImposed Image
  superimposed_img = get_gradcam_img(path, heatmap)
  ax.imshow(superimposed_img)
  ax.axis('off')
  ax.title.set_text(f"Predicted label : {Ind2ClassName[int(preds.argmax(axis=-1).squeeze())]} Actual : {label}")

plt.suptitle('Grad Cam Visualisation')
plt.savefig(f"{Save}VGG16/GradCam.jpg")
plt.show()
# Out:
# Predicted : VeryMildDemented
# Predicted : VeryMildDemented
# Predicted : NonDemented
# Predicted : NonDemented
