# %% [markdown]
# # Global PAth vars

# %%
#PATH
base_path = "drive/MyDrive/Pammy_Alzheimers_Disease_Prediction/Dataset/Alzheimers_Dataset/"
train = f"{base_path}train/"
test = f"{base_path}test/"
Save = f"drive/MyDrive/Pammy_Alzheimers_Disease_Prediction/Visualisation/"

base_path_bin = "drive/MyDrive/Pammy_Alzheimers_Disease_Prediction/Dataset/Alzheimers_Dataset_Binary/"
train_bin = f"{base_path_bin}train/"
test_bin = f"{base_path_bin}test/"
Save_bin = f"drive/MyDrive/Pammy_Alzheimers_Disease_Prediction/Visualisation/BinaryClassification/"

# %% [markdown]
# # Imports

# %%
import os, time

#arr operations
import numpy as np

# Progress Bar
from tqdm import tqdm

# Evaluation metrics
from sklearn import metrics
from sklearn.metrics import confusion_matrix, classification_report

#Importing Deep learning Libraries
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential, load_model
from keras.layers import InputLayer, BatchNormalization, Dropout, Flatten, Dense, Activation, MaxPool2D
from keras.layers import GlobalAveragePooling2D, Conv2D, MaxPooling2D
from keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler, Callback, ReduceLROnPlateau
from keras import optimizers, Input
from keras.utils.vis_utils import plot_model
from keras.applications.imagenet_utils import decode_predictions
import keras.backend as K


#Pretrained models
from keras.applications.xception import Xception
from keras.applications.inception_v3 import InceptionV3
from keras.applications.vgg16 import VGG16
from keras.applications.vgg19 import VGG19
from keras.applications.resnet import ResNet50
from keras.applications.resnet_v2 import ResNet152V2
#from keras.applications.resnet152_v2 import ResNet152V2


#Image read and show
import skimage.io
from skimage.io import imread, imshow
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')
#plt.style.use('fivethirtyeight')

#Metrics
from sklearn.metrics import f1_score , recall_score, accuracy_score, precision_score, confusion_matrix
from sklearn.metrics import roc_curve, auc, classification_report
from sklearn.preprocessing import label_binarize
from sklearn.multiclass import OneVsRestClassifier
from itertools import cycle

# %%
tf.__version__
# Out:
# '2.12.0'

# %% [markdown]
# # Utils Functions

# %%
def Confusion_Matrix_Heatmap(y_test,y_pred,class_Names, fName, ModelName):
    #Plot the confusion matrix to understand the classification in detail
    CM = confusion_matrix(y_test, y_pred)
    plt.figure(figsize=(10, 8), dpi=80, facecolor='w', edgecolor='k')
    ax = sns.heatmap(CM, cmap='Greens', annot=True, fmt='d', xticklabels=class_Names, yticklabels=class_Names)
    plt.title(f'Alzheimer\'s Disease Diagnosis - {ModelName}')
    plt.xlabel('Prediction')
    plt.ylabel('Truth')
    plt.savefig(f"{Save}{fName}")
    #plt.show(ax)

# Plot Evaluation Metrics
sns.set_style('darkgrid')
#plt.style.use('fivethirtyeight')
def Eval_Plot(acc,val_acc, loss,val_loss, auc, val_auc, precision, val_precision, path, title):

    fig, (ax1,ax2,ax3,ax4) = plt.subplots(1,4, figsize= (20,5))
    fig.suptitle(f"{title}\n", fontsize = 15)

    ax1.plot(range(1, len(acc) + 1), acc)
    ax1.plot(range(1, len(val_acc) + 1), val_acc)
    ax1.set_title('History of Accuracy', fontsize = 15)
    ax1.set_xlabel('Epochs', fontsize = 15)
    ax1.set_ylabel('Accuracy', fontsize = 15)
    ax1.legend(['Training', 'Validation'], fontsize = 15)


    ax2.plot(range(1, len(loss) + 1), loss)
    ax2.plot(range(1, len(val_loss) + 1), val_loss)
    ax2.set_title('History of Loss', fontsize = 15)
    ax2.set_xlabel('Epochs', fontsize = 15)
    ax2.set_ylabel('Loss', fontsize = 15)
    ax2.legend(['Training', 'Validation'], fontsize = 15)

    ax3.plot(range(1, len(auc) + 1), auc)
    ax3.plot(range(1, len(val_auc) + 1), val_auc)
    ax3.set_title('History of AUC', fontsize = 15)
    ax3.set_xlabel('Epochs', fontsize = 15)
    ax3.set_ylabel('AUC', fontsize = 15)
    ax3.legend(['Training', 'Validation'], fontsize = 15)

    ax4.plot(range(1, len(precision) + 1), precision)
    ax4.plot(range(1, len(val_precision) + 1), val_precision)
    ax4.set_title('History of Precision', fontsize = 15)
    ax4.set_xlabel('Epochs', fontsize = 15)
    ax4.set_ylabel('Precision', fontsize = 15)
    ax4.legend(['Training', 'Validation'], fontsize = 15)

    plt.savefig(f"{Save}{path}")
    #plt.show()

# %% [markdown]
# # Model Building

# %% [markdown]
# ## Set Seed

# %%
Seed = 29
Batch_Size = 32
Image_Size = 224
np.random.seed(Seed)
tf.random.set_seed(Seed)

# %% [markdown]
# ## GPU Test

# %%
# GPU
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %% [markdown]
# # MULTICLASS CLASSIFICATION MODELS

# %% [markdown]
# ## Data Generator

# %%
# Image data generator
training_data_gen = ImageDataGenerator(
    validation_split = 0.2,
    preprocessing_function=keras.applications.vgg19.preprocess_input,
    )

testing_data_gen = ImageDataGenerator(
    preprocessing_function=keras.applications.vgg19.preprocess_input,
    )

validation_data_gen = ImageDataGenerator(
    preprocessing_function=keras.applications.vgg19.preprocess_input,
    validation_split = 0.2
    )

# %% [markdown]
# ## Splitting the Data

# %%
training_data = training_data_gen.flow_from_directory(
    directory= train,
    target_size = (Image_Size,Image_Size),
    class_mode = 'categorical',
    color_mode  = 'rgb',
    subset = 'training',
    seed = Seed,
    batch_size = Batch_Size)

validation_data = validation_data_gen.flow_from_directory(
  directory = train,
  target_size = (Image_Size,Image_Size),
  class_mode = 'categorical',
  color_mode  = 'rgb',
  subset = 'validation',
  seed = Seed,
  batch_size = Batch_Size)

testing_data =  testing_data_gen.flow_from_directory(
  directory = test,
  target_size = (Image_Size,Image_Size),
  class_mode = 'categorical',
  color_mode  = 'rgb',
  seed = Seed,
  batch_size = Batch_Size
)
# Out:
# Found 4098 images belonging to 4 classes.
# Found 1023 images belonging to 4 classes.
# Found 1279 images belonging to 4 classes.

# %%
ClassName2Ind = (training_data.class_indices)
Ind2ClassName = {v: k for k, v in ClassName2Ind.items()}
X,y = training_data.next()

# %%
imshow(X[0])
plt.title(Ind2ClassName[np.argmax(y[0],axis=0)])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Text(0.5, 1.0, 'NonDemented')

# %%
steps_per_epoch = training_data.n // training_data.batch_size
print('steps per epoch: ',steps_per_epoch)
# Out:
# steps per epoch:  128

# %%
assert len(training_data) > 5, "Less Than 5 Batches"
assert len(validation_data) > 5, "Less Than 5 Batches"
assert len(testing_data) > 5, "Less Than 5 Batches"

# %%
print(f"Train shape : {X.shape} y shape {y.shape}")
# Out:
# Train shape : (32, 224, 224, 3) y shape (32, 4)

# %% [markdown]
# ## VGG19

# %%
K.clear_session()

# %%
VGG19_base = VGG19(
    include_top=False,
    weights="imagenet",
    input_shape=(Image_Size,Image_Size,3),
)

VGG19_base.trainable = False

# %%
for layer in VGG19_base.layers:
    layer.trainable=False

# %%
# Building Top
VGG19_Top=Sequential()
VGG19_Top.add(VGG19_base)
VGG19_Top.add(BatchNormalization())
VGG19_Top.add(Conv2D(1024,3,padding='same',activation='relu'))
VGG19_Top.add(Conv2D(1024,3,padding='same',activation='relu'))
VGG19_Top.add(MaxPooling2D())
VGG19_Top.add(Dropout(0.60))
VGG19_Top.add(BatchNormalization())
VGG19_Top.add(Flatten())
VGG19_Top.add(Dense(1024,activation='relu'))
VGG19_Top.add(Dense(4,activation='softmax'))

# %%
VGG19_Top.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg19 (Functional)          (None, 7, 7, 512)         20024384
#
#  batch_normalization (BatchN  (None, 7, 7, 512)        2048
#  ormalization)
#
#  conv2d (Conv2D)             (None, 7, 7, 1024)        4719616
#
#  conv2d_1 (Conv2D)           (None, 7, 7, 1024)        9438208
#
#  max_pooling2d (MaxPooling2D  (None, 3, 3, 1024)       0
#  )
#
#  dropout (Dropout)           (None, 3, 3, 1024)        0
#
#  batch_normalization_1 (Batc  (None, 3, 3, 1024)       4096
#  hNormalization)
#
#  flatten (Flatten)           (None, 9216)              0
#
#  dense (Dense)               (None, 1024)              9438208
#
#  dense_1 (Dense)             (None, 4)                 4100
#
# =================================================================
# Total params: 43,630,660
# Trainable params: 23,603,204
# Non-trainable params: 20,027,456
# _________________________________________________________________

# %%
plot_model(
    VGG19_Top,
    to_file=f"{Save}VGG19/Architecture.png",
    show_shapes=False,
    show_dtype=False,
    show_layer_names=True,
    rankdir="TB",
    expand_nested=False,
    dpi=96,
    layer_range=None,
    show_layer_activations=False,
)

# %% [markdown]
# ### VGG19 Transfer Learning - Freeze base model

# %%
#K.clear_session()
METRICS = [
      keras.metrics.BinaryAccuracy(name='accuracy'),
      keras.metrics.Precision(name='precision'),
      keras.metrics.Recall(name='recall'),
      keras.metrics.AUC(name='auc')
]

VGG19_Top.compile(
    optimizer=keras.optimizers.Adam(0.001),
    loss='categorical_crossentropy',
    metrics=METRICS,
)

epochs = 20
VGG19_history_1 = VGG19_Top.fit(
    training_data,
    epochs=epochs,
    validation_data=validation_data,
    steps_per_epoch=steps_per_epoch,
    verbose = 1,
    )
# Out:
# Epoch 1/20
# 128/128 [==============================] - 35s 217ms/step - loss: 1.1897 - accuracy: 0.7859 - precision: 0.6129 - recall: 0.3898 - auc: 0.8148 - val_loss: 1.3478 - val_accuracy: 0.7199 - val_precision: 0.4361 - val_recall: 0.4106 - val_auc: 0.7307
# Epoch 2/20
# 128/128 [==============================] - 18s 139ms/step - loss: 0.7666 - accuracy: 0.8297 - precision: 0.7020 - recall: 0.5539 - auc: 0.8919 - val_loss: 1.0921 - val_accuracy: 0.7632 - val_precision: 0.5394 - val_recall: 0.3617 - val_auc: 0.7891
# Epoch 3/20
# 128/128 [==============================] - 18s 138ms/step - loss: 0.6267 - accuracy: 0.8709 - precision: 0.7698 - recall: 0.6899 - auc: 0.9298 - val_loss: 1.1406 - val_accuracy: 0.7720 - val_precision: 0.5513 - val_recall: 0.4731 - val_auc: 0.8135
# Epoch 4/20
# 128/128 [==============================] - 18s 143ms/step - loss: 0.4662 - accuracy: 0.9061 - precision: 0.8266 - recall: 0.7900 - auc: 0.9607 - val_loss: 1.3419 - val_accuracy: 0.7664 - val_precision: 0.5351 - val_recall: 0.4995 - val_auc: 0.8140
# Epoch 5/20
# 128/128 [==============================] - 18s 142ms/step - loss: 0.3299 - accuracy: 0.9366 - precision: 0.8818 - recall: 0.8620 - auc: 0.9793 - val_loss: 1.4206 - val_accuracy: 0.7774 - val_precision: 0.5585 - val_recall: 0.5230 - val_auc: 0.8124
# Epoch 6/20
# 128/128 [==============================] - 18s 137ms/step - loss: 0.2024 - accuracy: 0.9620 - precision: 0.9272 - recall: 0.9203 - auc: 0.9914 - val_loss: 0.9849 - val_accuracy: 0.8485 - val_precision: 0.7025 - val_recall: 0.6833 - val_auc: 0.8967
# Epoch 7/20
# 128/128 [==============================] - 18s 137ms/step - loss: 0.1482 - accuracy: 0.9727 - precision: 0.9467 - recall: 0.9439 - auc: 0.9953 - val_loss: 1.6861 - val_accuracy: 0.7823 - val_precision: 0.5663 - val_recall: 0.5513 - val_auc: 0.8160
# Epoch 8/20
# 128/128 [==============================] - 18s 137ms/step - loss: 0.1325 - accuracy: 0.9758 - precision: 0.9536 - recall: 0.9496 - auc: 0.9959 - val_loss: 1.4903 - val_accuracy: 0.8331 - val_precision: 0.6687 - val_recall: 0.6588 - val_auc: 0.8623
# Epoch 9/20
# 128/128 [==============================] - 18s 137ms/step - loss: 0.0987 - accuracy: 0.9824 - precision: 0.9655 - recall: 0.9641 - auc: 0.9971 - val_loss: 1.7310 - val_accuracy: 0.7935 - val_precision: 0.5886 - val_recall: 0.5777 - val_auc: 0.8257
# Epoch 10/20
# 128/128 [==============================] - 18s 137ms/step - loss: 0.0781 - accuracy: 0.9857 - precision: 0.9726 - recall: 0.9700 - auc: 0.9988 - val_loss: 1.6169 - val_accuracy: 0.8021 - val_precision: 0.6062 - val_recall: 0.5943 - val_auc: 0.8377
# Epoch 11/20
# 128/128 [==============================] - 18s 136ms/step - loss: 0.0510 - accuracy: 0.9903 - precision: 0.9810 - recall: 0.9801 - auc: 0.9987 - val_loss: 2.3860 - val_accuracy: 0.7913 - val_precision: 0.5831 - val_recall: 0.5797 - val_auc: 0.8027
# Epoch 12/20
# 128/128 [==============================] - 18s 138ms/step - loss: 0.1012 - accuracy: 0.9830 - precision: 0.9665 - recall: 0.9656 - auc: 0.9971 - val_loss: 2.1408 - val_accuracy: 0.7903 - val_precision: 0.5818 - val_recall: 0.5738 - val_auc: 0.8067
# Epoch 13/20
# 128/128 [==============================] - 17s 136ms/step - loss: 0.0611 - accuracy: 0.9905 - precision: 0.9815 - recall: 0.9803 - auc: 0.9983 - val_loss: 1.9705 - val_accuracy: 0.8126 - val_precision: 0.6255 - val_recall: 0.6237 - val_auc: 0.8377
# Epoch 14/20
# 128/128 [==============================] - 17s 136ms/step - loss: 0.0394 - accuracy: 0.9933 - precision: 0.9870 - recall: 0.9862 - auc: 0.9994 - val_loss: 2.0282 - val_accuracy: 0.8282 - val_precision: 0.6572 - val_recall: 0.6540 - val_auc: 0.8464
# Epoch 15/20
# 128/128 [==============================] - 18s 138ms/step - loss: 0.0828 - accuracy: 0.9861 - precision: 0.9729 - recall: 0.9715 - auc: 0.9978 - val_loss: 1.9978 - val_accuracy: 0.7334 - val_precision: 0.4657 - val_recall: 0.4506 - val_auc: 0.7704
# Epoch 16/20
# 128/128 [==============================] - 17s 135ms/step - loss: 0.0580 - accuracy: 0.9903 - precision: 0.9813 - recall: 0.9801 - auc: 0.9989 - val_loss: 2.7260 - val_accuracy: 0.8091 - val_precision: 0.6189 - val_recall: 0.6158 - val_auc: 0.8135
# Epoch 17/20
# 128/128 [==============================] - 17s 135ms/step - loss: 0.0309 - accuracy: 0.9952 - precision: 0.9909 - recall: 0.9899 - auc: 0.9995 - val_loss: 1.7477 - val_accuracy: 0.8331 - val_precision: 0.6680 - val_recall: 0.6608 - val_auc: 0.8592
# Epoch 18/20
# 128/128 [==============================] - 18s 138ms/step - loss: 0.0264 - accuracy: 0.9943 - precision: 0.9889 - recall: 0.9882 - auc: 0.9999 - val_loss: 2.1096 - val_accuracy: 0.8192 - val_precision: 0.6397 - val_recall: 0.6334 - val_auc: 0.8368
# Epoch 19/20
# 128/128 [==============================] - 18s 136ms/step - loss: 0.0947 - accuracy: 0.9842 - precision: 0.9694 - recall: 0.9673 - auc: 0.9972 - val_loss: 1.7872 - val_accuracy: 0.8089 - val_precision: 0.6201 - val_recall: 0.6080 - val_auc: 0.8375
# Epoch 20/20
# 128/128 [==============================] - 17s 135ms/step - loss: 0.1079 - accuracy: 0.9840 - precision: 0.9694 - recall: 0.9666 - auc: 0.9959 - val_loss: 1.8053 - val_accuracy: 0.8294 - val_precision: 0.6620 - val_recall: 0.6491 - val_auc: 0.8489

# %%
path = "VGG19/loss_acc_1.png"
title = " MODEL'S METRICS VISUALIZATION : Transfer Learning "
Eval_Plot(
    VGG19_history_1.history['accuracy'],VGG19_history_1.history['val_accuracy'],
    VGG19_history_1.history['loss'],VGG19_history_1.history['val_loss'],
    VGG19_history_1.history['auc'],VGG19_history_1.history['val_auc'],
    VGG19_history_1.history['precision'],VGG19_history_1.history['val_precision'],
    path, title
)

# %% [markdown]
# ### VGG19 finetuning - Unfreeze base model and train entire model with low learning rate

# %%
isinstance(VGG19_base.layers[1], BatchNormalization)
# Out:
# False

# %%
VGG19_base.trainable = True
#freeze_BN(VGG19_base)

# %%
epochs = 50
lr_reduce = ReduceLROnPlateau(monitor='val_auc', factor=0.6, patience=5, verbose=1, mode='max', min_lr=5e-5)

early_stopping_cb = EarlyStopping(
    monitor='val_auc',
    patience=10,
    restore_best_weights=True,
    verbose=1,
    mode="max"
    )

checkpoint_cb = ModelCheckpoint(
    f"{Save}VGG19/VGG19.h5",
    monitor='val_auc',
    save_best_only=True,
    verbose=1,
    mode="max"
    )

VGG19_Top.compile(
    optimizer=keras.optimizers.RMSprop(0.001),  # Low learning rate
    loss='categorical_crossentropy',
    metrics=METRICS,
)

VGG19_Top.summary()

VGG19_history_2 = VGG19_Top.fit(
    training_data,
    epochs=epochs,
    validation_data=validation_data,
    verbose = 1,
    steps_per_epoch=steps_per_epoch,
    callbacks = [lr_reduce, early_stopping_cb, checkpoint_cb])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg19 (Functional)          (None, 7, 7, 512)         20024384
#
#  batch_normalization (BatchN  (None, 7, 7, 512)        2048
#  ormalization)
#
#  conv2d (Conv2D)             (None, 7, 7, 1024)        4719616
#
#  conv2d_1 (Conv2D)           (None, 7, 7, 1024)        9438208
#
#  max_pooling2d (MaxPooling2D  (None, 3, 3, 1024)       0
#  )
#
#  dropout (Dropout)           (None, 3, 3, 1024)        0
#
#  batch_normalization_1 (Batc  (None, 3, 3, 1024)       4096
#  hNormalization)
#
#  flatten (Flatten)           (None, 9216)              0
#
#  dense (Dense)               (None, 1024)              9438208
#
#  dense_1 (Dense)             (None, 4)                 4100
#
# =================================================================
# Total params: 43,630,660
# Trainable params: 43,627,588
# Non-trainable params: 3,072
# _________________________________________________________________
# Epoch 1/50
# 128/128 [==============================] - ETA: 0s - loss: 1.1415 - accuracy: 0.7853 - precision: 0.6229 - recall: 0.3580 - auc: 0.8072
# Epoch 1: val_auc improved from -inf to 0.66699, saving model to drive/MyDrive/Pammy_Alzheimers_Disease_Prediction/Visualisation/VGG19/VGG19.h5
# 128/128 [==============================] - 47s 334ms/step - loss: 1.1415 - accuracy: 0.7853 - precision: 0.6229 - recall: 0.3580 - auc: 0.8072 - val_loss: 37.6907 - val_accuracy: 0.7502 - val_precision: 0.5005 - val_recall: 0.5005 - val_auc: 0.6670 - lr: 0.0010
# Epoch 2/50
# 128/128 [==============================] - ETA: 0s - loss: 0.9736 - accuracy: 0.7870 - precision: 0.6529 - recall: 0.3160 - auc: 0.8225
# Epoch 2: val_auc did not improve from 0.66699
# 128/128 [==============================] - 39s 303ms/step - loss: 0.9736 - accuracy: 0.7870 - precision: 0.6529 - recall: 0.3160 - auc: 0.8225 - val_loss: 35.0423 - val_accuracy: 0.6750 - val_precision: 0.3500 - val_recall: 0.3500 - val_auc: 0.5673 - lr: 0.0010
# Epoch 3/50
# 128/128 [==============================] - ETA: 0s - loss: 0.9051 - accuracy: 0.7991 - precision: 0.6854 - recall: 0.3628 - auc: 0.8423
# Epoch 3: val_auc improved from 0.66699 to 0.80363, saving model to drive/MyDrive/Pammy_Alzheimers_Disease_Prediction/Visualisation/VGG19/VGG19.h5
# 128/128 [==============================] - 42s 327ms/step - loss: 0.9051 - accuracy: 0.7991 - precision: 0.6854 - recall: 0.3628 - auc: 0.8423 - val_loss: 1.9236 - val_accuracy: 0.7722 - val_precision: 0.5490 - val_recall: 0.4985 - val_auc: 0.8036 - lr: 0.0010
# Epoch 4/50
# 128/128 [==============================] - ETA: 0s - loss: 0.8636 - accuracy: 0.8042 - precision: 0.6786 - recall: 0.4117 - auc: 0.8588
# Epoch 4: val_auc did not improve from 0.80363
# 128/128 [==============================] - 39s 303ms/step - loss: 0.8636 - accuracy: 0.8042 - precision: 0.6786 - recall: 0.4117 - auc: 0.8588 - val_loss: 10996.0615 - val_accuracy: 0.6750 - val_precision: 0.3500 - val_recall: 0.3500 - val_auc: 0.5666 - lr: 0.0010
# Epoch 5/50
# 128/128 [==============================] - ETA: 0s - loss: 0.8471 - accuracy: 0.8086 - precision: 0.6741 - recall: 0.4538 - auc: 0.8671
# Epoch 5: val_auc did not improve from 0.80363
# 128/128 [==============================] - 39s 302ms/step - loss: 0.8471 - accuracy: 0.8086 - precision: 0.6741 - recall: 0.4538 - auc: 0.8671 - val_loss: 27.0053 - val_accuracy: 0.6750 - val_precision: 0.3500 - val_recall: 0.3500 - val_auc: 0.5657 - lr: 0.0010
# Epoch 6/50
# 128/128 [==============================] - ETA: 0s - loss: 0.8235 - accuracy: 0.8141 - precision: 0.6837 - recall: 0.4769 - auc: 0.8723
# Epoch 6: val_auc did not improve from 0.80363
# 128/128 [==============================] - 39s 303ms/step - loss: 0.8235 - accuracy: 0.8141 - precision: 0.6837 - recall: 0.4769 - auc: 0.8723 - val_loss: 10.1544 - val_accuracy: 0.7537 - val_precision: 0.5074 - val_recall: 0.5005 - val_auc: 0.7036 - lr: 0.0010
# Epoch 7/50
# 128/128 [==============================] - ETA: 0s - loss: 0.7937 - accuracy: 0.8222 - precision: 0.6963 - recall: 0.5121 - auc: 0.8818
# Epoch 7: val_auc improved from 0.80363 to 0.81180, saving model to drive/MyDrive/Pammy_Alzheimers_Disease_Prediction/Visualisation/VGG19/VGG19.h5
# 128/128 [==============================] - 42s 326ms/step - loss: 0.7937 - accuracy: 0.8222 - precision: 0.6963 - recall: 0.5121 - auc: 0.8818 - val_loss: 1.2877 - val_accuracy: 0.7674 - val_precision: 0.5464 - val_recall: 0.4086 - val_auc: 0.8118 - lr: 0.0010
# Epoch 8/50
# 128/128 [==============================] - ETA: 0s - loss: 0.7684 - accuracy: 0.8256 - precision: 0.6934 - recall: 0.5423 - auc: 0.8902
# Epoch 8: val_auc did not improve from 0.81180
# 128/128 [==============================] - 39s 303ms/step - loss: 0.7684 - accuracy: 0.8256 - precision: 0.6934 - recall: 0.5423 - auc: 0.8902 - val_loss: 1.0549 - val_accuracy: 0.7610 - val_precision: 0.5299 - val_recall: 0.3900 - val_auc: 0.8033 - lr: 0.0010
# Epoch 9/50
# 128/128 [==============================] - ETA: 0s - loss: 0.7458 - accuracy: 0.8353 - precision: 0.7121 - recall: 0.5730 - auc: 0.8973
# Epoch 9: val_auc did not improve from 0.81180
# 128/128 [==============================] - 39s 302ms/step - loss: 0.7458 - accuracy: 0.8353 - precision: 0.7121 - recall: 0.5730 - auc: 0.8973 - val_loss: 49049460.0000 - val_accuracy: 0.6906 - val_precision: 0.3586 - val_recall: 0.3011 - val_auc: 0.7286 - lr: 0.0010
# Epoch 10/50
# 128/128 [==============================] - ETA: 0s - loss: 0.7284 - accuracy: 0.8412 - precision: 0.7266 - recall: 0.5851 - auc: 0.9036
# Epoch 10: val_auc did not improve from 0.81180
# 128/128 [==============================] - 39s 302ms/step - loss: 0.7284 - accuracy: 0.8412 - precision: 0.7266 - recall: 0.5851 - auc: 0.9036 - val_loss: 1.8774 - val_accuracy: 0.7769 - val_precision: 0.5621 - val_recall: 0.4868 - val_auc: 0.8115 - lr: 0.0010
# Epoch 11/50
# 128/128 [==============================] - ETA: 0s - loss: 0.6729 - accuracy: 0.8467 - precision: 0.7251 - recall: 0.6227 - auc: 0.9158
# Epoch 11: val_auc did not improve from 0.81180
# 128/128 [==============================] - 39s 305ms/step - loss: 0.6729 - accuracy: 0.8467 - precision: 0.7251 - recall: 0.6227 - auc: 0.9158 - val_loss: 7.2589 - val_accuracy: 0.7568 - val_precision: 0.5139 - val_recall: 0.5044 - val_auc: 0.7368 - lr: 0.0010
# Epoch 12/50
# 128/128 [==============================] - ETA: 0s - loss: 0.6686 - accuracy: 0.8572 - precision: 0.7458 - recall: 0.6503 - auc: 0.9199
# Epoch 12: val_auc improved from 0.81180 to 0.82103, saving model to drive/MyDrive/Pammy_Alzheimers_Disease_Prediction/Visualisation/VGG19/VGG19.h5
# 128/128 [==============================] - 42s 324ms/step - loss: 0.6686 - accuracy: 0.8572 - precision: 0.7458 - recall: 0.6503 - auc: 0.9199 - val_loss: 1.8780 - val_accuracy: 0.7889 - val_precision: 0.5819 - val_recall: 0.5523 - val_auc: 0.8210 - lr: 0.0010
# Epoch 13/50
# 128/128 [==============================] - ETA: 0s - loss: 0.6339 - accuracy: 0.8653 - precision: 0.7597 - recall: 0.6749 - auc: 0.9283
# Epoch 13: val_auc improved from 0.82103 to 0.84652, saving model to drive/MyDrive/Pammy_Alzheimers_Disease_Prediction/Visualisation/VGG19/VGG19.h5
# 128/128 [==============================] - 42s 325ms/step - loss: 0.6339 - accuracy: 0.8653 - precision: 0.7597 - recall: 0.6749 - auc: 0.9283 - val_loss: 1.0039 - val_accuracy: 0.7842 - val_precision: 0.5808 - val_recall: 0.4917 - val_auc: 0.8465 - lr: 0.0010
# Epoch 14/50
# 128/128 [==============================] - ETA: 0s - loss: 0.5954 - accuracy: 0.8725 - precision: 0.7719 - recall: 0.6958 - auc: 0.9360
# Epoch 14: val_auc did not improve from 0.84652
# 128/128 [==============================] - 39s 303ms/step - loss: 0.5954 - accuracy: 0.8725 - precision: 0.7719 - recall: 0.6958 - auc: 0.9360 - val_loss: 5.9776 - val_accuracy: 0.7583 - val_precision: 0.5170 - val_recall: 0.5044 - val_auc: 0.7353 - lr: 0.0010
# Epoch 15/50
# 128/128 [==============================] - ETA: 0s - loss: 0.5438 - accuracy: 0.8887 - precision: 0.7950 - recall: 0.7477 - auc: 0.9474
# Epoch 15: val_auc did not improve from 0.84652
# 128/128 [==============================] - 39s 302ms/step - loss: 0.5438 - accuracy: 0.8887 - precision: 0.7950 - recall: 0.7477 - auc: 0.9474 - val_loss: 133.0463 - val_accuracy: 0.7502 - val_precision: 0.5005 - val_recall: 0.5005 - val_auc: 0.6670 - lr: 0.0010
# Epoch 16/50
# 128/128 [==============================] - ETA: 0s - loss: 0.4944 - accuracy: 0.8965 - precision: 0.8099 - recall: 0.7659 - auc: 0.9560
# Epoch 16: val_auc did not improve from 0.84652
# 128/128 [==============================] - 39s 303ms/step - loss: 0.4944 - accuracy: 0.8965 - precision: 0.8099 - recall: 0.7659 - auc: 0.9560 - val_loss: 27.1458 - val_accuracy: 0.7554 - val_precision: 0.5108 - val_recall: 0.5083 - val_auc: 0.6817 - lr: 0.0010
# Epoch 17/50
# 128/128 [==============================] - ETA: 0s - loss: 0.4677 - accuracy: 0.9031 - precision: 0.8204 - recall: 0.7841 - auc: 0.9601
# Epoch 17: val_auc did not improve from 0.84652
# 128/128 [==============================] - 39s 304ms/step - loss: 0.4677 - accuracy: 0.9031 - precision: 0.8204 - recall: 0.7841 - auc: 0.9601 - val_loss: 3.9471 - val_accuracy: 0.7696 - val_precision: 0.5407 - val_recall: 0.5200 - val_auc: 0.7806 - lr: 0.0010
# Epoch 18/50
# 128/128 [==============================] - ETA: 0s - loss: 0.4409 - accuracy: 0.9097 - precision: 0.8332 - recall: 0.7986 - auc: 0.9651
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0006000000284984708.
#
# Epoch 18: val_auc did not improve from 0.84652
# 128/128 [==============================] - 39s 303ms/step - loss: 0.4409 - accuracy: 0.9097 - precision: 0.8332 - recall: 0.7986 - auc: 0.9651 - val_loss: 1.7611 - val_accuracy: 0.6591 - val_precision: 0.3082 - val_recall: 0.2923 - val_auc: 0.6691 - lr: 0.0010
# Epoch 19/50
# 128/128 [==============================] - ETA: 0s - loss: 0.2866 - accuracy: 0.9428 - precision: 0.8898 - recall: 0.8800 - auc: 0.9842
# Epoch 19: val_auc did not improve from 0.84652
# 128/128 [==============================] - 39s 303ms/step - loss: 0.2866 - accuracy: 0.9428 - precision: 0.8898 - recall: 0.8800 - auc: 0.9842 - val_loss: 4.5425 - val_accuracy: 0.6017 - val_precision: 0.1986 - val_recall: 0.1955 - val_auc: 0.3913 - lr: 6.0000e-04
# Epoch 20/50
# 128/128 [==============================] - ETA: 0s - loss: 0.2650 - accuracy: 0.9519 - precision: 0.9078 - recall: 0.8989 - auc: 0.9870
# Epoch 20: val_auc did not improve from 0.84652
# 128/128 [==============================] - 39s 304ms/step - loss: 0.2650 - accuracy: 0.9519 - precision: 0.9078 - recall: 0.8989 - auc: 0.9870 - val_loss: 3.7011 - val_accuracy: 0.6131 - val_precision: 0.1923 - val_recall: 0.1711 - val_auc: 0.4900 - lr: 6.0000e-04
# Epoch 21/50
# 128/128 [==============================] - ETA: 0s - loss: 0.2237 - accuracy: 0.9571 - precision: 0.9166 - recall: 0.9112 - auc: 0.9898
# Epoch 21: val_auc did not improve from 0.84652
# 128/128 [==============================] - 39s 303ms/step - loss: 0.2237 - accuracy: 0.9571 - precision: 0.9166 - recall: 0.9112 - auc: 0.9898 - val_loss: 3.1044 - val_accuracy: 0.6239 - val_precision: 0.2362 - val_recall: 0.2258 - val_auc: 0.5861 - lr: 6.0000e-04
# Epoch 22/50
# 128/128 [==============================] - ETA: 0s - loss: 0.1892 - accuracy: 0.9627 - precision: 0.9276 - recall: 0.9230 - auc: 0.9921
# Epoch 22: val_auc did not improve from 0.84652
# 128/128 [==============================] - 39s 303ms/step - loss: 0.1892 - accuracy: 0.9627 - precision: 0.9276 - recall: 0.9230 - auc: 0.9921 - val_loss: 1.5934 - val_accuracy: 0.7234 - val_precision: 0.4440 - val_recall: 0.4223 - val_auc: 0.7630 - lr: 6.0000e-04
# Epoch 23/50
# 128/128 [==============================] - ETA: 0s - loss: 0.1802 - accuracy: 0.9662 - precision: 0.9349 - recall: 0.9297 - auc: 0.9926
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0003600000170990825.
# Restoring model weights from the end of the best epoch: 13.
#
# Epoch 23: val_auc did not improve from 0.84652
# 128/128 [==============================] - 39s 303ms/step - loss: 0.1802 - accuracy: 0.9662 - precision: 0.9349 - recall: 0.9297 - auc: 0.9926 - val_loss: 317207360.0000 - val_accuracy: 0.6251 - val_precision: 0.2478 - val_recall: 0.2454 - val_auc: 0.5654 - lr: 6.0000e-04
# Epoch 23: early stopping

# %% [markdown]
# ### Scores

# %%
scores_VGG19 = VGG19_Top.evaluate(testing_data)
# Out:
# 40/40 [==============================] - 5s 112ms/step - loss: 0.9423 - accuracy: 0.8043 - precision: 0.6326 - recall: 0.5184 - auc: 0.8520

# %%
print(f"Accuracy in test set  : {scores_VGG19[1]}")
print(f"Precision in test set : {scores_VGG19[2]}")
print(f"Recall in test set    : {scores_VGG19[3]}")
print(f"AUC in test set       : {scores_VGG19[4]}")
# Out:
# Accuracy in test set  : 0.8043393492698669
# Precision in test set : 0.6326335668563843
# Recall in test set    : 0.5183737277984619
# AUC in test set       : 0.8520492911338806

# %%
import pandas as pd
Scores = pd.DataFrame([scores_VGG19], columns = ["Loss", "Test Accuracy", "Precision", "Recall", "AUC"])
Scores
# Out:
#        Loss  Test Accuracy  Precision    Recall       AUC
# 0  0.942251       0.804339   0.632634  0.518374  0.852049

# %%
Scores.to_csv(f"{Save}VGG19/score.csv")

# %% [markdown]
# ### Plots

# %%
path = "VGG19/loss_acc_2.png"
title = " MODEL'S METRICS VISUALIZATION : Fine Tuning "
Eval_Plot(
    VGG19_history_2.history['accuracy'],VGG19_history_2.history['val_accuracy'],
    VGG19_history_2.history['loss'],VGG19_history_2.history['val_loss'],
    VGG19_history_2.history['auc'],VGG19_history_2.history['val_auc'],
    VGG19_history_2.history['precision'],VGG19_history_2.history['val_precision'],
    path, title
)

# %%
predictions = VGG19_Top.predict(testing_data)
y_pred = predictions.argmax(axis = -1)
y_label = testing_data.labels.copy()
class_Names = list(testing_data.class_indices.keys())

# %%
assert y_pred.shape == y_label.shape

# %%
Confusion_Matrix_Heatmap(y_label, y_pred, class_Names, f"VGG19/HeatMap.jpeg", "VGG19")

# %% [markdown]
# # GradCam, activation Visualisation

# %%
# Display
from IPython.display import Image, display
import matplotlib.pyplot as plt
import matplotlib.cm as cm

# %% [markdown]
# ## Configurable parameters

# %%
VGG19_Top.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg19 (Functional)          (None, 7, 7, 512)         20024384
#
#  batch_normalization (BatchN  (None, 7, 7, 512)        2048
#  ormalization)
#
#  conv2d (Conv2D)             (None, 7, 7, 1024)        4719616
#
#  conv2d_1 (Conv2D)           (None, 7, 7, 1024)        9438208
#
#  max_pooling2d (MaxPooling2D  (None, 3, 3, 1024)       0
#  )
#
#  dropout (Dropout)           (None, 3, 3, 1024)        0
#
#  batch_normalization_1 (Batc  (None, 3, 3, 1024)       4096
#  hNormalization)
#
#  flatten (Flatten)           (None, 9216)              0
#
#  dense (Dense)               (None, 1024)              9438208
#
#  dense_1 (Dense)             (None, 4)                 4100
#
# =================================================================
# Total params: 43,630,660
# Trainable params: 43,627,588
# Non-trainable params: 3,072
# _________________________________________________________________

# %%
last_conv_layer_name = "conv2d_1"
decode_predictions = keras.applications.inception_v3.decode_predictions
X,y = testing_data.next()

# %%
X[3].shape
# Out:
# (224, 224, 3)

# %%
img_path = X[0].copy()
imshow(X[3])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
def get_img_array(img_path, size):
    # `img` is a PIL image of size 299x299
    img = keras.preprocessing.image.load_img(img_path, target_size=size)
    # `array` is a float32 Numpy array of shape (299, 299, 3)
    array = keras.preprocessing.image.img_to_array(img)
    # We add a dimension to transform our image array into a "batch"
    # of size (1, 299, 299, 3)
    array = np.expand_dims(array, axis=0)
    return array


def make_gradcam_heatmap(img_array, model, last_conv_layer_name, pred_index=None):
    # First, we create a model that maps the input image to the activations
    # of the last conv layer as well as the output predictions
    grad_model = tf.keras.models.Model(
        [model.inputs], [model.get_layer(last_conv_layer_name).output, model.output]
    )

    # Then, we compute the gradient of the top predicted class for our input image
    # with respect to the activations of the last conv layer
    with tf.GradientTape() as tape:
        last_conv_layer_output, preds = grad_model(img_array)
        if pred_index is None:
            pred_index = tf.argmax(preds[0])
        class_channel = preds[:, pred_index]

    # This is the gradient of the output neuron (top predicted or chosen)
    # with regard to the output feature map of the last conv layer
    grads = tape.gradient(class_channel, last_conv_layer_output)

    # This is a vector where each entry is the mean intensity of the gradient
    # over a specific feature map channel
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))

    # We multiply each channel in the feature map array
    # by "how important this channel is" with regard to the top predicted class
    # then sum all the channels to obtain the heatmap class activation
    last_conv_layer_output = last_conv_layer_output[0]
    heatmap = last_conv_layer_output @ pooled_grads[..., tf.newaxis]
    heatmap = tf.squeeze(heatmap)

    # For visualization purpose, we will also normalize the heatmap between 0 & 1
    heatmap = tf.maximum(heatmap, 0) / tf.math.reduce_max(heatmap)
    return heatmap.numpy()

def get_gradcam_img(img_path, heatmap, cam_path="cam.jpg", alpha=0.4):
    # Load the original image
    img = keras.preprocessing.image.load_img(img_path)
    img = keras.preprocessing.image.img_to_array(img)

    # Rescale heatmap to a range 0-255
    heatmap = np.uint8(255 * heatmap)

    # Use jet colormap to colorize heatmap
    jet = cm.get_cmap("jet")

    # Use RGB values of the colormap
    jet_colors = jet(np.arange(256))[:, :3]
    jet_heatmap = jet_colors[heatmap]

    # Create an image with RGB colorized heatmap
    jet_heatmap = keras.preprocessing.image.array_to_img(jet_heatmap)
    jet_heatmap = jet_heatmap.resize((img.shape[1], img.shape[0]))
    jet_heatmap = keras.preprocessing.image.img_to_array(jet_heatmap)

    # Superimpose the heatmap on original image
    superimposed_img = jet_heatmap * alpha + img
    superimposed_img = keras.preprocessing.image.array_to_img(superimposed_img)

    return superimposed_img

# %%
# Make model
model_load= keras.models.load_model(f"{Save}VGG19/VGG19.h5")

# Remove last layer's softmax
model_load.layers[-1].activation = None

# %%
class_Names = os.listdir(f"{test}").copy()
img_paths = []
for cls in class_Names:
  ClsPath2dir = f"{test}{cls}/"
  content = os.listdir(ClsPath2dir)
  imgPath = os.path.join(ClsPath2dir, np.random.choice(content))
  img_paths.append(imgPath)

img_paths

# %%
fig, axs = plt.subplots(2, 2, figsize = (15,15))
for ax, path, label in zip(axs.flatten(), img_paths, class_Names):
  # Prepare image
  img_arry = keras.applications.vgg19.preprocess_input(get_img_array(path, (Image_Size, Image_Size)))
  # Print what the top predicted class is
  preds = model_load.predict(img_arry)
  print(f"Predicted : {Ind2ClassName[int(preds.argmax(axis=-1).squeeze())]}")
  #print("Predicted:", decode_predictions(preds, top=1)[0])

  # Generate class activation heatmap
  heatmap = make_gradcam_heatmap(img_arry, model_load, last_conv_layer_name)

  # Get superImposed Image
  superimposed_img = get_gradcam_img(path, heatmap)
  ax.imshow(superimposed_img)
  ax.axis('off')
  ax.title.set_text(f"Predicted label : {Ind2ClassName[int(preds.argmax(axis=-1).squeeze())]} Actual : {label}")

plt.suptitle('Grad Cam Visualisation')
plt.savefig(f"{Save}VGG19/GradCam.jpg")
plt.show()
# Out:
# Predicted : MildDemented
# Predicted : VeryMildDemented
# Predicted : MildDemented
# Predicted : VeryMildDemented
