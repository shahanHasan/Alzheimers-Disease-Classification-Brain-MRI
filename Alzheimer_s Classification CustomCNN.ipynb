# %% [markdown]
# # Global PAth vars

# %%
#PATH 
base_path = "drive/MyDrive/Pammy_Alzheimers_Disease_Prediction/Dataset/Alzheimers_Dataset/"
train = f"{base_path}train/"
test = f"{base_path}test/"
Save = f"drive/MyDrive/Pammy_Alzheimers_Disease_Prediction/Visualisation/"


base_path_bin = "drive/MyDrive/Pammy_Alzheimers_Disease_Prediction/Dataset/Alzheimers_Dataset_Binary/"
train_bin = f"{base_path_bin}train/" 
test_bin = f"{base_path_bin}test/"
Save_bin = f"drive/MyDrive/Pammy_Alzheimers_Disease_Prediction/Visualisation/BinaryClassification/"

# %% [markdown]
# # Imports

# %%
import os, time

#arr operations
import numpy as np

# Progress Bar
from tqdm import tqdm

# Evaluation metrics
from sklearn import metrics
from sklearn.metrics import confusion_matrix, classification_report

#Importing Deep learning Libraries
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential, load_model
from keras.layers import InputLayer, BatchNormalization, Dropout, Flatten, Dense, Activation, MaxPool2D
from keras.layers import GlobalAveragePooling2D, Conv2D, MaxPooling2D, SeparableConv2D
from keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler, Callback, ReduceLROnPlateau
from keras import optimizers, Input
from keras.utils.vis_utils import plot_model
from keras.applications.imagenet_utils import decode_predictions
import keras.backend as K


#Pretrained models
from keras.applications.xception import Xception
from keras.applications.inception_v3 import InceptionV3
from keras.applications.vgg16 import VGG16
from keras.applications.vgg19 import VGG19
from keras.applications.resnet import ResNet50
from keras.applications.resnet_v2 import ResNet152V2
#from keras.applications.resnet152_v2 import ResNet152V2


#Image read and show
import skimage.io
from skimage.io import imread, imshow
import matplotlib.pyplot as plt 
import seaborn as sns
sns.set_style('darkgrid')
#plt.style.use('fivethirtyeight')

#Metrics
from sklearn.metrics import f1_score , recall_score, accuracy_score, precision_score, confusion_matrix
from sklearn.metrics import roc_curve, auc, classification_report
from sklearn.preprocessing import label_binarize
from sklearn.multiclass import OneVsRestClassifier
from itertools import cycle

# %%
tf.__version__
# Out:
# '2.8.2'

# %% [markdown]
# # Utils Functions

# %%
def Confusion_Matrix_Heatmap(y_test,y_pred,class_Names, fName, ModelName):
    #Plot the confusion matrix to understand the classification in detail
    CM = confusion_matrix(y_test, y_pred)
    plt.figure(figsize=(10, 8), dpi=80, facecolor='w', edgecolor='k')
    ax = sns.heatmap(CM, cmap='Greens', annot=True, fmt='d', xticklabels=class_Names, yticklabels=class_Names)
    plt.title(f'Alzheimer\'s Disease Diagnosis - {ModelName}')
    plt.xlabel('Prediction')
    plt.ylabel('Truth')
    plt.savefig(f"{Save}{fName}")
    #plt.show(ax)

# Plot Evaluation Metrics
sns.set_style('darkgrid')
#plt.style.use('fivethirtyeight')
def Eval_Plot(acc,val_acc, loss,val_loss, auc, val_auc, precision, val_precision, path, title):
    
    fig, (ax1,ax2,ax3,ax4) = plt.subplots(1,4, figsize= (20,5))
    fig.suptitle(f"{title}\n", fontsize = 15)

    ax1.plot(range(1, len(acc) + 1), acc)
    ax1.plot(range(1, len(val_acc) + 1), val_acc)
    ax1.set_title('History of Accuracy', fontsize = 15)
    ax1.set_xlabel('Epochs', fontsize = 15)
    ax1.set_ylabel('Accuracy', fontsize = 15)
    ax1.legend(['Training', 'Validation'], fontsize = 15)


    ax2.plot(range(1, len(loss) + 1), loss)
    ax2.plot(range(1, len(val_loss) + 1), val_loss)
    ax2.set_title('History of Loss', fontsize = 15)
    ax2.set_xlabel('Epochs', fontsize = 15)
    ax2.set_ylabel('Loss', fontsize = 15)
    ax2.legend(['Training', 'Validation'], fontsize = 15)

    ax3.plot(range(1, len(auc) + 1), auc)
    ax3.plot(range(1, len(val_auc) + 1), val_auc)
    ax3.set_title('History of AUC', fontsize = 15)
    ax3.set_xlabel('Epochs', fontsize = 15)
    ax3.set_ylabel('AUC', fontsize = 15)
    ax3.legend(['Training', 'Validation'], fontsize = 15)
    
    ax4.plot(range(1, len(precision) + 1), precision)
    ax4.plot(range(1, len(val_precision) + 1), val_precision)
    ax4.set_title('History of Precision', fontsize = 15)
    ax4.set_xlabel('Epochs', fontsize = 15)
    ax4.set_ylabel('Precision', fontsize = 15)
    ax4.legend(['Training', 'Validation'], fontsize = 15)

    plt.savefig(f"{Save}{path}")
    #plt.show()

# %% [markdown]
# # Model Building

# %% [markdown]
# ## Set Seed

# %%
Seed = 29
Batch_Size = 32
Image_Size = 256
np.random.seed(Seed)
tf.random.set_seed(Seed)

# %% [markdown]
# ## GPU Test

# %%
# GPU
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %% [markdown]
# # MULTICLASS CLASSIFICATION MODELS

# %% [markdown]
# ## Data Generator

# %%
# Image data generator
training_data_gen = ImageDataGenerator(
    validation_split = 0.2,
    rescale = 1./255,
    )

testing_data_gen = ImageDataGenerator(        
    rescale = 1./255,
    )

validation_data_gen = ImageDataGenerator(
    rescale = 1./255,
    validation_split = 0.2
    )

# %% [markdown]
# ## Splitting the Data

# %%
training_data = training_data_gen.flow_from_directory(
    directory= train,
    target_size = (Image_Size,Image_Size),
    class_mode = 'categorical',
    color_mode  = 'rgb', 
    subset = 'training',
    seed = Seed,
    batch_size = Batch_Size)

validation_data = validation_data_gen.flow_from_directory(
  directory = train,
  target_size = (Image_Size,Image_Size),
  class_mode = 'categorical',
  color_mode  = 'rgb', 
  subset = 'validation',
  seed = Seed,
  batch_size = Batch_Size)

testing_data =  testing_data_gen.flow_from_directory(
  directory = test,
  target_size = (Image_Size,Image_Size),
  class_mode = 'categorical',
  color_mode  = 'rgb', 
  seed = Seed,
  batch_size = Batch_Size
)
# Out:
# Found 4098 images belonging to 4 classes.
# Found 1023 images belonging to 4 classes.
# Found 1279 images belonging to 4 classes.

# %%
ClassName2Ind = (training_data.class_indices)
Ind2ClassName = {v: k for k, v in ClassName2Ind.items()}
X,y = training_data.next()

# %%
imshow(X[0])
plt.title(Ind2ClassName[np.argmax(y[0],axis=0)])
# Out:
# Text(0.5, 1.0, 'NonDemented')

# %%
steps_per_epoch = training_data.n // training_data.batch_size
print('steps per epoch: ',steps_per_epoch)
# Out:
# steps per epoch:  128

# %%
assert len(training_data) > 5, "Less Than 5 Batches"
assert len(validation_data) > 5, "Less Than 5 Batches"
assert len(testing_data) > 5, "Less Than 5 Batches"

# %%
print(f"Train shape : {X.shape} y shape {y.shape}")
# Out:
# Train shape : (32, 256, 256, 3) y shape (32, 4)

# %% [markdown]
# ## CNN - From Scratch

# %%
K.clear_session()

# %%
def conv_block(filters, act='relu'):
    """Defining a Convolutional NN block for a Sequential CNN model. """
    
    block = Sequential()
    block.add(SeparableConv2D(filters, 3, activation=act, padding='same'))
    block.add(SeparableConv2D(filters, 3, activation=act, padding='same'))
    block.add(BatchNormalization())
    block.add(MaxPool2D())
    
    return block

def dense_block(units, dropout_rate, act='relu'):
    """Defining a Dense NN block for a Sequential CNN model. """
    
    block = Sequential()
    block.add(Dense(units, activation=act))
    block.add(BatchNormalization())
    block.add(Dropout(dropout_rate))
    
    return block

def build_model():
    model = Sequential([
        Input(shape=(*Image_Size, 3)),
        
        Conv2D(16, 3, activation='relu', padding='same'),
        Conv2D(16, 3, activation='relu', padding='same'),
        MaxPool2D(),
        
        conv_block(32),
        conv_block(64),
        
        conv_block(128),
        Dropout(0.2),
        
        conv_block(256),
        Dropout(0.2),
        
        Flatten(),
        dense_block(512, 0.7),
        dense_block(128, 0.5),
        dense_block(64, 0.3),
        
        Dense(4, activation='softmax')
    ])

    return model
    

def construct_model(act='relu'):
    """
    Constructing a Sequential CNN architecture for 
    performing the classification task. 
    """
    
    model = Sequential([
        Input(shape=(Image_Size, Image_Size, 3)),
        Conv2D(128, 3, activation=act, padding='same'),
        Conv2D(128, 3, activation=act, padding='same'),
        MaxPool2D(),
        Dropout(0.2),
        conv_block(256),
        Dropout(0.2),
        conv_block(256),
        Dropout(0.2),
        conv_block(256),
        Dropout(0.2),
        Flatten(),
        dense_block(128, 0.5),
        dense_block(128, 0.3),
        dense_block(64, 0.2),
        Dense(4, activation='softmax')        
    ], name = "cnn_model")

    return model

# %%
METRICS = [
      keras.metrics.BinaryAccuracy(name='accuracy'),
      keras.metrics.Precision(name='precision'),
      keras.metrics.Recall(name='recall'),  
      keras.metrics.AUC(name='auc')
]
Custom_CNN = construct_model()
Custom_CNN.compile(
    optimizer= keras.optimizers.Adam(0.001),
    loss=tf.losses.CategoricalCrossentropy(),
    metrics=METRICS)
Custom_CNN.summary()
# Out:
# Model: "cnn_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 256, 256, 128)     3584
#
#  conv2d_1 (Conv2D)           (None, 256, 256, 128)     147584
#
#  max_pooling2d (MaxPooling2D  (None, 128, 128, 128)    0
#  )
#
#  dropout (Dropout)           (None, 128, 128, 128)     0
#
#  sequential (Sequential)     (None, 64, 64, 256)       103296
#
#  dropout_1 (Dropout)         (None, 64, 64, 256)       0
#
#  sequential_1 (Sequential)   (None, 32, 32, 256)       137216
#
#  dropout_2 (Dropout)         (None, 32, 32, 256)       0
#
#  sequential_2 (Sequential)   (None, 16, 16, 256)       137216
#
#  dropout_3 (Dropout)         (None, 16, 16, 256)       0
#
#  flatten (Flatten)           (None, 65536)             0
#
#  sequential_3 (Sequential)   (None, 128)               8389248
#
#  sequential_4 (Sequential)   (None, 128)               17024
#
#  sequential_5 (Sequential)   (None, 64)                8512
#
#  dense_3 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 8,943,940
# Trainable params: 8,941,764
# Non-trainable params: 2,176
# _________________________________________________________________

# %%
plot_model(
    Custom_CNN,
    to_file=f"{Save}CustomCNN/Architecture.png",
    show_shapes=False,
    show_dtype=False,
    show_layer_names=True,
    rankdir="TB",
    expand_nested=False,
    dpi=96,
    layer_range=None,
    show_layer_activations=False,
)

# %%
epochs = 100
lr_reduce = ReduceLROnPlateau(monitor='val_auc', factor=0.5, patience=5, verbose=1, mode='max', min_lr=5e-5)

early_stopping_cb = EarlyStopping(
    monitor='val_auc', 
    patience=15, 
    restore_best_weights=True, 
    verbose=1, 
    mode="max"
    )

checkpoint_cb = ModelCheckpoint(
    f"{Save}CustomCNN/CustomCNN.h5", 
    monitor='val_auc',
    save_best_only=True, 
    verbose=1, 
    mode="max"
    )

Custom_CNN.compile(
    optimizer=keras.optimizers.RMSprop(0.001),  # Low learning rate
    loss='categorical_crossentropy',
    metrics=METRICS,
)

Custom_CNN_history = Custom_CNN.fit(
    training_data, 
    epochs=epochs, 
    validation_data=validation_data, 
    verbose = 1, 
    steps_per_epoch=steps_per_epoch,
    callbacks = [lr_reduce, early_stopping_cb, checkpoint_cb],
    )
# Out:
# Epoch 1/100
# 128/128 [==============================] - ETA: 0s - loss: 1.3993 - accuracy: 0.7500 - precision: 0.5000 - recall: 0.3138 - auc: 0.6951
# Epoch 1: val_auc improved from -inf to 0.78038, saving model to drive/MyDrive/Pammy_Alzheimers_Disease_Prediction/Visualisation/CustomCNN/CustomCNN.h5
# 128/128 [==============================] - 682s 5s/step - loss: 1.3993 - accuracy: 0.7500 - precision: 0.5000 - recall: 0.3138 - auc: 0.6951 - val_loss: 1.0810 - val_accuracy: 0.7500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7804 - lr: 0.0010
# Epoch 2/100
# 128/128 [==============================] - ETA: 0s - loss: 1.1604 - accuracy: 0.7657 - precision: 0.5473 - recall: 0.3625 - auc: 0.7713
# Epoch 2: val_auc did not improve from 0.78038
# 128/128 [==============================] - 84s 652ms/step - loss: 1.1604 - accuracy: 0.7657 - precision: 0.5473 - recall: 0.3625 - auc: 0.7713 - val_loss: 1.6808 - val_accuracy: 0.6750 - val_precision: 0.3500 - val_recall: 0.3500 - val_auc: 0.6099 - lr: 0.0010
# Epoch 3/100
# 128/128 [==============================] - ETA: 0s - loss: 1.0536 - accuracy: 0.7753 - precision: 0.5745 - recall: 0.3898 - auc: 0.8032
# Epoch 3: val_auc did not improve from 0.78038
# 128/128 [==============================] - 83s 652ms/step - loss: 1.0536 - accuracy: 0.7753 - precision: 0.5745 - recall: 0.3898 - auc: 0.8032 - val_loss: 1.5958 - val_accuracy: 0.6750 - val_precision: 0.3500 - val_recall: 0.3500 - val_auc: 0.6095 - lr: 0.0010
# Epoch 4/100
# 128/128 [==============================] - ETA: 0s - loss: 0.9620 - accuracy: 0.7863 - precision: 0.6058 - recall: 0.4161 - auc: 0.8301
# Epoch 4: val_auc did not improve from 0.78038
# 128/128 [==============================] - 83s 652ms/step - loss: 0.9620 - accuracy: 0.7863 - precision: 0.6058 - recall: 0.4161 - auc: 0.8301 - val_loss: 1.2580 - val_accuracy: 0.6767 - val_precision: 0.3408 - val_recall: 0.3138 - val_auc: 0.7084 - lr: 0.0010
# Epoch 5/100
# 128/128 [==============================] - ETA: 0s - loss: 0.9470 - accuracy: 0.7911 - precision: 0.6181 - recall: 0.4299 - auc: 0.8351
# Epoch 5: val_auc did not improve from 0.78038
# 128/128 [==============================] - 84s 652ms/step - loss: 0.9470 - accuracy: 0.7911 - precision: 0.6181 - recall: 0.4299 - auc: 0.8351 - val_loss: 5.0487 - val_accuracy: 0.7502 - val_precision: 0.5005 - val_recall: 0.5005 - val_auc: 0.7585 - lr: 0.0010
# Epoch 6/100
# 128/128 [==============================] - ETA: 0s - loss: 0.9028 - accuracy: 0.8008 - precision: 0.6477 - recall: 0.4453 - auc: 0.8495
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 6: val_auc did not improve from 0.78038
# 128/128 [==============================] - 84s 657ms/step - loss: 0.9028 - accuracy: 0.8008 - precision: 0.6477 - recall: 0.4453 - auc: 0.8495 - val_loss: 1.4620 - val_accuracy: 0.7268 - val_precision: 0.4515 - val_recall: 0.4321 - val_auc: 0.7620 - lr: 0.0010
# Epoch 7/100
# 128/128 [==============================] - ETA: 0s - loss: 0.8332 - accuracy: 0.8169 - precision: 0.6842 - recall: 0.4970 - auc: 0.8722
# Epoch 7: val_auc did not improve from 0.78038
# 128/128 [==============================] - 84s 652ms/step - loss: 0.8332 - accuracy: 0.8169 - precision: 0.6842 - recall: 0.4970 - auc: 0.8722 - val_loss: 1.2055 - val_accuracy: 0.7336 - val_precision: 0.4626 - val_recall: 0.4047 - val_auc: 0.7691 - lr: 5.0000e-04
# Epoch 8/100
# 128/128 [==============================] - ETA: 0s - loss: 0.7600 - accuracy: 0.8374 - precision: 0.7290 - recall: 0.5563 - auc: 0.8951
# Epoch 8: val_auc did not improve from 0.78038
# 128/128 [==============================] - 83s 652ms/step - loss: 0.7600 - accuracy: 0.8374 - precision: 0.7290 - recall: 0.5563 - auc: 0.8951 - val_loss: 1.3507 - val_accuracy: 0.6557 - val_precision: 0.2356 - val_recall: 0.1681 - val_auc: 0.6551 - lr: 5.0000e-04
# Epoch 9/100
# 128/128 [==============================] - ETA: 0s - loss: 0.6917 - accuracy: 0.8551 - precision: 0.7552 - recall: 0.6220 - auc: 0.9147
# Epoch 9: val_auc improved from 0.78038 to 0.83800, saving model to drive/MyDrive/Pammy_Alzheimers_Disease_Prediction/Visualisation/CustomCNN/CustomCNN.h5
# 128/128 [==============================] - 84s 659ms/step - loss: 0.6917 - accuracy: 0.8551 - precision: 0.7552 - recall: 0.6220 - auc: 0.9147 - val_loss: 0.9626 - val_accuracy: 0.7925 - val_precision: 0.6038 - val_recall: 0.4946 - val_auc: 0.8380 - lr: 5.0000e-04
# Epoch 10/100
# 128/128 [==============================] - ETA: 0s - loss: 0.6114 - accuracy: 0.8751 - precision: 0.7841 - recall: 0.6904 - auc: 0.9339
# Epoch 10: val_auc did not improve from 0.83800
# 128/128 [==============================] - 83s 652ms/step - loss: 0.6114 - accuracy: 0.8751 - precision: 0.7841 - recall: 0.6904 - auc: 0.9339 - val_loss: 1.2605 - val_accuracy: 0.7793 - val_precision: 0.5622 - val_recall: 0.5298 - val_auc: 0.8267 - lr: 5.0000e-04
# Epoch 11/100
# 128/128 [==============================] - ETA: 0s - loss: 0.5276 - accuracy: 0.8956 - precision: 0.8188 - recall: 0.7479 - auc: 0.9508
# Epoch 11: val_auc did not improve from 0.83800
# 128/128 [==============================] - 84s 652ms/step - loss: 0.5276 - accuracy: 0.8956 - precision: 0.8188 - recall: 0.7479 - auc: 0.9508 - val_loss: 2.3757 - val_accuracy: 0.7744 - val_precision: 0.5500 - val_recall: 0.5376 - val_auc: 0.7729 - lr: 5.0000e-04
# Epoch 12/100
# 128/128 [==============================] - ETA: 0s - loss: 0.4797 - accuracy: 0.9051 - precision: 0.8314 - recall: 0.7784 - auc: 0.9590
# Epoch 12: val_auc did not improve from 0.83800
# 128/128 [==============================] - 83s 652ms/step - loss: 0.4797 - accuracy: 0.9051 - precision: 0.8314 - recall: 0.7784 - auc: 0.9590 - val_loss: 1.2566 - val_accuracy: 0.7405 - val_precision: 0.4759 - val_recall: 0.3763 - val_auc: 0.7610 - lr: 5.0000e-04
# Epoch 13/100
# 128/128 [==============================] - ETA: 0s - loss: 0.4004 - accuracy: 0.9232 - precision: 0.8631 - recall: 0.8234 - auc: 0.9715
# Epoch 13: val_auc improved from 0.83800 to 0.83903, saving model to drive/MyDrive/Pammy_Alzheimers_Disease_Prediction/Visualisation/CustomCNN/CustomCNN.h5
# 128/128 [==============================] - 84s 659ms/step - loss: 0.4004 - accuracy: 0.9232 - precision: 0.8631 - recall: 0.8234 - auc: 0.9715 - val_loss: 1.5646 - val_accuracy: 0.7959 - val_precision: 0.5948 - val_recall: 0.5767 - val_auc: 0.8390 - lr: 5.0000e-04
# Epoch 14/100
# 128/128 [==============================] - ETA: 0s - loss: 0.3428 - accuracy: 0.9341 - precision: 0.8819 - recall: 0.8502 - auc: 0.9786
# Epoch 14: val_auc improved from 0.83903 to 0.92495, saving model to drive/MyDrive/Pammy_Alzheimers_Disease_Prediction/Visualisation/CustomCNN/CustomCNN.h5
# 128/128 [==============================] - 84s 658ms/step - loss: 0.3428 - accuracy: 0.9341 - precision: 0.8819 - recall: 0.8502 - auc: 0.9786 - val_loss: 0.6767 - val_accuracy: 0.8631 - val_precision: 0.7369 - val_recall: 0.7038 - val_auc: 0.9250 - lr: 5.0000e-04
# Epoch 15/100
# 128/128 [==============================] - ETA: 0s - loss: 0.3030 - accuracy: 0.9435 - precision: 0.8983 - recall: 0.8728 - auc: 0.9830
# Epoch 15: val_auc did not improve from 0.92495
# 128/128 [==============================] - 83s 652ms/step - loss: 0.3030 - accuracy: 0.9435 - precision: 0.8983 - recall: 0.8728 - auc: 0.9830 - val_loss: 0.8431 - val_accuracy: 0.8504 - val_precision: 0.7053 - val_recall: 0.6901 - val_auc: 0.9137 - lr: 5.0000e-04
# Epoch 16/100
# 128/128 [==============================] - ETA: 0s - loss: 0.2507 - accuracy: 0.9540 - precision: 0.9173 - recall: 0.8970 - auc: 0.9882
# Epoch 16: val_auc improved from 0.92495 to 0.93975, saving model to drive/MyDrive/Pammy_Alzheimers_Disease_Prediction/Visualisation/CustomCNN/CustomCNN.h5
# 128/128 [==============================] - 85s 662ms/step - loss: 0.2507 - accuracy: 0.9540 - precision: 0.9173 - recall: 0.8970 - auc: 0.9882 - val_loss: 0.6409 - val_accuracy: 0.8744 - val_precision: 0.7532 - val_recall: 0.7400 - val_auc: 0.9397 - lr: 5.0000e-04
# Epoch 17/100
# 128/128 [==============================] - ETA: 0s - loss: 0.2232 - accuracy: 0.9579 - precision: 0.9227 - recall: 0.9078 - auc: 0.9906
# Epoch 17: val_auc did not improve from 0.93975
# 128/128 [==============================] - 83s 651ms/step - loss: 0.2232 - accuracy: 0.9579 - precision: 0.9227 - recall: 0.9078 - auc: 0.9906 - val_loss: 0.6782 - val_accuracy: 0.8827 - val_precision: 0.7691 - val_recall: 0.7586 - val_auc: 0.9388 - lr: 5.0000e-04
# Epoch 18/100
# 128/128 [==============================] - ETA: 0s - loss: 0.1913 - accuracy: 0.9642 - precision: 0.9329 - recall: 0.9230 - auc: 0.9929
# Epoch 18: val_auc improved from 0.93975 to 0.94919, saving model to drive/MyDrive/Pammy_Alzheimers_Disease_Prediction/Visualisation/CustomCNN/CustomCNN.h5
# 128/128 [==============================] - 84s 658ms/step - loss: 0.1913 - accuracy: 0.9642 - precision: 0.9329 - recall: 0.9230 - auc: 0.9929 - val_loss: 0.5514 - val_accuracy: 0.8881 - val_precision: 0.7811 - val_recall: 0.7674 - val_auc: 0.9492 - lr: 5.0000e-04
# Epoch 19/100
# 128/128 [==============================] - ETA: 0s - loss: 0.1586 - accuracy: 0.9727 - precision: 0.9489 - recall: 0.9415 - auc: 0.9949
# Epoch 19: val_auc improved from 0.94919 to 0.95538, saving model to drive/MyDrive/Pammy_Alzheimers_Disease_Prediction/Visualisation/CustomCNN/CustomCNN.h5
# 128/128 [==============================] - 84s 659ms/step - loss: 0.1586 - accuracy: 0.9727 - precision: 0.9489 - recall: 0.9415 - auc: 0.9949 - val_loss: 0.5450 - val_accuracy: 0.9025 - val_precision: 0.8095 - val_recall: 0.7977 - val_auc: 0.9554 - lr: 5.0000e-04
# Epoch 20/100
# 128/128 [==============================] - ETA: 0s - loss: 0.1538 - accuracy: 0.9731 - precision: 0.9497 - recall: 0.9424 - auc: 0.9950
# Epoch 20: val_auc did not improve from 0.95538
# 128/128 [==============================] - 84s 652ms/step - loss: 0.1538 - accuracy: 0.9731 - precision: 0.9497 - recall: 0.9424 - auc: 0.9950 - val_loss: 0.8140 - val_accuracy: 0.8695 - val_precision: 0.7395 - val_recall: 0.7380 - val_auc: 0.9305 - lr: 5.0000e-04
# Epoch 21/100
# 128/128 [==============================] - ETA: 0s - loss: 0.1220 - accuracy: 0.9790 - precision: 0.9591 - recall: 0.9570 - auc: 0.9965
# Epoch 21: val_auc did not improve from 0.95538
# 128/128 [==============================] - 83s 652ms/step - loss: 0.1220 - accuracy: 0.9790 - precision: 0.9591 - recall: 0.9570 - auc: 0.9965 - val_loss: 0.9645 - val_accuracy: 0.8712 - val_precision: 0.7441 - val_recall: 0.7390 - val_auc: 0.9144 - lr: 5.0000e-04
# Epoch 22/100
# 128/128 [==============================] - ETA: 0s - loss: 0.1345 - accuracy: 0.9772 - precision: 0.9576 - recall: 0.9508 - auc: 0.9961
# Epoch 22: val_auc did not improve from 0.95538
# 128/128 [==============================] - 84s 652ms/step - loss: 0.1345 - accuracy: 0.9772 - precision: 0.9576 - recall: 0.9508 - auc: 0.9961 - val_loss: 0.8746 - val_accuracy: 0.8658 - val_precision: 0.7361 - val_recall: 0.7224 - val_auc: 0.9186 - lr: 5.0000e-04
# Epoch 23/100
# 128/128 [==============================] - ETA: 0s - loss: 0.1179 - accuracy: 0.9787 - precision: 0.9602 - recall: 0.9545 - auc: 0.9968
# Epoch 23: val_auc did not improve from 0.95538
# 128/128 [==============================] - 84s 652ms/step - loss: 0.1179 - accuracy: 0.9787 - precision: 0.9602 - recall: 0.9545 - auc: 0.9968 - val_loss: 0.9072 - val_accuracy: 0.8700 - val_precision: 0.7423 - val_recall: 0.7351 - val_auc: 0.9150 - lr: 5.0000e-04
# Epoch 24/100
# 128/128 [==============================] - ETA: 0s - loss: 0.1095 - accuracy: 0.9812 - precision: 0.9640 - recall: 0.9606 - auc: 0.9970
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 24: val_auc did not improve from 0.95538
# 128/128 [==============================] - 84s 653ms/step - loss: 0.1095 - accuracy: 0.9812 - precision: 0.9640 - recall: 0.9606 - auc: 0.9970 - val_loss: 0.8530 - val_accuracy: 0.8822 - val_precision: 0.7697 - val_recall: 0.7546 - val_auc: 0.9212 - lr: 5.0000e-04
# Epoch 25/100
# 128/128 [==============================] - ETA: 0s - loss: 0.0932 - accuracy: 0.9841 - precision: 0.9699 - recall: 0.9666 - auc: 0.9978
# Epoch 25: val_auc improved from 0.95538 to 0.97022, saving model to drive/MyDrive/Pammy_Alzheimers_Disease_Prediction/Visualisation/CustomCNN/CustomCNN.h5
# 128/128 [==============================] - 84s 658ms/step - loss: 0.0932 - accuracy: 0.9841 - precision: 0.9699 - recall: 0.9666 - auc: 0.9978 - val_loss: 0.4514 - val_accuracy: 0.9240 - val_precision: 0.8504 - val_recall: 0.8446 - val_auc: 0.9702 - lr: 2.5000e-04
# Epoch 26/100
# 128/128 [==============================] - ETA: 0s - loss: 0.0717 - accuracy: 0.9880 - precision: 0.9766 - recall: 0.9754 - auc: 0.9985
# Epoch 26: val_auc improved from 0.97022 to 0.97358, saving model to drive/MyDrive/Pammy_Alzheimers_Disease_Prediction/Visualisation/CustomCNN/CustomCNN.h5
# 128/128 [==============================] - 84s 660ms/step - loss: 0.0717 - accuracy: 0.9880 - precision: 0.9766 - recall: 0.9754 - auc: 0.9985 - val_loss: 0.3988 - val_accuracy: 0.9389 - val_precision: 0.8808 - val_recall: 0.8739 - val_auc: 0.9736 - lr: 2.5000e-04
# Epoch 27/100
# 128/128 [==============================] - ETA: 0s - loss: 0.0643 - accuracy: 0.9897 - precision: 0.9801 - recall: 0.9788 - auc: 0.9989
# Epoch 27: val_auc improved from 0.97358 to 0.97901, saving model to drive/MyDrive/Pammy_Alzheimers_Disease_Prediction/Visualisation/CustomCNN/CustomCNN.h5
# 128/128 [==============================] - 84s 658ms/step - loss: 0.0643 - accuracy: 0.9897 - precision: 0.9801 - recall: 0.9788 - auc: 0.9989 - val_loss: 0.3578 - val_accuracy: 0.9389 - val_precision: 0.8793 - val_recall: 0.8759 - val_auc: 0.9790 - lr: 2.5000e-04
# Epoch 28/100
# 128/128 [==============================] - ETA: 0s - loss: 0.0518 - accuracy: 0.9920 - precision: 0.9847 - recall: 0.9833 - auc: 0.9993
# Epoch 28: val_auc did not improve from 0.97901
# 128/128 [==============================] - 83s 652ms/step - loss: 0.0518 - accuracy: 0.9920 - precision: 0.9847 - recall: 0.9833 - auc: 0.9993 - val_loss: 0.5292 - val_accuracy: 0.9223 - val_precision: 0.8494 - val_recall: 0.8377 - val_auc: 0.9623 - lr: 2.5000e-04
# Epoch 29/100
# 128/128 [==============================] - ETA: 0s - loss: 0.0534 - accuracy: 0.9904 - precision: 0.9813 - recall: 0.9803 - auc: 0.9990
# Epoch 29: val_auc did not improve from 0.97901
# 128/128 [==============================] - 83s 652ms/step - loss: 0.0534 - accuracy: 0.9904 - precision: 0.9813 - recall: 0.9803 - auc: 0.9990 - val_loss: 0.3884 - val_accuracy: 0.9374 - val_precision: 0.8801 - val_recall: 0.8680 - val_auc: 0.9748 - lr: 2.5000e-04
# Epoch 30/100
# 128/128 [==============================] - ETA: 0s - loss: 0.0607 - accuracy: 0.9903 - precision: 0.9815 - recall: 0.9796 - auc: 0.9990
# Epoch 30: val_auc did not improve from 0.97901
# 128/128 [==============================] - 83s 652ms/step - loss: 0.0607 - accuracy: 0.9903 - precision: 0.9815 - recall: 0.9796 - auc: 0.9990 - val_loss: 0.8072 - val_accuracy: 0.8969 - val_precision: 0.7955 - val_recall: 0.7908 - val_auc: 0.9317 - lr: 2.5000e-04
# Epoch 31/100
# 128/128 [==============================] - ETA: 0s - loss: 0.0418 - accuracy: 0.9932 - precision: 0.9865 - recall: 0.9862 - auc: 0.9995
# Epoch 31: val_auc did not improve from 0.97901
# 128/128 [==============================] - 83s 652ms/step - loss: 0.0418 - accuracy: 0.9932 - precision: 0.9865 - recall: 0.9862 - auc: 0.9995 - val_loss: 0.5051 - val_accuracy: 0.9260 - val_precision: 0.8543 - val_recall: 0.8485 - val_auc: 0.9653 - lr: 2.5000e-04
# Epoch 32/100
# 128/128 [==============================] - ETA: 0s - loss: 0.0569 - accuracy: 0.9913 - precision: 0.9835 - recall: 0.9816 - auc: 0.9990
# Epoch 32: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 32: val_auc did not improve from 0.97901
# 128/128 [==============================] - 84s 652ms/step - loss: 0.0569 - accuracy: 0.9913 - precision: 0.9835 - recall: 0.9816 - auc: 0.9990 - val_loss: 0.3900 - val_accuracy: 0.9374 - val_precision: 0.8763 - val_recall: 0.8729 - val_auc: 0.9764 - lr: 2.5000e-04
# Epoch 33/100
# 128/128 [==============================] - ETA: 0s - loss: 0.0381 - accuracy: 0.9939 - precision: 0.9885 - recall: 0.9871 - auc: 0.9996
# Epoch 33: val_auc did not improve from 0.97901
# 128/128 [==============================] - 84s 656ms/step - loss: 0.0381 - accuracy: 0.9939 - precision: 0.9885 - recall: 0.9871 - auc: 0.9996 - val_loss: 0.3815 - val_accuracy: 0.9460 - val_precision: 0.8947 - val_recall: 0.8886 - val_auc: 0.9762 - lr: 1.2500e-04
# Epoch 34/100
# 128/128 [==============================] - ETA: 0s - loss: 0.0341 - accuracy: 0.9951 - precision: 0.9904 - recall: 0.9899 - auc: 0.9993
# Epoch 34: val_auc did not improve from 0.97901
# 128/128 [==============================] - 83s 652ms/step - loss: 0.0341 - accuracy: 0.9951 - precision: 0.9904 - recall: 0.9899 - auc: 0.9993 - val_loss: 0.5009 - val_accuracy: 0.9296 - val_precision: 0.8614 - val_recall: 0.8563 - val_auc: 0.9632 - lr: 1.2500e-04
# Epoch 35/100
# 128/128 [==============================] - ETA: 0s - loss: 0.0364 - accuracy: 0.9944 - precision: 0.9892 - recall: 0.9884 - auc: 0.9993
# Epoch 35: val_auc did not improve from 0.97901
# 128/128 [==============================] - 83s 652ms/step - loss: 0.0364 - accuracy: 0.9944 - precision: 0.9892 - recall: 0.9884 - auc: 0.9993 - val_loss: 0.4562 - val_accuracy: 0.9308 - val_precision: 0.8620 - val_recall: 0.8612 - val_auc: 0.9709 - lr: 1.2500e-04
# Epoch 36/100
# 128/128 [==============================] - ETA: 0s - loss: 0.0349 - accuracy: 0.9952 - precision: 0.9909 - recall: 0.9899 - auc: 0.9994
# Epoch 36: val_auc did not improve from 0.97901
# 128/128 [==============================] - 84s 652ms/step - loss: 0.0349 - accuracy: 0.9952 - precision: 0.9909 - recall: 0.9899 - auc: 0.9994 - val_loss: 0.3688 - val_accuracy: 0.9418 - val_precision: 0.8875 - val_recall: 0.8788 - val_auc: 0.9781 - lr: 1.2500e-04
# Epoch 37/100
# 128/128 [==============================] - ETA: 0s - loss: 0.0357 - accuracy: 0.9943 - precision: 0.9889 - recall: 0.9882 - auc: 0.9995
# Epoch 37: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 37: val_auc did not improve from 0.97901
# 128/128 [==============================] - 84s 653ms/step - loss: 0.0357 - accuracy: 0.9943 - precision: 0.9889 - recall: 0.9882 - auc: 0.9995 - val_loss: 0.5637 - val_accuracy: 0.9311 - val_precision: 0.8636 - val_recall: 0.8602 - val_auc: 0.9583 - lr: 1.2500e-04
# Epoch 38/100
# 128/128 [==============================] - ETA: 0s - loss: 0.0317 - accuracy: 0.9942 - precision: 0.9887 - recall: 0.9882 - auc: 0.9997
# Epoch 38: val_auc improved from 0.97901 to 0.97952, saving model to drive/MyDrive/Pammy_Alzheimers_Disease_Prediction/Visualisation/CustomCNN/CustomCNN.h5
# 128/128 [==============================] - 84s 659ms/step - loss: 0.0317 - accuracy: 0.9942 - precision: 0.9887 - recall: 0.9882 - auc: 0.9997 - val_loss: 0.3288 - val_accuracy: 0.9504 - val_precision: 0.9020 - val_recall: 0.8993 - val_auc: 0.9795 - lr: 6.2500e-05
# Epoch 39/100
# 128/128 [==============================] - ETA: 0s - loss: 0.0292 - accuracy: 0.9955 - precision: 0.9911 - recall: 0.9909 - auc: 0.9995
# Epoch 39: val_auc improved from 0.97952 to 0.97980, saving model to drive/MyDrive/Pammy_Alzheimers_Disease_Prediction/Visualisation/CustomCNN/CustomCNN.h5
# 128/128 [==============================] - 84s 658ms/step - loss: 0.0292 - accuracy: 0.9955 - precision: 0.9911 - recall: 0.9909 - auc: 0.9995 - val_loss: 0.3363 - val_accuracy: 0.9479 - val_precision: 0.8971 - val_recall: 0.8944 - val_auc: 0.9798 - lr: 6.2500e-05
# Epoch 40/100
# 128/128 [==============================] - ETA: 0s - loss: 0.0313 - accuracy: 0.9947 - precision: 0.9894 - recall: 0.9892 - auc: 0.9996
# Epoch 40: val_auc did not improve from 0.97980
# 128/128 [==============================] - 83s 652ms/step - loss: 0.0313 - accuracy: 0.9947 - precision: 0.9894 - recall: 0.9892 - auc: 0.9996 - val_loss: 0.3418 - val_accuracy: 0.9499 - val_precision: 0.9018 - val_recall: 0.8974 - val_auc: 0.9790 - lr: 6.2500e-05
# Epoch 41/100
# 128/128 [==============================] - ETA: 0s - loss: 0.0262 - accuracy: 0.9965 - precision: 0.9936 - recall: 0.9924 - auc: 0.9995
# Epoch 41: val_auc improved from 0.97980 to 0.98088, saving model to drive/MyDrive/Pammy_Alzheimers_Disease_Prediction/Visualisation/CustomCNN/CustomCNN.h5
# 128/128 [==============================] - 85s 661ms/step - loss: 0.0262 - accuracy: 0.9965 - precision: 0.9936 - recall: 0.9924 - auc: 0.9995 - val_loss: 0.3163 - val_accuracy: 0.9536 - val_precision: 0.9087 - val_recall: 0.9052 - val_auc: 0.9809 - lr: 6.2500e-05
# Epoch 42/100
# 128/128 [==============================] - ETA: 0s - loss: 0.0215 - accuracy: 0.9967 - precision: 0.9936 - recall: 0.9931 - auc: 0.9997
# Epoch 42: val_auc did not improve from 0.98088
# 128/128 [==============================] - 83s 652ms/step - loss: 0.0215 - accuracy: 0.9967 - precision: 0.9936 - recall: 0.9931 - auc: 0.9997 - val_loss: 0.3918 - val_accuracy: 0.9433 - val_precision: 0.8889 - val_recall: 0.8837 - val_auc: 0.9751 - lr: 6.2500e-05
# Epoch 43/100
# 128/128 [==============================] - ETA: 0s - loss: 0.0280 - accuracy: 0.9955 - precision: 0.9911 - recall: 0.9909 - auc: 0.9997
# Epoch 43: val_auc did not improve from 0.98088
# 128/128 [==============================] - 83s 652ms/step - loss: 0.0280 - accuracy: 0.9955 - precision: 0.9911 - recall: 0.9909 - auc: 0.9997 - val_loss: 0.3834 - val_accuracy: 0.9426 - val_precision: 0.8870 - val_recall: 0.8827 - val_auc: 0.9758 - lr: 6.2500e-05
# Epoch 44/100
# 128/128 [==============================] - ETA: 0s - loss: 0.0206 - accuracy: 0.9962 - precision: 0.9926 - recall: 0.9924 - auc: 0.9998
# Epoch 44: val_auc improved from 0.98088 to 0.98127, saving model to drive/MyDrive/Pammy_Alzheimers_Disease_Prediction/Visualisation/CustomCNN/CustomCNN.h5
# 128/128 [==============================] - 85s 660ms/step - loss: 0.0206 - accuracy: 0.9962 - precision: 0.9926 - recall: 0.9924 - auc: 0.9998 - val_loss: 0.3188 - val_accuracy: 0.9560 - val_precision: 0.9128 - val_recall: 0.9110 - val_auc: 0.9813 - lr: 6.2500e-05
# Epoch 45/100
# 128/128 [==============================] - ETA: 0s - loss: 0.0239 - accuracy: 0.9956 - precision: 0.9916 - recall: 0.9909 - auc: 0.9999
# Epoch 45: val_auc did not improve from 0.98127
# 128/128 [==============================] - 84s 652ms/step - loss: 0.0239 - accuracy: 0.9956 - precision: 0.9916 - recall: 0.9909 - auc: 0.9999 - val_loss: 0.3576 - val_accuracy: 0.9497 - val_precision: 0.9017 - val_recall: 0.8964 - val_auc: 0.9775 - lr: 6.2500e-05
# Epoch 46/100
# 128/128 [==============================] - ETA: 0s - loss: 0.0251 - accuracy: 0.9961 - precision: 0.9924 - recall: 0.9919 - auc: 0.9995
# Epoch 46: val_auc improved from 0.98127 to 0.98262, saving model to drive/MyDrive/Pammy_Alzheimers_Disease_Prediction/Visualisation/CustomCNN/CustomCNN.h5
# 128/128 [==============================] - 84s 658ms/step - loss: 0.0251 - accuracy: 0.9961 - precision: 0.9924 - recall: 0.9919 - auc: 0.9995 - val_loss: 0.3078 - val_accuracy: 0.9536 - val_precision: 0.9087 - val_recall: 0.9052 - val_auc: 0.9826 - lr: 6.2500e-05
# Epoch 47/100
# 128/128 [==============================] - ETA: 0s - loss: 0.0234 - accuracy: 0.9969 - precision: 0.9941 - recall: 0.9936 - auc: 0.9996
# Epoch 47: val_auc did not improve from 0.98262
# 128/128 [==============================] - 84s 652ms/step - loss: 0.0234 - accuracy: 0.9969 - precision: 0.9941 - recall: 0.9936 - auc: 0.9996 - val_loss: 0.3544 - val_accuracy: 0.9484 - val_precision: 0.8996 - val_recall: 0.8935 - val_auc: 0.9776 - lr: 6.2500e-05
# Epoch 48/100
# 128/128 [==============================] - ETA: 0s - loss: 0.0190 - accuracy: 0.9975 - precision: 0.9956 - recall: 0.9946 - auc: 0.9999
# Epoch 48: val_auc did not improve from 0.98262
# 128/128 [==============================] - 83s 651ms/step - loss: 0.0190 - accuracy: 0.9975 - precision: 0.9956 - recall: 0.9946 - auc: 0.9999 - val_loss: 0.3796 - val_accuracy: 0.9431 - val_precision: 0.8865 - val_recall: 0.8856 - val_auc: 0.9790 - lr: 6.2500e-05
# Epoch 49/100
# 128/128 [==============================] - ETA: 0s - loss: 0.0277 - accuracy: 0.9956 - precision: 0.9914 - recall: 0.9911 - auc: 0.9994
# Epoch 49: val_auc did not improve from 0.98262
# 128/128 [==============================] - 84s 652ms/step - loss: 0.0277 - accuracy: 0.9956 - precision: 0.9914 - recall: 0.9911 - auc: 0.9994 - val_loss: 0.3967 - val_accuracy: 0.9426 - val_precision: 0.8863 - val_recall: 0.8837 - val_auc: 0.9746 - lr: 6.2500e-05
# Epoch 50/100
# 128/128 [==============================] - ETA: 0s - loss: 0.0228 - accuracy: 0.9962 - precision: 0.9926 - recall: 0.9924 - auc: 0.9996
# Epoch 50: val_auc did not improve from 0.98262
# 128/128 [==============================] - 83s 652ms/step - loss: 0.0228 - accuracy: 0.9962 - precision: 0.9926 - recall: 0.9924 - auc: 0.9996 - val_loss: 0.3924 - val_accuracy: 0.9411 - val_precision: 0.8826 - val_recall: 0.8817 - val_auc: 0.9759 - lr: 6.2500e-05
# Epoch 51/100
# 128/128 [==============================] - ETA: 0s - loss: 0.0283 - accuracy: 0.9965 - precision: 0.9931 - recall: 0.9929 - auc: 0.9994
# Epoch 51: ReduceLROnPlateau reducing learning rate to 5e-05.
#
# Epoch 51: val_auc did not improve from 0.98262
# 128/128 [==============================] - 83s 651ms/step - loss: 0.0283 - accuracy: 0.9965 - precision: 0.9931 - recall: 0.9929 - auc: 0.9994 - val_loss: 0.3420 - val_accuracy: 0.9536 - val_precision: 0.9095 - val_recall: 0.9042 - val_auc: 0.9802 - lr: 6.2500e-05
# Epoch 52/100
# 128/128 [==============================] - ETA: 0s - loss: 0.0224 - accuracy: 0.9966 - precision: 0.9934 - recall: 0.9931 - auc: 0.9996
# Epoch 52: val_auc did not improve from 0.98262
# 128/128 [==============================] - 84s 653ms/step - loss: 0.0224 - accuracy: 0.9966 - precision: 0.9934 - recall: 0.9931 - auc: 0.9996 - val_loss: 0.3414 - val_accuracy: 0.9511 - val_precision: 0.9030 - val_recall: 0.9013 - val_auc: 0.9798 - lr: 5.0000e-05
# Epoch 53/100
# 128/128 [==============================] - ETA: 0s - loss: 0.0248 - accuracy: 0.9961 - precision: 0.9924 - recall: 0.9921 - auc: 0.9996
# Epoch 53: val_auc did not improve from 0.98262
# 128/128 [==============================] - 83s 652ms/step - loss: 0.0248 - accuracy: 0.9961 - precision: 0.9924 - recall: 0.9921 - auc: 0.9996 - val_loss: 0.3434 - val_accuracy: 0.9489 - val_precision: 0.8990 - val_recall: 0.8964 - val_auc: 0.9798 - lr: 5.0000e-05
# Epoch 54/100
# 128/128 [==============================] - ETA: 0s - loss: 0.0171 - accuracy: 0.9968 - precision: 0.9936 - recall: 0.9936 - auc: 0.9998
# Epoch 54: val_auc did not improve from 0.98262
# 128/128 [==============================] - 84s 652ms/step - loss: 0.0171 - accuracy: 0.9968 - precision: 0.9936 - recall: 0.9936 - auc: 0.9998 - val_loss: 0.3915 - val_accuracy: 0.9470 - val_precision: 0.8951 - val_recall: 0.8925 - val_auc: 0.9761 - lr: 5.0000e-05
# Epoch 55/100
# 128/128 [==============================] - ETA: 0s - loss: 0.0258 - accuracy: 0.9966 - precision: 0.9931 - recall: 0.9931 - auc: 0.9994
# Epoch 55: val_auc did not improve from 0.98262
# 128/128 [==============================] - 83s 652ms/step - loss: 0.0258 - accuracy: 0.9966 - precision: 0.9931 - recall: 0.9931 - auc: 0.9994 - val_loss: 0.3533 - val_accuracy: 0.9516 - val_precision: 0.9048 - val_recall: 0.9013 - val_auc: 0.9787 - lr: 5.0000e-05
# Epoch 56/100
# 128/128 [==============================] - ETA: 0s - loss: 0.0197 - accuracy: 0.9973 - precision: 0.9948 - recall: 0.9943 - auc: 0.9995
# Epoch 56: val_auc did not improve from 0.98262
# 128/128 [==============================] - 84s 652ms/step - loss: 0.0197 - accuracy: 0.9973 - precision: 0.9948 - recall: 0.9943 - auc: 0.9995 - val_loss: 0.3651 - val_accuracy: 0.9484 - val_precision: 0.8988 - val_recall: 0.8944 - val_auc: 0.9785 - lr: 5.0000e-05
# Epoch 57/100
# 128/128 [==============================] - ETA: 0s - loss: 0.0210 - accuracy: 0.9962 - precision: 0.9926 - recall: 0.9924 - auc: 0.9998
# Epoch 57: val_auc improved from 0.98262 to 0.98389, saving model to drive/MyDrive/Pammy_Alzheimers_Disease_Prediction/Visualisation/CustomCNN/CustomCNN.h5
# 128/128 [==============================] - 84s 659ms/step - loss: 0.0210 - accuracy: 0.9962 - precision: 0.9926 - recall: 0.9924 - auc: 0.9998 - val_loss: 0.3035 - val_accuracy: 0.9575 - val_precision: 0.9150 - val_recall: 0.9150 - val_auc: 0.9839 - lr: 5.0000e-05
# Epoch 58/100
# 128/128 [==============================] - ETA: 0s - loss: 0.0144 - accuracy: 0.9974 - precision: 0.9948 - recall: 0.9946 - auc: 1.0000
# Epoch 58: val_auc did not improve from 0.98389
# 128/128 [==============================] - 83s 652ms/step - loss: 0.0144 - accuracy: 0.9974 - precision: 0.9948 - recall: 0.9946 - auc: 1.0000 - val_loss: 0.3365 - val_accuracy: 0.9504 - val_precision: 0.9012 - val_recall: 0.9003 - val_auc: 0.9810 - lr: 5.0000e-05
# Epoch 59/100
# 128/128 [==============================] - ETA: 0s - loss: 0.0177 - accuracy: 0.9974 - precision: 0.9951 - recall: 0.9946 - auc: 0.9999
# Epoch 59: val_auc did not improve from 0.98389
# 128/128 [==============================] - 84s 652ms/step - loss: 0.0177 - accuracy: 0.9974 - precision: 0.9951 - recall: 0.9946 - auc: 0.9999 - val_loss: 0.3903 - val_accuracy: 0.9475 - val_precision: 0.8961 - val_recall: 0.8935 - val_auc: 0.9750 - lr: 5.0000e-05
# Epoch 60/100
# 128/128 [==============================] - ETA: 0s - loss: 0.0252 - accuracy: 0.9965 - precision: 0.9931 - recall: 0.9929 - auc: 0.9996
# Epoch 60: val_auc did not improve from 0.98389
# 128/128 [==============================] - 83s 652ms/step - loss: 0.0252 - accuracy: 0.9965 - precision: 0.9931 - recall: 0.9929 - auc: 0.9996 - val_loss: 0.3393 - val_accuracy: 0.9543 - val_precision: 0.9098 - val_recall: 0.9071 - val_auc: 0.9806 - lr: 5.0000e-05
# Epoch 61/100
# 128/128 [==============================] - ETA: 0s - loss: 0.0237 - accuracy: 0.9962 - precision: 0.9926 - recall: 0.9921 - auc: 0.9998
# Epoch 61: val_auc did not improve from 0.98389
# 128/128 [==============================] - 84s 652ms/step - loss: 0.0237 - accuracy: 0.9962 - precision: 0.9926 - recall: 0.9921 - auc: 0.9998 - val_loss: 0.3453 - val_accuracy: 0.9528 - val_precision: 0.9061 - val_recall: 0.9052 - val_auc: 0.9799 - lr: 5.0000e-05
# Epoch 62/100
# 128/128 [==============================] - ETA: 0s - loss: 0.0212 - accuracy: 0.9964 - precision: 0.9931 - recall: 0.9926 - auc: 0.9998
# Epoch 62: val_auc did not improve from 0.98389
# 128/128 [==============================] - 83s 652ms/step - loss: 0.0212 - accuracy: 0.9964 - precision: 0.9931 - recall: 0.9926 - auc: 0.9998 - val_loss: 0.3501 - val_accuracy: 0.9519 - val_precision: 0.9049 - val_recall: 0.9022 - val_auc: 0.9793 - lr: 5.0000e-05
# Epoch 63/100
# 128/128 [==============================] - ETA: 0s - loss: 0.0198 - accuracy: 0.9970 - precision: 0.9941 - recall: 0.9941 - auc: 0.9998
# Epoch 63: val_auc did not improve from 0.98389
# 128/128 [==============================] - 84s 653ms/step - loss: 0.0198 - accuracy: 0.9970 - precision: 0.9941 - recall: 0.9941 - auc: 0.9998 - val_loss: 0.3393 - val_accuracy: 0.9536 - val_precision: 0.9095 - val_recall: 0.9042 - val_auc: 0.9811 - lr: 5.0000e-05
# Epoch 64/100
# 128/128 [==============================] - ETA: 0s - loss: 0.0225 - accuracy: 0.9967 - precision: 0.9936 - recall: 0.9931 - auc: 0.9996
# Epoch 64: val_auc did not improve from 0.98389
# 128/128 [==============================] - 84s 652ms/step - loss: 0.0225 - accuracy: 0.9967 - precision: 0.9936 - recall: 0.9931 - auc: 0.9996 - val_loss: 0.3204 - val_accuracy: 0.9550 - val_precision: 0.9109 - val_recall: 0.9091 - val_auc: 0.9815 - lr: 5.0000e-05
# Epoch 65/100
# 128/128 [==============================] - ETA: 0s - loss: 0.0238 - accuracy: 0.9948 - precision: 0.9899 - recall: 0.9892 - auc: 0.9997
# Epoch 65: val_auc did not improve from 0.98389
# 128/128 [==============================] - 83s 652ms/step - loss: 0.0238 - accuracy: 0.9948 - precision: 0.9899 - recall: 0.9892 - auc: 0.9997 - val_loss: 0.3426 - val_accuracy: 0.9506 - val_precision: 0.9021 - val_recall: 0.9003 - val_auc: 0.9796 - lr: 5.0000e-05
# Epoch 66/100
# 128/128 [==============================] - ETA: 0s - loss: 0.0140 - accuracy: 0.9981 - precision: 0.9963 - recall: 0.9961 - auc: 0.9998
# Epoch 66: val_auc did not improve from 0.98389
# 128/128 [==============================] - 84s 652ms/step - loss: 0.0140 - accuracy: 0.9981 - precision: 0.9963 - recall: 0.9961 - auc: 0.9998 - val_loss: 0.3297 - val_accuracy: 0.9570 - val_precision: 0.9156 - val_recall: 0.9120 - val_auc: 0.9805 - lr: 5.0000e-05
# Epoch 67/100
# 128/128 [==============================] - ETA: 0s - loss: 0.0241 - accuracy: 0.9961 - precision: 0.9924 - recall: 0.9921 - auc: 0.9997
# Epoch 67: val_auc did not improve from 0.98389
# 128/128 [==============================] - 84s 653ms/step - loss: 0.0241 - accuracy: 0.9961 - precision: 0.9924 - recall: 0.9921 - auc: 0.9997 - val_loss: 0.3580 - val_accuracy: 0.9528 - val_precision: 0.9069 - val_recall: 0.9042 - val_auc: 0.9771 - lr: 5.0000e-05
# Epoch 68/100
# 128/128 [==============================] - ETA: 0s - loss: 0.0186 - accuracy: 0.9969 - precision: 0.9941 - recall: 0.9936 - auc: 0.9995
# Epoch 68: val_auc improved from 0.98389 to 0.98464, saving model to drive/MyDrive/Pammy_Alzheimers_Disease_Prediction/Visualisation/CustomCNN/CustomCNN.h5
# 128/128 [==============================] - 84s 657ms/step - loss: 0.0186 - accuracy: 0.9969 - precision: 0.9941 - recall: 0.9936 - auc: 0.9995 - val_loss: 0.2765 - val_accuracy: 0.9638 - val_precision: 0.9285 - val_recall: 0.9267 - val_auc: 0.9846 - lr: 5.0000e-05
# Epoch 69/100
# 128/128 [==============================] - ETA: 0s - loss: 0.0198 - accuracy: 0.9974 - precision: 0.9948 - recall: 0.9946 - auc: 0.9995
# Epoch 69: val_auc did not improve from 0.98464
# 128/128 [==============================] - 83s 652ms/step - loss: 0.0198 - accuracy: 0.9974 - precision: 0.9948 - recall: 0.9946 - auc: 0.9995 - val_loss: 0.3791 - val_accuracy: 0.9501 - val_precision: 0.9019 - val_recall: 0.8983 - val_auc: 0.9779 - lr: 5.0000e-05
# Epoch 70/100
# 128/128 [==============================] - ETA: 0s - loss: 0.0185 - accuracy: 0.9974 - precision: 0.9948 - recall: 0.9948 - auc: 0.9999
# Epoch 70: val_auc did not improve from 0.98464
# 128/128 [==============================] - 83s 652ms/step - loss: 0.0185 - accuracy: 0.9974 - precision: 0.9948 - recall: 0.9948 - auc: 0.9999 - val_loss: 0.3555 - val_accuracy: 0.9519 - val_precision: 0.9049 - val_recall: 0.9022 - val_auc: 0.9795 - lr: 5.0000e-05
# Epoch 71/100
# 128/128 [==============================] - ETA: 0s - loss: 0.0140 - accuracy: 0.9974 - precision: 0.9948 - recall: 0.9946 - auc: 1.0000
# Epoch 71: val_auc did not improve from 0.98464
# 128/128 [==============================] - 83s 652ms/step - loss: 0.0140 - accuracy: 0.9974 - precision: 0.9948 - recall: 0.9946 - auc: 1.0000 - val_loss: 0.3416 - val_accuracy: 0.9572 - val_precision: 0.9149 - val_recall: 0.9140 - val_auc: 0.9790 - lr: 5.0000e-05
# Epoch 72/100
# 128/128 [==============================] - ETA: 0s - loss: 0.0252 - accuracy: 0.9959 - precision: 0.9921 - recall: 0.9916 - auc: 0.9993
# Epoch 72: val_auc did not improve from 0.98464
# 128/128 [==============================] - 83s 652ms/step - loss: 0.0252 - accuracy: 0.9959 - precision: 0.9921 - recall: 0.9916 - auc: 0.9993 - val_loss: 0.3868 - val_accuracy: 0.9489 - val_precision: 0.8982 - val_recall: 0.8974 - val_auc: 0.9756 - lr: 5.0000e-05
# Epoch 73/100
# 128/128 [==============================] - ETA: 0s - loss: 0.0159 - accuracy: 0.9975 - precision: 0.9951 - recall: 0.9948 - auc: 0.9996
# Epoch 73: val_auc did not improve from 0.98464
# 128/128 [==============================] - 83s 652ms/step - loss: 0.0159 - accuracy: 0.9975 - precision: 0.9951 - recall: 0.9948 - auc: 0.9996 - val_loss: 0.3640 - val_accuracy: 0.9492 - val_precision: 0.8991 - val_recall: 0.8974 - val_auc: 0.9782 - lr: 5.0000e-05
# Epoch 74/100
# 128/128 [==============================] - ETA: 0s - loss: 0.0191 - accuracy: 0.9967 - precision: 0.9936 - recall: 0.9931 - auc: 0.9996
# Epoch 74: val_auc did not improve from 0.98464
# 128/128 [==============================] - 84s 653ms/step - loss: 0.0191 - accuracy: 0.9967 - precision: 0.9936 - recall: 0.9931 - auc: 0.9996 - val_loss: 0.3703 - val_accuracy: 0.9509 - val_precision: 0.9022 - val_recall: 0.9013 - val_auc: 0.9775 - lr: 5.0000e-05
# Epoch 75/100
# 128/128 [==============================] - ETA: 0s - loss: 0.0217 - accuracy: 0.9968 - precision: 0.9938 - recall: 0.9934 - auc: 0.9996
# Epoch 75: val_auc did not improve from 0.98464
# 128/128 [==============================] - 84s 652ms/step - loss: 0.0217 - accuracy: 0.9968 - precision: 0.9938 - recall: 0.9934 - auc: 0.9996 - val_loss: 0.3962 - val_accuracy: 0.9433 - val_precision: 0.8866 - val_recall: 0.8866 - val_auc: 0.9770 - lr: 5.0000e-05
# Epoch 76/100
# 128/128 [==============================] - ETA: 0s - loss: 0.0097 - accuracy: 0.9988 - precision: 0.9975 - recall: 0.9975 - auc: 1.0000
# Epoch 76: val_auc did not improve from 0.98464
# 128/128 [==============================] - 83s 651ms/step - loss: 0.0097 - accuracy: 0.9988 - precision: 0.9975 - recall: 0.9975 - auc: 1.0000 - val_loss: 0.3308 - val_accuracy: 0.9570 - val_precision: 0.9148 - val_recall: 0.9130 - val_auc: 0.9801 - lr: 5.0000e-05
# Epoch 77/100
# 128/128 [==============================] - ETA: 0s - loss: 0.0179 - accuracy: 0.9970 - precision: 0.9941 - recall: 0.9939 - auc: 0.9996
# Epoch 77: val_auc did not improve from 0.98464
# 128/128 [==============================] - 84s 652ms/step - loss: 0.0179 - accuracy: 0.9970 - precision: 0.9941 - recall: 0.9939 - auc: 0.9996 - val_loss: 0.3478 - val_accuracy: 0.9550 - val_precision: 0.9117 - val_recall: 0.9081 - val_auc: 0.9797 - lr: 5.0000e-05
# Epoch 78/100
# 128/128 [==============================] - ETA: 0s - loss: 0.0139 - accuracy: 0.9978 - precision: 0.9958 - recall: 0.9956 - auc: 1.0000
# Epoch 78: val_auc did not improve from 0.98464
# 128/128 [==============================] - 83s 652ms/step - loss: 0.0139 - accuracy: 0.9978 - precision: 0.9958 - recall: 0.9956 - auc: 1.0000 - val_loss: 0.3461 - val_accuracy: 0.9533 - val_precision: 0.9070 - val_recall: 0.9062 - val_auc: 0.9805 - lr: 5.0000e-05
# Epoch 79/100
# 128/128 [==============================] - ETA: 0s - loss: 0.0081 - accuracy: 0.9988 - precision: 0.9976 - recall: 0.9976 - auc: 1.0000
# Epoch 79: val_auc did not improve from 0.98464
# 128/128 [==============================] - 84s 657ms/step - loss: 0.0081 - accuracy: 0.9988 - precision: 0.9976 - recall: 0.9976 - auc: 1.0000 - val_loss: 0.4033 - val_accuracy: 0.9467 - val_precision: 0.8950 - val_recall: 0.8915 - val_auc: 0.9745 - lr: 5.0000e-05
# Epoch 80/100
# 128/128 [==============================] - ETA: 0s - loss: 0.0160 - accuracy: 0.9980 - precision: 0.9961 - recall: 0.9961 - auc: 0.9995
# Epoch 80: val_auc did not improve from 0.98464
# 128/128 [==============================] - 83s 652ms/step - loss: 0.0160 - accuracy: 0.9980 - precision: 0.9961 - recall: 0.9961 - auc: 0.9995 - val_loss: 0.3421 - val_accuracy: 0.9558 - val_precision: 0.9119 - val_recall: 0.9110 - val_auc: 0.9787 - lr: 5.0000e-05
# Epoch 81/100
# 128/128 [==============================] - ETA: 0s - loss: 0.0215 - accuracy: 0.9969 - precision: 0.9941 - recall: 0.9936 - auc: 0.9993
# Epoch 81: val_auc did not improve from 0.98464
# 128/128 [==============================] - 83s 652ms/step - loss: 0.0215 - accuracy: 0.9969 - precision: 0.9941 - recall: 0.9936 - auc: 0.9993 - val_loss: 0.3688 - val_accuracy: 0.9538 - val_precision: 0.9080 - val_recall: 0.9071 - val_auc: 0.9769 - lr: 5.0000e-05
# Epoch 82/100
# 128/128 [==============================] - ETA: 0s - loss: 0.0186 - accuracy: 0.9969 - precision: 0.9941 - recall: 0.9937 - auc: 0.9998
# Epoch 82: val_auc did not improve from 0.98464
# 128/128 [==============================] - 84s 656ms/step - loss: 0.0186 - accuracy: 0.9969 - precision: 0.9941 - recall: 0.9937 - auc: 0.9998 - val_loss: 0.3415 - val_accuracy: 0.9560 - val_precision: 0.9136 - val_recall: 0.9101 - val_auc: 0.9798 - lr: 5.0000e-05
# Epoch 83/100
# 128/128 [==============================] - ETA: 0s - loss: 0.0073 - accuracy: 0.9989 - precision: 0.9978 - recall: 0.9978 - auc: 1.0000Restoring model weights from the end of the best epoch: 68.
#
# Epoch 83: val_auc did not improve from 0.98464
# 128/128 [==============================] - 83s 652ms/step - loss: 0.0073 - accuracy: 0.9989 - precision: 0.9978 - recall: 0.9978 - auc: 1.0000 - val_loss: 0.3373 - val_accuracy: 0.9587 - val_precision: 0.9186 - val_recall: 0.9159 - val_auc: 0.9801 - lr: 5.0000e-05
# Epoch 83: early stopping

# %% [markdown]
# ### Plot

# %%
path = "CustomCNN/loss_acc_2.png"
title = " MODEL'S METRICS VISUALIZATION : Fine Tuning "
Eval_Plot(
    Custom_CNN_history.history['accuracy'],Custom_CNN_history.history['val_accuracy'],
    Custom_CNN_history.history['loss'],Custom_CNN_history.history['val_loss'],
    Custom_CNN_history.history['auc'],Custom_CNN_history.history['val_auc'],
    Custom_CNN_history.history['precision'],Custom_CNN_history.history['val_precision'],
    path, title
)

# %%
predictions = Custom_CNN.predict(testing_data) 
y_pred = predictions.argmax(axis = -1)
y_label = testing_data.labels.copy()
class_Names = list(testing_data.class_indices.keys())

# %%
assert y_pred.shape == y_label.shape

# %%
Confusion_Matrix_Heatmap(y_label, y_pred, class_Names, f"CustomCNN/HeatMap.jpeg", "Custom_CNN")

# %% [markdown]
# ### Scores

# %%
scores_Custom_CNN = Custom_CNN.evaluate(testing_data)
# Out:
# 40/40 [==============================] - 5s 124ms/step - loss: 1.3923 - accuracy: 0.8628 - precision: 0.7281 - recall: 0.7201 - auc: 0.8856

# %%
print(f"Accuracy in test set  : {scores_Custom_CNN[1]}")
print(f"Precision in test set : {scores_Custom_CNN[2]}")
print(f"Recall in test set    : {scores_Custom_CNN[3]}")
print(f"AUC in test set       : {scores_Custom_CNN[4]}")
# Out:
# Accuracy in test set  : 0.8627834320068359
# Precision in test set : 0.7280632257461548
# Recall in test set    : 0.720093846321106
# AUC in test set       : 0.8856478929519653

# %%
import pandas as pd
Scores = pd.DataFrame([scores_Custom_CNN], columns = ["Loss", "Test Accuracy", "Precision", "Recall", "AUC"])
Scores
# Out:
#        Loss  Test Accuracy  Precision    Recall       AUC
# 0  1.392284       0.862783   0.728063  0.720094  0.885648

# %%
Scores.to_csv(f"{Save}CustomCNN/score.csv")

# %% [markdown]
# # GradCam, activation Visualisation

# %%
# Display
from IPython.display import Image, display
import matplotlib.pyplot as plt
import matplotlib.cm as cm

# %% [markdown]
# ## Configurable parameters

# %%
Custom_CNN.summary()
# Out:
# Model: "cnn_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 256, 256, 128)     3584
#
#  conv2d_1 (Conv2D)           (None, 256, 256, 128)     147584
#
#  max_pooling2d (MaxPooling2D  (None, 128, 128, 128)    0
#  )
#
#  dropout (Dropout)           (None, 128, 128, 128)     0
#
#  sequential (Sequential)     (None, 64, 64, 256)       103296
#
#  dropout_1 (Dropout)         (None, 64, 64, 256)       0
#
#  sequential_1 (Sequential)   (None, 32, 32, 256)       137216
#
#  dropout_2 (Dropout)         (None, 32, 32, 256)       0
#
#  sequential_2 (Sequential)   (None, 16, 16, 256)       137216
#
#  dropout_3 (Dropout)         (None, 16, 16, 256)       0
#
#  flatten (Flatten)           (None, 65536)             0
#
#  sequential_3 (Sequential)   (None, 128)               8389248
#
#  sequential_4 (Sequential)   (None, 128)               17024
#
#  sequential_5 (Sequential)   (None, 64)                8512
#
#  dense_3 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 8,943,940
# Trainable params: 8,941,764
# Non-trainable params: 2,176
# _________________________________________________________________

# %%
for layer in Custom_CNN.get_layer("sequential_2").layers:
  print(layer.name)
# Out:
# separable_conv2d_4
# separable_conv2d_5
# batch_normalization_2
# max_pooling2d_3

# %%
last_sequential_layer = "sequential_2"
last_conv_layer_name = "conv2d_1"
X,y = testing_data.next()

# %%
X[3].shape
# Out:
# (256, 256, 3)

# %%
img_path = X[0].copy()
imshow(X[3])

# %%
def get_img_array(img_path, size):
    # `img` is a PIL image of size 299x299
    img = keras.preprocessing.image.load_img(img_path, target_size=size)
    # `array` is a float32 Numpy array of shape (299, 299, 3)
    array = keras.preprocessing.image.img_to_array(img)
    # We add a dimension to transform our image array into a "batch"
    # of size (1, 299, 299, 3)
    array = np.expand_dims(array, axis=0)
    return array


def make_gradcam_heatmap(img_array, model, last_conv_layer_name, pred_index=None):
    # First, we create a model that maps the input image to the activations
    # of the last conv layer as well as the output predictions
    grad_model = tf.keras.models.Model(
        [model.inputs], [model.get_layer(last_conv_layer_name).output, model.output]
    )

    # Then, we compute the gradient of the top predicted class for our input image
    # with respect to the activations of the last conv layer
    with tf.GradientTape() as tape:
        last_conv_layer_output, preds = grad_model(img_array)
        if pred_index is None:
            pred_index = tf.argmax(preds[0])
        class_channel = preds[:, pred_index]

    # This is the gradient of the output neuron (top predicted or chosen)
    # with regard to the output feature map of the last conv layer
    grads = tape.gradient(class_channel, last_conv_layer_output)

    # This is a vector where each entry is the mean intensity of the gradient
    # over a specific feature map channel
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))

    # We multiply each channel in the feature map array
    # by "how important this channel is" with regard to the top predicted class
    # then sum all the channels to obtain the heatmap class activation
    last_conv_layer_output = last_conv_layer_output[0]
    heatmap = last_conv_layer_output @ pooled_grads[..., tf.newaxis]
    heatmap = tf.squeeze(heatmap)

    # For visualization purpose, we will also normalize the heatmap between 0 & 1
    heatmap = tf.maximum(heatmap, 0) / tf.math.reduce_max(heatmap)
    return heatmap.numpy()

def get_gradcam_img(img_path, heatmap, cam_path="cam.jpg", alpha=0.4):
    # Load the original image
    img = keras.preprocessing.image.load_img(img_path)
    img = keras.preprocessing.image.img_to_array(img)

    # Rescale heatmap to a range 0-255
    heatmap = np.uint8(255 * heatmap)

    # Use jet colormap to colorize heatmap
    jet = cm.get_cmap("jet")

    # Use RGB values of the colormap
    jet_colors = jet(np.arange(256))[:, :3]
    jet_heatmap = jet_colors[heatmap]

    # Create an image with RGB colorized heatmap
    jet_heatmap = keras.preprocessing.image.array_to_img(jet_heatmap)
    jet_heatmap = jet_heatmap.resize((img.shape[1], img.shape[0]))
    jet_heatmap = keras.preprocessing.image.img_to_array(jet_heatmap)

    # Superimpose the heatmap on original image
    superimposed_img = jet_heatmap * alpha + img
    superimposed_img = keras.preprocessing.image.array_to_img(superimposed_img)

    return superimposed_img

# %%
# Make model
model_load= keras.models.load_model(f"{Save}CustomCNN/CustomCNN.h5")

# Remove last layer's softmax
model_load.layers[-1].activation = None

# %%
class_Names = os.listdir(f"{test}").copy()
img_paths = []
for cls in class_Names:
  ClsPath2dir = f"{test}{cls}/"
  content = os.listdir(ClsPath2dir)
  imgPath = os.path.join(ClsPath2dir, np.random.choice(content))
  img_paths.append(imgPath)

img_paths
# Out:
# ['drive/MyDrive/Pammy_Alzheimers_Disease_Prediction/Dataset/Alzheimers_Dataset/test/ModerateDemented/31.jpg',
#  'drive/MyDrive/Pammy_Alzheimers_Disease_Prediction/Dataset/Alzheimers_Dataset/test/VeryMildDemented/31 (19).jpg',
#  'drive/MyDrive/Pammy_Alzheimers_Disease_Prediction/Dataset/Alzheimers_Dataset/test/NonDemented/30 (15).jpg',
#  'drive/MyDrive/Pammy_Alzheimers_Disease_Prediction/Dataset/Alzheimers_Dataset/test/MildDemented/32 (18).jpg']

# %%
fig, axs = plt.subplots(2, 2, figsize = (15,15))
for ax, path, label in zip(axs.flatten(), img_paths, class_Names): 
  # Prepare image
  img_arry = keras.layers.Rescaling(scale=1./255)(get_img_array(path, (Image_Size, Image_Size)))
  # Print what the top predicted class is
  preds = model_load.predict(img_arry)
  print(f"Predicted : {Ind2ClassName[int(preds.argmax(axis=-1).squeeze())]}")
  #print("Predicted:", decode_predictions(preds, top=1)[0])

  # Generate class activation heatmap
  heatmap = make_gradcam_heatmap(img_arry, model_load, last_conv_layer_name)

  # Get superImposed Image
  superimposed_img = get_gradcam_img(path, heatmap)
  ax.imshow(superimposed_img)
  ax.axis('off')
  ax.title.set_text(f"Predicted label : {Ind2ClassName[int(preds.argmax(axis=-1).squeeze())]} Actual : {label}")

plt.suptitle('Grad Cam Visualisation')
plt.savefig(f"{Save}CustomCNN/GradCam.jpg")
plt.show()
# Out:
# Predicted : VeryMildDemented
# Predicted : VeryMildDemented
# Predicted : VeryMildDemented
# Predicted : NonDemented
