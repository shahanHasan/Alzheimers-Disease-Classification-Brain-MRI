# %% [markdown]
# # Global PAth vars

# %%
#PATH 
base_path = "drive/MyDrive/Pammy_Alzheimers_Disease_Prediction/Dataset/Alzheimers_Dataset/"
train = f"{base_path}train/"
test = f"{base_path}test/"
Save = f"drive/MyDrive/Pammy_Alzheimers_Disease_Prediction/Visualisation/"


base_path_bin = "drive/MyDrive/Pammy_Alzheimers_Disease_Prediction/Dataset/Alzheimers_Dataset_Binary/"
train_bin = f"{base_path_bin}train/" 
test_bin = f"{base_path_bin}test/"
Save_bin = f"drive/MyDrive/Pammy_Alzheimers_Disease_Prediction/Visualisation/BinaryClassification/"

# %% [markdown]
# # Imports

# %%
import os, time

#arr operations
import numpy as np

# Progress Bar
from tqdm import tqdm

# Evaluation metrics
from sklearn import metrics
from sklearn.metrics import confusion_matrix, classification_report

#Importing Deep learning Libraries
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential, load_model
from keras.layers import InputLayer, BatchNormalization, Dropout, Flatten, Dense, Activation, MaxPool2D
from keras.layers import GlobalAveragePooling2D, Conv2D, MaxPooling2D
from keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler, Callback, ReduceLROnPlateau
from keras import optimizers, Input
from keras.utils.vis_utils import plot_model
from keras.applications.imagenet_utils import decode_predictions
import keras.backend as K


#Pretrained models
from keras.applications.xception import Xception
from keras.applications.inception_v3 import InceptionV3
from keras.applications.vgg16 import VGG16
from keras.applications.vgg19 import VGG19
from keras.applications.resnet import ResNet50
from keras.applications.resnet_v2 import ResNet152V2
#from keras.applications.resnet152_v2 import ResNet152V2


#Image read and show
import skimage.io
from skimage.io import imread, imshow
import matplotlib.pyplot as plt 
import seaborn as sns
sns.set_style('darkgrid')
#plt.style.use('fivethirtyeight')

#Metrics
from sklearn.metrics import f1_score , recall_score, accuracy_score, precision_score, confusion_matrix
from sklearn.metrics import roc_curve, auc, classification_report
from sklearn.preprocessing import label_binarize
from sklearn.multiclass import OneVsRestClassifier
from itertools import cycle

# %%
tf.__version__
# Out:
# '2.8.2'

# %% [markdown]
# # Utils Functions

# %%
def Confusion_Matrix_Heatmap(y_test,y_pred,class_Names, fName, ModelName):
    #Plot the confusion matrix to understand the classification in detail
    CM = confusion_matrix(y_test, y_pred)
    plt.figure(figsize=(10, 8), dpi=80, facecolor='w', edgecolor='k')
    ax = sns.heatmap(CM, cmap='Greens', annot=True, fmt='d', xticklabels=class_Names, yticklabels=class_Names)
    plt.title(f'Alzheimer\'s Disease Diagnosis - {ModelName}')
    plt.xlabel('Prediction')
    plt.ylabel('Truth')
    plt.savefig(f"{Save}{fName}")
    #plt.show(ax)

# Plot Evaluation Metrics
sns.set_style('darkgrid')
#plt.style.use('fivethirtyeight')
def Eval_Plot(acc,val_acc, loss,val_loss, auc, val_auc, precision, val_precision, path, title):
    
    fig, (ax1,ax2,ax3,ax4) = plt.subplots(1,4, figsize= (20,5))
    fig.suptitle(f"{title}\n", fontsize = 15)

    ax1.plot(range(1, len(acc) + 1), acc)
    ax1.plot(range(1, len(val_acc) + 1), val_acc)
    ax1.set_title('History of Accuracy', fontsize = 15)
    ax1.set_xlabel('Epochs', fontsize = 15)
    ax1.set_ylabel('Accuracy', fontsize = 15)
    ax1.legend(['Training', 'Validation'], fontsize = 15)


    ax2.plot(range(1, len(loss) + 1), loss)
    ax2.plot(range(1, len(val_loss) + 1), val_loss)
    ax2.set_title('History of Loss', fontsize = 15)
    ax2.set_xlabel('Epochs', fontsize = 15)
    ax2.set_ylabel('Loss', fontsize = 15)
    ax2.legend(['Training', 'Validation'], fontsize = 15)

    ax3.plot(range(1, len(auc) + 1), auc)
    ax3.plot(range(1, len(val_auc) + 1), val_auc)
    ax3.set_title('History of AUC', fontsize = 15)
    ax3.set_xlabel('Epochs', fontsize = 15)
    ax3.set_ylabel('AUC', fontsize = 15)
    ax3.legend(['Training', 'Validation'], fontsize = 15)
    
    ax4.plot(range(1, len(precision) + 1), precision)
    ax4.plot(range(1, len(val_precision) + 1), val_precision)
    ax4.set_title('History of Precision', fontsize = 15)
    ax4.set_xlabel('Epochs', fontsize = 15)
    ax4.set_ylabel('Precision', fontsize = 15)
    ax4.legend(['Training', 'Validation'], fontsize = 15)

    plt.savefig(f"{Save}{path}")
    #plt.show()

def freeze_BN(model):
  """
  Unfreeze all layers except BatchNorm
  """
  for layer in model.layers:
    if isinstance(layer, BatchNormalization):
      layer.trainable = False

# %% [markdown]
# # Model Building

# %% [markdown]
# ## Set Seed

# %%
Seed = 29
Batch_Size = 32
Image_Size = 299
np.random.seed(Seed)
tf.random.set_seed(Seed)

# %% [markdown]
# ## GPU Test

# %%
# GPU
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %% [markdown]
# # MULTICLASS CLASSIFICATION MODELS

# %% [markdown]
# ## Data Generator

# %%
# Image data generator
training_data_gen = ImageDataGenerator(
    validation_split = 0.2,
    preprocessing_function=keras.applications.xception.preprocess_input,           
    )

testing_data_gen = ImageDataGenerator(        
    preprocessing_function=keras.applications.xception.preprocess_input,           
    )

validation_data_gen = ImageDataGenerator(
    preprocessing_function=keras.applications.xception.preprocess_input,
    validation_split = 0.2
    )

# %% [markdown]
# ## Splitting the Data

# %%
training_data = training_data_gen.flow_from_directory(
    directory= train,
    target_size = (Image_Size,Image_Size),
    class_mode = 'categorical',
    color_mode  = 'rgb', 
    subset = 'training',
    seed = Seed,
    batch_size = Batch_Size)

validation_data = validation_data_gen.flow_from_directory(
  directory = train,
  target_size = (Image_Size,Image_Size),
  class_mode = 'categorical',
  color_mode  = 'rgb', 
  subset = 'validation',
  seed = Seed,
  batch_size = Batch_Size)

testing_data =  testing_data_gen.flow_from_directory(
  directory = test,
  target_size = (Image_Size,Image_Size),
  class_mode = 'categorical',
  color_mode  = 'rgb', 
  seed = Seed,
  batch_size = Batch_Size
)
# Out:
# Found 4098 images belonging to 4 classes.
# Found 1023 images belonging to 4 classes.
# Found 1279 images belonging to 4 classes.

# %%
ClassName2Ind = (training_data.class_indices)
Ind2ClassName = {v: k for k, v in ClassName2Ind.items()}
X,y = training_data.next()

# %%
imshow(X[0])
plt.title(Ind2ClassName[np.argmax(y[0],axis=0)])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Text(0.5, 1.0, 'NonDemented')

# %%
steps_per_epoch = training_data.n // training_data.batch_size
print('steps per epoch: ',steps_per_epoch)
# Out:
# steps per epoch:  128

# %%
assert len(training_data) > 5, "Less Than 5 Batches"
assert len(validation_data) > 5, "Less Than 5 Batches"
assert len(testing_data) > 5, "Less Than 5 Batches"

# %%
print(f"Train shape : {X.shape} y shape {y.shape}")
# Out:
# Train shape : (32, 299, 299, 3) y shape (32, 4)

# %% [markdown]
# ## Xception

# %%
def Base_model(ImageSize):
  BaseModel = Xception(
    include_top=False,
    weights="imagenet",
    input_shape=(ImageSize,ImageSize,3))
  BaseModel.trainable = False
  return BaseModel

Xception_base = Base_model(Image_Size)

# %%
# for layer in Xception_base.layers:
#     layer.trainable=False

# %%
def ModelTop(base_model, dropout, conv_nodes, dense_node):
  Top = Sequential()
  Top.add(base_model)
  Top.add(Dropout(dropout))
  Top.add(BatchNormalization())

  Top.add(Conv2D(conv_nodes,3,padding='same',activation='relu'))
  Top.add(Conv2D(conv_nodes,3,padding='same',activation='relu'))
  Top.add(MaxPooling2D())
  Top.add(Dropout(dropout +0.10))
  Top.add(BatchNormalization())

  Top.add(Flatten())
  Top.add(Dense(dense_node,activation='relu'))
  Top.add(Dense(4,activation='softmax'))
  return Top 

# Building Top
Xception_Extention= ModelTop(Xception_base, 0.5, 1024, 1024)

# %%
Xception_Extention.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  xception (Functional)       (None, 10, 10, 2048)      20861480
#
#  dropout (Dropout)           (None, 10, 10, 2048)      0
#
#  batch_normalization_8 (Batc  (None, 10, 10, 2048)     8192
#  hNormalization)
#
#  conv2d_8 (Conv2D)           (None, 10, 10, 1024)      18875392
#
#  conv2d_9 (Conv2D)           (None, 10, 10, 1024)      9438208
#
#  max_pooling2d (MaxPooling2D  (None, 5, 5, 1024)       0
#  )
#
#  dropout_1 (Dropout)         (None, 5, 5, 1024)        0
#
#  batch_normalization_9 (Batc  (None, 5, 5, 1024)       4096
#  hNormalization)
#
#  flatten (Flatten)           (None, 25600)             0
#
#  dense_3 (Dense)             (None, 1024)              26215424
#
#  dense_4 (Dense)             (None, 4)                 4100
#
# =================================================================
# Total params: 75,406,892
# Trainable params: 54,539,268
# Non-trainable params: 20,867,624
# _________________________________________________________________

# %%
plot_model(
    Xception_Extention,
    to_file=f"{Save}Xception/Architecture.png",
    show_shapes=False,
    show_dtype=False,
    show_layer_names=True,
    rankdir="TB",
    expand_nested=False,
    dpi=96,
    layer_range=None,
    show_layer_activations=False,
)

# %% [markdown]
# ### Xception Transfer Learning - Freeze base model

# %%
METRICS = [
      keras.metrics.BinaryAccuracy(name='accuracy'),
      keras.metrics.Precision(name='precision'),
      keras.metrics.Recall(name='recall'),  
      keras.metrics.AUC(name='auc')
]

Xception_Extention.compile(
    optimizer=keras.optimizers.Adam(0.001), 
    loss='categorical_crossentropy',
    metrics=METRICS,
)

epochs = 10
Xception_history_1 = Xception_Extention.fit(
    training_data, 
    epochs=epochs, 
    validation_data=validation_data,
    steps_per_epoch=steps_per_epoch,
    verbose = 1,
    )
# Out:
# Epoch 1/10
# 128/128 [==============================] - 1121s 9s/step - loss: 2.3351 - accuracy: 0.7466 - precision: 0.4872 - recall: 0.2627 - auc: 0.7570 - val_loss: 1.0694 - val_accuracy: 0.7510 - val_precision: 0.5020 - val_recall: 0.4976 - val_auc: 0.7866
# Epoch 2/10
# 128/128 [==============================] - 29s 224ms/step - loss: 0.9748 - accuracy: 0.7801 - precision: 0.6231 - recall: 0.3050 - auc: 0.8150 - val_loss: 1.0359 - val_accuracy: 0.7727 - val_precision: 0.5910 - val_recall: 0.2952 - val_auc: 0.7965
# Epoch 3/10
# 128/128 [==============================] - 29s 225ms/step - loss: 0.9078 - accuracy: 0.7961 - precision: 0.6703 - recall: 0.3630 - auc: 0.8391 - val_loss: 1.0673 - val_accuracy: 0.7647 - val_precision: 0.5806 - val_recall: 0.2111 - val_auc: 0.7465
# Epoch 4/10
# 128/128 [==============================] - 29s 224ms/step - loss: 0.8239 - accuracy: 0.8106 - precision: 0.6825 - recall: 0.4535 - auc: 0.8692 - val_loss: 0.9516 - val_accuracy: 0.7566 - val_precision: 0.5220 - val_recall: 0.3138 - val_auc: 0.8108
# Epoch 5/10
# 128/128 [==============================] - 29s 225ms/step - loss: 0.7684 - accuracy: 0.8267 - precision: 0.6954 - recall: 0.5462 - auc: 0.8898 - val_loss: 1.1344 - val_accuracy: 0.7055 - val_precision: 0.3681 - val_recall: 0.2483 - val_auc: 0.7390
# Epoch 6/10
# 128/128 [==============================] - 29s 225ms/step - loss: 0.6932 - accuracy: 0.8478 - precision: 0.7310 - recall: 0.6190 - auc: 0.9117 - val_loss: 1.0542 - val_accuracy: 0.7610 - val_precision: 0.5281 - val_recall: 0.4135 - val_auc: 0.8052
# Epoch 7/10
# 128/128 [==============================] - 29s 225ms/step - loss: 0.6452 - accuracy: 0.8621 - precision: 0.7525 - recall: 0.6685 - auc: 0.9247 - val_loss: 1.1354 - val_accuracy: 0.7385 - val_precision: 0.4719 - val_recall: 0.3851 - val_auc: 0.7839
# Epoch 8/10
# 128/128 [==============================] - 29s 225ms/step - loss: 0.6164 - accuracy: 0.8754 - precision: 0.7749 - recall: 0.7068 - auc: 0.9326 - val_loss: 2.2778 - val_accuracy: 0.6522 - val_precision: 0.2904 - val_recall: 0.2708 - val_auc: 0.6145
# Epoch 9/10
# 128/128 [==============================] - 29s 225ms/step - loss: 0.5269 - accuracy: 0.8899 - precision: 0.8004 - recall: 0.7457 - auc: 0.9497 - val_loss: 1.1165 - val_accuracy: 0.7818 - val_precision: 0.5702 - val_recall: 0.5161 - val_auc: 0.8301
# Epoch 10/10
# 128/128 [==============================] - 29s 226ms/step - loss: 0.4121 - accuracy: 0.9159 - precision: 0.8450 - recall: 0.8126 - auc: 0.9689 - val_loss: 1.2787 - val_accuracy: 0.8028 - val_precision: 0.6074 - val_recall: 0.5973 - val_auc: 0.8447

# %%
path = "Xception/loss_acc_1.png"
title = " MODEL'S METRICS VISUALIZATION : Transfer Learning "
Eval_Plot(
    Xception_history_1.history['accuracy'],Xception_history_1.history['val_accuracy'],
    Xception_history_1.history['loss'],Xception_history_1.history['val_loss'],
    Xception_history_1.history['auc'],Xception_history_1.history['val_auc'],
    Xception_history_1.history['precision'],Xception_history_1.history['val_precision'],
    path, title
)

# %% [markdown]
# ### Xception finetuning - Unfreeze base model and train entire model with low learning rate

# %%
isinstance(Xception_base.layers[1], BatchNormalization)
# Out:
# False

# %%
Xception_base.trainable = True
#freeze_BN(Xception_base)

# %%
epochs = 50
lr_reduce = ReduceLROnPlateau(monitor='val_auc', factor=0.6, patience=5, verbose=1, mode='max', min_lr=5e-5)

early_stopping_cb = EarlyStopping(
    monitor='val_auc', 
    patience=10, 
    restore_best_weights=True, 
    verbose=1, 
    mode="max"
    )

checkpoint_cb = ModelCheckpoint(
    f"{Save}Xception/Xception.h5", 
    monitor='val_auc',
    save_best_only=True, 
    verbose=1, 
    mode="max"
    )

Xception_Extention.compile(
    optimizer=keras.optimizers.RMSprop(0.001),  # Low learning rate
    loss='categorical_crossentropy',
    metrics=METRICS,
)

Xception_Extention.summary()

Xception_history_2 = Xception_Extention.fit(
    training_data, 
    epochs=epochs, 
    validation_data=validation_data, 
    verbose = 1, 
    steps_per_epoch=steps_per_epoch,
    callbacks = [lr_reduce, early_stopping_cb, checkpoint_cb])
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  xception (Functional)       (None, 10, 10, 2048)      20861480
#
#  dropout (Dropout)           (None, 10, 10, 2048)      0
#
#  batch_normalization_8 (Batc  (None, 10, 10, 2048)     8192
#  hNormalization)
#
#  conv2d_8 (Conv2D)           (None, 10, 10, 1024)      18875392
#
#  conv2d_9 (Conv2D)           (None, 10, 10, 1024)      9438208
#
#  max_pooling2d (MaxPooling2D  (None, 5, 5, 1024)       0
#  )
#
#  dropout_1 (Dropout)         (None, 5, 5, 1024)        0
#
#  batch_normalization_9 (Batc  (None, 5, 5, 1024)       4096
#  hNormalization)
#
#  flatten (Flatten)           (None, 25600)             0
#
#  dense_3 (Dense)             (None, 1024)              26215424
#
#  dense_4 (Dense)             (None, 4)                 4100
#
# =================================================================
# Total params: 75,406,892
# Trainable params: 75,346,220
# Non-trainable params: 60,672
# _________________________________________________________________
# Epoch 1/50
# 128/128 [==============================] - ETA: 0s - loss: 1.0592 - accuracy: 0.7959 - precision: 0.6285 - recall: 0.4494 - auc: 0.8277
# Epoch 1: val_auc improved from -inf to 0.68667, saving model to drive/MyDrive/Pammy_Alzheimers_Disease_Prediction/Visualisation/Xception/Xception.h5
# 128/128 [==============================] - 121s 857ms/step - loss: 1.0592 - accuracy: 0.7959 - precision: 0.6285 - recall: 0.4494 - auc: 0.8277 - val_loss: 39.1070 - val_accuracy: 0.7502 - val_precision: 0.5005 - val_recall: 0.5005 - val_auc: 0.6867 - lr: 0.0010
# Epoch 2/50
# 128/128 [==============================] - ETA: 0s - loss: 0.9491 - accuracy: 0.8197 - precision: 0.6846 - recall: 0.5172 - auc: 0.8782
# Epoch 2: val_auc did not improve from 0.68667
# 128/128 [==============================] - 103s 805ms/step - loss: 0.9491 - accuracy: 0.8197 - precision: 0.6846 - recall: 0.5172 - auc: 0.8782 - val_loss: 42.2943 - val_accuracy: 0.7001 - val_precision: 0.4002 - val_recall: 0.3998 - val_auc: 0.6110 - lr: 0.0010
# Epoch 3/50
# 128/128 [==============================] - ETA: 0s - loss: 0.6914 - accuracy: 0.8545 - precision: 0.7336 - recall: 0.6562 - auc: 0.9171
50
# 128/128 [==============================] - ETA: 0s - loss: 0.0399 - accuracy: 0.9952 - precision: 0.9906 - recall: 0.9902 - auc: 0.9992
# Epoch 17: val_auc did not improve from 0.92535
# 128/128 [==============================] - 103s 805ms/step - loss: 0.0399 - accuracy: 0.9952 - precision: 0.9906 - recall: 0.9902 - auc: 0.9992 - val_loss: 2.3349 - val_accuracy: 0.8712 - val_precision: 0.7427 - val_recall: 0.7419 - val_auc: 0.8818 - lr: 6.0000e-04
# Epoch 18/50
# 128/128 [==============================] - ETA: 0s - loss: 0.0319 - accuracy: 0.9977 - precision: 0.9953 - recall: 0.9953 - auc: 0.9995
# Epoch 18: val_auc did not improve from 0.92535
# 128/128 [==============================] - 103s 805ms/step - loss: 0.0319 - accuracy: 0.9977 - precision: 0.9953 - recall: 0.9953 - auc: 0.9995 - val_loss: 1.5276 - val_accuracy: 0.9047 - val_precision: 0.8094 - val_recall: 0.8094 - val_auc: 0.9205 - lr: 6.0000e-04
# Epoch 19/50
# 128/128 [==============================] - ETA: 0s - loss: 0.0260 - accuracy: 0.9962 - precision: 0.9924 - recall: 0.9924 - auc: 0.9993
# Epoch 19: val_auc did not improve from 0.92535
# 128/128 [==============================] - 103s 805ms/step - loss: 0.0260 - accuracy: 0.9962 - precision: 0.9924 - recall: 0.9924 - auc: 0.9993 - val_loss: 2.7883 - val_accuracy: 0.8514 - val_precision: 0.7028 - val_recall: 0.7028 - val_auc: 0.8429 - lr: 6.0000e-04
# Epoch 20/50
# 128/128 [==============================] - ETA: 0s - loss: 0.0471 - accuracy: 0.9948 - precision: 0.9897 - recall: 0.9897 - auc: 0.9975
# Epoch 20: val_auc did not improve from 0.92535
# 128/128 [==============================] - 103s 807ms/step - loss: 0.0471 - accuracy: 0.9948 - precision: 0.9897 - recall: 0.9897 - auc: 0.9975 - val_loss: 1.8930 - val_accuracy: 0.8688 - val_precision: 0.7396 - val_recall: 0.7331 - val_auc: 0.8832 - lr: 6.0000e-04
# Epoch 21/50
# 128/128 [==============================] - ETA: 0s - loss: 0.0059 - accuracy: 0.9990 - precision: 0.9980 - recall: 0.9978 - auc: 0.9998
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0003600000170990825.
# Restoring model weights from the end of the best epoch: 11.
#
# Epoch 21: val_auc did not improve from 0.92535
# 128/128 [==============================] - 103s 807ms/step - loss: 0.0059 - accuracy: 0.9990 - precision: 0.9980 - recall: 0.9978 - auc: 0.9998 - val_loss: 4.5656 - val_accuracy: 0.8502 - val_precision: 0.7006 - val_recall: 0.6999 - val_auc: 0.8465 - lr: 6.0000e-04
# Epoch 21: early stopping

# %% [markdown]
# ### Scores

# %%
scores_Xception = Xception_Extention.evaluate_generator(testing_data)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   """Entry point for launching an IPython kernel.

# %%
print(f"Accuracy in test set  : {scores_Xception[1]}")
print(f"Precision in test set : {scores_Xception[2]}")
print(f"Recall in test set    : {scores_Xception[3]}")
print(f"AUC in test set       : {scores_Xception[4]}")
# Out:
# Accuracy in test set  : 0.8481235504150391
# Precision in test set : 0.6964006423950195
# Recall in test set    : 0.6958561539649963
# AUC in test set       : 0.8684386014938354

# %% [markdown]
# ### Plots

# %%
path = "Xception/loss_acc_2.png"
title = " MODEL'S METRICS VISUALIZATION : Fine Tuning "
Eval_Plot(
    Xception_history_2.history['accuracy'],Xception_history_2.history['val_accuracy'],
    Xception_history_2.history['loss'],Xception_history_2.history['val_loss'],
    Xception_history_2.history['auc'],Xception_history_2.history['val_auc'],
    Xception_history_2.history['precision'],Xception_history_2.history['val_precision'],
    path, title
)

# %%
imshow(testing_data[0][0][0])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
predictions = Xception_Extention.predict(testing_data)

# %%
y_pred = predictions.argmax(axis = -1)
y_label = testing_data.labels.copy()
class_Names = list(testing_data.class_indices.keys())

# %%
assert y_pred.shape == y_label.shape

# %%
Confusion_Matrix_Heatmap(y_label, y_pred, class_Names, f"Xception/HeatMap.jpeg", "Xception")

# %%
Xception_Extention.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  xception (Functional)       (None, 10, 10, 2048)      20861480
#
#  dropout (Dropout)           (None, 10, 10, 2048)      0
#
#  batch_normalization_8 (Batc  (None, 10, 10, 2048)     8192
#  hNormalization)
#
#  conv2d_8 (Conv2D)           (None, 10, 10, 1024)      18875392
#
#  conv2d_9 (Conv2D)           (None, 10, 10, 1024)      9438208
#
#  max_pooling2d (MaxPooling2D  (None, 5, 5, 1024)       0
#  )
#
#  dropout_1 (Dropout)         (None, 5, 5, 1024)        0
#
#  batch_normalization_9 (Batc  (None, 5, 5, 1024)       4096
#  hNormalization)
#
#  flatten (Flatten)           (None, 25600)             0
#
#  dense_3 (Dense)             (None, 1024)              26215424
#
#  dense_4 (Dense)             (None, 4)                 4100
#
# =================================================================
# Total params: 75,406,892
# Trainable params: 75,346,220
# Non-trainable params: 60,672
# _________________________________________________________________

# %% [markdown]
# # GradCam, activation Visualisation

# %%
# Display
from IPython.display import Image, display
import matplotlib.pyplot as plt
import matplotlib.cm as cm

# %% [markdown]
# ## Configurable parameters

# %%
last_conv_layer_name = "conv2d_9"
decode_predictions = keras.applications.xception.decode_predictions
X,y = testing_data.next()

# %%
X[3].shape
# Out:
# (299, 299, 3)

# %%
img_path = X[0].copy()
imshow(X[3])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
def get_img_array(img_path, size):
    # `img` is a PIL image of size 299x299
    img = keras.preprocessing.image.load_img(img_path, target_size=size)
    # `array` is a float32 Numpy array of shape (299, 299, 3)
    array = keras.preprocessing.image.img_to_array(img)
    # We add a dimension to transform our image array into a "batch"
    # of size (1, 299, 299, 3)
    array = np.expand_dims(array, axis=0)
    return array


def make_gradcam_heatmap(img_array, model, last_conv_layer_name, pred_index=None):
    # First, we create a model that maps the input image to the activations
    # of the last conv layer as well as the output predictions
    grad_model = tf.keras.models.Model(
        [model.inputs], [model.get_layer(last_conv_layer_name).output, model.output]
    )

    # Then, we compute the gradient of the top predicted class for our input image
    # with respect to the activations of the last conv layer
    with tf.GradientTape() as tape:
        last_conv_layer_output, preds = grad_model(img_array)
        if pred_index is None:
            pred_index = tf.argmax(preds[0])
        class_channel = preds[:, pred_index]

    # This is the gradient of the output neuron (top predicted or chosen)
    # with regard to the output feature map of the last conv layer
    grads = tape.gradient(class_channel, last_conv_layer_output)

    # This is a vector where each entry is the mean intensity of the gradient
    # over a specific feature map channel
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))

    # We multiply each channel in the feature map array
    # by "how important this channel is" with regard to the top predicted class
    # then sum all the channels to obtain the heatmap class activation
    last_conv_layer_output = last_conv_layer_output[0]
    heatmap = last_conv_layer_output @ pooled_grads[..., tf.newaxis]
    heatmap = tf.squeeze(heatmap)

    # For visualization purpose, we will also normalize the heatmap between 0 & 1
    heatmap = tf.maximum(heatmap, 0) / tf.math.reduce_max(heatmap)
    return heatmap.numpy()

def get_gradcam_img(img_path, heatmap, cam_path="cam.jpg", alpha=0.4):
    # Load the original image
    img = keras.preprocessing.image.load_img(img_path)
    img = keras.preprocessing.image.img_to_array(img)

    # Rescale heatmap to a range 0-255
    heatmap = np.uint8(255 * heatmap)

    # Use jet colormap to colorize heatmap
    jet = cm.get_cmap("jet")

    # Use RGB values of the colormap
    jet_colors = jet(np.arange(256))[:, :3]
    jet_heatmap = jet_colors[heatmap]

    # Create an image with RGB colorized heatmap
    jet_heatmap = keras.preprocessing.image.array_to_img(jet_heatmap)
    jet_heatmap = jet_heatmap.resize((img.shape[1], img.shape[0]))
    jet_heatmap = keras.preprocessing.image.img_to_array(jet_heatmap)

    # Superimpose the heatmap on original image
    superimposed_img = jet_heatmap * alpha + img
    superimposed_img = keras.preprocessing.image.array_to_img(superimposed_img)

    return superimposed_img

# %%
# Make model
model_load= keras.models.load_model(f"{Save}Xception/Xception.h5")

# Remove last layer's softmax
#model_load.layers[-1].activation = None

# %%
import pandas as pd

scores_Xception = model_load.evaluate(testing_data)

Scores = pd.DataFrame([scores_Xception], columns = ["Loss", "Test Accuracy", "Precision", "Recall", "AUC"])
Scores
# Out:
# 40/40 [==============================] - 375s 9s/step - loss: 2.2827 - accuracy: 0.8481 - precision: 0.6964 - recall: 0.6959 - auc: 0.8684
#        Loss  Test Accuracy  Precision    Recall       AUC
# 0  2.282743       0.848124   0.696401  0.695856  0.868439

# %%
Scores.to_csv(f"{Save}Xception/score.csv")

# %%
class_Names = os.listdir(f"{test}").copy()

# %%
img_paths = []
for cls in class_Names:
  ClsPath2dir = f"{test}{cls}/"
  content = os.listdir(ClsPath2dir)
  imgPath = os.path.join(ClsPath2dir, np.random.choice(content))
  img_paths.append(imgPath)

img_paths
# Out:
# ['drive/MyDrive/Pammy_Alzheimers_Disease_Prediction/Dataset/Alzheimers_Dataset/test/MildDemented/28 (23).jpg',
#  'drive/MyDrive/Pammy_Alzheimers_Disease_Prediction/Dataset/Alzheimers_Dataset/test/ModerateDemented/29.jpg',
#  'drive/MyDrive/Pammy_Alzheimers_Disease_Prediction/Dataset/Alzheimers_Dataset/test/NonDemented/32 (77).jpg',
#  'drive/MyDrive/Pammy_Alzheimers_Disease_Prediction/Dataset/Alzheimers_Dataset/test/VeryMildDemented/28 (21).jpg']

# %%
fig, axs = plt.subplots(2, 2, figsize = (15,15))
for ax, path, label in zip(axs.flatten(), img_paths, class_Names): 
  # Prepare image
  img_arry = keras.applications.xception.preprocess_input(get_img_array(path, (Image_Size, Image_Size)))
  # Print what the top predicted class is
  preds = model_load.predict(img_arry)
  print(f"Predicted : {Ind2ClassName[int(preds.argmax(axis=-1).squeeze())]}")
  #print("Predicted:", decode_predictions(preds, top=1)[0])

  # Generate class activation heatmap
  heatmap = make_gradcam_heatmap(img_arry, model_load, last_conv_layer_name)

  # Get superImposed Image
  superimposed_img = get_gradcam_img(path, heatmap)
  ax.imshow(superimposed_img)
  ax.axis('off')
  ax.title.set_text(f"Predicted label : {Ind2ClassName[int(preds.argmax(axis=-1).squeeze())]} Actual : {label}")

plt.suptitle('Grad Cam Visualisation')
plt.savefig(f"{Save}Xception/GradCam.jpg")
plt.show()
# Out:
# WARNING:tensorflow:6 out of the last 16 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f2f57375830> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Predicted : VeryMildDemented
# Predicted : MildDemented
# Predicted : NonDemented
# Predicted : VeryMildDemented
